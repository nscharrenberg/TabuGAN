# %%
pip install rdt
# Out:
# Requirement already satisfied: rdt in /usr/local/lib/python3.10/dist-packages (1.12.1)
# Requirement already satisfied: Faker>=17 in /usr/local/lib/python3.10/dist-packages (from rdt) (25.9.2)
# Requirement already satisfied: pandas>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from rdt) (2.0.3)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from rdt) (1.2.2)
# Requirement already satisfied: numpy>=1.23.3 in /usr/local/lib/python3.10/dist-packages (from rdt) (1.25.2)
# Requirement already satisfied: scipy>=1.9.2 in /usr/local/lib/python3.10/dist-packages (from rdt) (1.11.4)
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.10/dist-packages (from Faker>=17->rdt) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.0->rdt) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.0->rdt) (2024.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.1.0->rdt) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.1.0->rdt) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.4->Faker>=17->rdt) (1.16.0)

# %%
import pandas as pd
X = pd.read_csv("censusData.csv")

# %%
class DataTransformer(object):
    """Data Transformer.

    Model continuous columns with a BayesianGMM and normalize them to a scalar between [-1, 1]
    and a vector. Discrete columns are encoded using a OneHotEncoder.
    """

    def __init__(self, max_clusters=10, weight_threshold=0.005):
        """Create a data transformer.

        Args:
            max_clusters (int):
                Maximum number of Gaussian distributions in Bayesian GMM.
            weight_threshold (float):
                Weight threshold for a Gaussian distribution to be kept.
        """
        self._max_clusters = max_clusters
        self._weight_threshold = weight_threshold

    def _fit_continuous(self, data):
        """Train Bayesian GMM for continuous columns.

        Args:
            data (pd.DataFrame):
                A dataframe containing a column.

        Returns:
            namedtuple:
                A ``ColumnTransformInfo`` object.
        """
        column_name = data.columns[0]
        gm = ClusterBasedNormalizer(
            missing_value_generation='from_column',
            max_clusters=min(len(data), self._max_clusters),
            weight_threshold=self._weight_threshold,
        )
        gm.fit(data, column_name)
        num_components = sum(gm.valid_component_indicator)

        return ColumnTransformInfo(
            column_name=column_name,
            column_type='continuous',
            transform=gm,
            output_info=[SpanInfo(1, 'tanh'), SpanInfo(num_components, 'softmax')],
            output_dimensions=1 + num_components,
        )

    def _fit_discrete(self, data):
        """Fit one hot encoder for discrete column.

        Args:
            data (pd.DataFrame):
                A dataframe containing a column.

        Returns:
            namedtuple:
                A ``ColumnTransformInfo`` object.
        """
        column_name = data.columns[0]
        ohe = OneHotEncoder()
        ohe.fit(data, column_name)
        num_categories = len(ohe.dummies)

        return ColumnTransformInfo(
            column_name=column_name,
            column_type='discrete',
            transform=ohe,
            output_info=[SpanInfo(num_categories, 'softmax')],
            output_dimensions=num_categories,
        )

    def fit(self, raw_data, discrete_columns=()):
        """Fit the ``DataTransformer``.

        Fits a ``ClusterBasedNormalizer`` for continuous columns and a
        ``OneHotEncoder`` for discrete columns.

        This step also counts the #columns in matrix data and span information.
        """
        self.output_info_list = []
        self.output_dimensions = 0
        self.dataframe = True

        if not isinstance(raw_data, pd.DataFrame):
            self.dataframe = False
            # work around for RDT issue #328 Fitting with numerical column names fails
            discrete_columns = [str(column) for column in discrete_columns]
            column_names = [str(num) for num in range(raw_data.shape[1])]
            raw_data = pd.DataFrame(raw_data, columns=column_names)

        self._column_raw_dtypes = raw_data.infer_objects().dtypes
        self._column_transform_info_list = []
        for column_name in raw_data.columns:
            if column_name in discrete_columns:
                column_transform_info = self._fit_discrete(raw_data[[column_name]])
            else:
                column_transform_info = self._fit_continuous(raw_data[[column_name]])

            self.output_info_list.append(column_transform_info.output_info)
            self.output_dimensions += column_transform_info.output_dimensions
            self._column_transform_info_list.append(column_transform_info)

    def _transform_continuous(self, column_transform_info, data):
        column_name = data.columns[0]
        flattened_column = data[column_name].to_numpy().flatten()
        data = data.assign(**{column_name: flattened_column})
        gm = column_transform_info.transform
        transformed = gm.transform(data)

        #  Converts the transformed data to the appropriate output format.
        #  The first column (ending in '.normalized') stays the same,
        #  but the lable encoded column (ending in '.component') is one hot encoded.
        output = np.zeros((len(transformed), column_transform_info.output_dimensions))
        output[:, 0] = transformed[f'{column_name}.normalized'].to_numpy()
        index = transformed[f'{column_name}.component'].to_numpy().astype(int)
        output[np.arange(index.size), index + 1] = 1.0

        return output

    def _transform_discrete(self, column_transform_info, data):
        ohe = column_transform_info.transform
        return ohe.transform(data).to_numpy()

    def _synchronous_transform(self, raw_data, column_transform_info_list):
        """Take a Pandas DataFrame and transform columns synchronous.

        Outputs a list with Numpy arrays.
        """
        column_data_list = []
        for column_transform_info in column_transform_info_list:
            column_name = column_transform_info.column_name
            data = raw_data[[column_name]]
            if column_transform_info.column_type == 'continuous':
                column_data_list.append(self._transform_continuous(column_transform_info, data))
            else:
                column_data_list.append(self._transform_discrete(column_transform_info, data))

        return column_data_list

    def _parallel_transform(self, raw_data, column_transform_info_list):
        """Take a Pandas DataFrame and transform columns in parallel.

        Outputs a list with Numpy arrays.
        """
        processes = []
        for column_transform_info in column_transform_info_list:
            column_name = column_transform_info.column_name
            data = raw_data[[column_name]]
            process = None
            if column_transform_info.column_type == 'continuous':
                process = delayed(self._transform_continuous)(column_transform_info, data)
            else:
                process = delayed(self._transform_discrete)(column_transform_info, data)
            processes.append(process)

        return Parallel(n_jobs=-1)(processes)

    def transform(self, raw_data):
        """Take raw data and output a matrix data."""
        if not isinstance(raw_data, pd.DataFrame):
            column_names = [str(num) for num in range(raw_data.shape[1])]
            raw_data = pd.DataFrame(raw_data, columns=column_names)

        # Only use parallelization with larger data sizes.
        # Otherwise, the transformation will be slower.
        if raw_data.shape[0] < 500:
            column_data_list = self._synchronous_transform(
                raw_data, self._column_transform_info_list
            )
        else:
            column_data_list = self._parallel_transform(raw_data, self._column_transform_info_list)

        return np.concatenate(column_data_list, axis=1).astype(float)

    def _inverse_transform_continuous(self, column_transform_info, column_data, sigmas, st):
        gm = column_transform_info.transform
        data = pd.DataFrame(column_data[:, :2], columns=list(gm.get_output_sdtypes())).astype(float)
        data[data.columns[1]] = np.argmax(column_data[:, 1:], axis=1)
        if sigmas is not None:
            selected_normalized_value = np.random.normal(data.iloc[:, 0], sigmas[st])
            data.iloc[:, 0] = selected_normalized_value

        return gm.reverse_transform(data)

    def _inverse_transform_discrete(self, column_transform_info, column_data):
        ohe = column_transform_info.transform
        data = pd.DataFrame(column_data, columns=list(ohe.get_output_sdtypes()))
        return ohe.reverse_transform(data)[column_transform_info.column_name]

    def inverse_transform(self, data, sigmas=None):
        """Take matrix data and output raw data.

        Output uses the same type as input to the transform function.
        Either np array or pd dataframe.
        """
        st = 0
        recovered_column_data_list = []
        column_names = []
        for column_transform_info in self._column_transform_info_list:
            dim = column_transform_info.output_dimensions
            column_data = data[:, st : st + dim]
            if column_transform_info.column_type == 'continuous':
                recovered_column_data = self._inverse_transform_continuous(
                    column_transform_info, column_data, sigmas, st
                )
            else:
                recovered_column_data = self._inverse_transform_discrete(
                    column_transform_info, column_data
                )

            recovered_column_data_list.append(recovered_column_data)
            column_names.append(column_transform_info.column_name)
            st += dim

        recovered_data = np.column_stack(recovered_column_data_list)
        recovered_data = pd.DataFrame(recovered_data, columns=column_names).astype(
            self._column_raw_dtypes
        )
        if not self.dataframe:
            recovered_data = recovered_data.to_numpy()

        return recovered_data

    def convert_column_name_value_to_id(self, column_name, value):
        """Get the ids of the given `column_name`."""
        discrete_counter = 0
        column_id = 0
        for column_transform_info in self._column_transform_info_list:
            if column_transform_info.column_name == column_name:
                break
            if column_transform_info.column_type == 'discrete':
                discrete_counter += 1

            column_id += 1

        else:
            raise ValueError(f"The column_name `{column_name}` doesn't exist in the data.")

        ohe = column_transform_info.transform
        data = pd.DataFrame([value], columns=[column_transform_info.column_name])
        one_hot = ohe.transform(data).to_numpy()[0]
        if sum(one_hot) == 0:
            raise ValueError(f"The value `{value}` doesn't exist in the column `{column_name}`.")

        return {
            'discrete_column_id': discrete_counter,
            'column_id': column_id,
            'value_id': np.argmax(one_hot),
        }


import pandas as pd
import torch
import torch.nn as nn
from google.colab import drive
from sklearn.preprocessing import OneHotEncoder
X = pd.read_csv("censusData.csv")
drive.mount('/content/drive')

categorical_columns = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'native-country','income']
print("Categorical: ",categorical_columns)
continuous_columns = [col for col in X.columns if col not in categorical_columns]
print("Continuous: ",continuous_columns)

X['capital-gain-binary'] = (X['capital-gain'] != 0).astype(int)  # 1 if gain exists, 0 otherwise
categorical_columns.append('capital-gain-binary')
X['capital-loss-binary'] = (X['capital-loss'] != 0).astype(int)  # 1 if loss exists, 0 otherwise
categorical_columns.append('capital-loss-binary')

encoder = OneHotEncoder(handle_unknown='ignore', sparse=False, drop='if_binary')
X_encoded_cat = encoder.fit_transform(X[categorical_columns])
print(encoder.get_feature_names_out())
from collections import namedtuple

from rdt.transformers import ClusterBasedNormalizer, OneHotEncoder
SpanInfo = namedtuple('SpanInfo', ['dim', 'activation_fn'])
ColumnTransformInfo = namedtuple(
    'ColumnTransformInfo',
    ['column_name', 'column_type', 'transform', 'output_info', 'output_dimensions'],
)
import numpy as np
dataTrans = DataTransformer()
print(X[continuous_columns].values)
# Precompute an encoder to handle later conversions efficiently
for column in continuous_columns:
  CTI = dataTrans._fit_continuous(pd.DataFrame(X[column],columns=[column]))
  temp = dataTrans._transform_continuous(CTI, pd.DataFrame(X[column],columns=[column]))
  X[column] = temp
print('cti; ',CTI)
X_continuous = X[continuous_columns].values
print(X_continuous)
temp = np.concatenate((X_encoded_cat,np.array(X_continuous)),axis=1)
np.savetxt("original_datav8.csv", temp, delimiter=",")
print(torch.tensor(X_encoded_cat).shape)
X_encoded = torch.cat((torch.tensor(X_encoded_cat),torch.tensor(X_continuous)),dim=1)
dataset = list(X_encoded)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(X_encoded.shape)
num_variables = X_encoded_cat.shape[1] + X_continuous.shape[1]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Categorical:  ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'native-country', 'income']
# Continuous:  ['age', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week']
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ['workclass_?' 'workclass_Federal-gov' 'workclass_Local-gov'
#  'workclass_Never-worked' 'workclass_Private' 'workclass_Self-emp-inc'
#  'workclass_Self-emp-not-inc' 'workclass_State-gov'
#  'workclass_Without-pay' 'workclass_nan' 'education_10th' 'education_11th'
#  'education_12th' 'education_1st-4th' 'education_5th-6th'
#  'education_7th-8th' 'education_9th' 'education_Assoc-acdm'
#  'education_Assoc-voc' 'education_Bachelors' 'education_Doctorate'
#  'education_HS-grad' 'education_Masters' 'education_Preschool'
#  'education_Prof-school' 'education_Some-college'
#  'marital-status_Divorced' 'marital-status_Married-AF-spouse'
#  'marital-status_Married-civ-spouse'
#  'marital-status_Married-spouse-absent' 'marital-status_Never-married'
#  'marital-status_Separated' 'marital-status_Widowed' 'occupation_?'
#  'occupation_Adm-clerical' 'occupation_Armed-Forces'
#  'occupation_Craft-repair' 'occupation_Exec-managerial'
#  'occupation_Farming-fishing' 'occupation_Handlers-cleaners'
#  'occupation_Machine-op-inspct' 'occupation_Other-service'
#  'occupation_Priv-house-serv' 'occupation_Prof-specialty'
#  'occupation_Protective-serv' 'occupation_Sales' 'occupation_Tech-support'
#  'occupation_Transport-moving' 'occupation_nan' 'relationship_Husband'
#  'relationship_Not-in-family' 'relationship_Other-relative'
#  'relationship_Own-child' 'relationship_Unmarried' 'relationship_Wife'
#  'race_Amer-Indian-Eskimo' 'race_Asian-Pac-Islander' 'race_Black'
#  'race_Other' 'race_White' 'sex_Male' 'native-country_?'
#  'native-country_Cambodia' 'native-country_Canada' 'native-country_China'
#  'native-country_Columbia' 'native-country_Cuba'
#  'native-country_Dominican-Republic' 'native-country_Ecuador'
#  'native-country_El-Salvador' 'native-country_England'
#  'native-country_France' 'native-country_Germany' 'native-country_Greece'
#  'native-country_Guatemala' 'native-country_Haiti'
#  'native-country_Holand-Netherlands' 'native-country_Honduras'
#  'native-country_Hong' 'native-country_Hungary' 'native-country_India'
#  'native-country_Iran' 'native-country_Ireland' 'native-country_Italy'
#  'native-country_Jamaica' 'native-country_Japan' 'native-country_Laos'
#  'native-country_Mexico' 'native-country_Nicaragua'
#  'native-country_Outlying-US(Guam-USVI-etc)' 'native-country_Peru'
#  'native-country_Philippines' 'native-country_Poland'
#  'native-country_Portugal' 'native-country_Puerto-Rico'
#  'native-country_Scotland' 'native-country_South' 'native-country_Taiwan'
#  'native-country_Thailand' 'native-country_Trinadad&Tobago'
#  'native-country_United-States' 'native-country_Vietnam'
#  'native-country_Yugoslavia' 'native-country_nan' 'income_>50K'
#  'capital-gain-binary_1' 'capital-loss-binary_1']
# [[  39   13 2174    0   40]
#  [  50   13    0    0   13]
#  [  38    9    0    0   40]
#  ...
#  [  38   13    0    0   50]
#  [  44   13 5455    0   40]
#  [  35   13    0    0   60]]
# cti;  ColumnTransformInfo(column_name='hours-per-week', column_type='continuous', transform=ClusterBasedNormalizer(missing_value_generation='from_column'), output_info=[SpanInfo(dim=1, activation_fn='tanh'), SpanInfo(dim=10, activation_fn='softmax')], output_dimensions=11)
# [[-4.81735581e-01  2.09453583e-03 -1.33843643e-01 -2.45830481e-04
#   -5.64630074e-05]
#  [-4.41787833e-02  2.09453583e-03 -3.10536227e-04 -2.45830481e-04
#    4.18596044e-02]
#  [-1.76794103e-01 -7.68821920e-04 -3.10536227e-04 -2.45830481e-04
#   -5.64630074e-05]
#  ...
#  [ 2.60900999e-01  2.09453583e-03 -3.10536227e-04 -2.45830481e-04
#   -3.67164036e-02]
#  [-6.16925087e-01  2.09453583e-03  3.05262032e-01 -2.45830481e-04
#   -5.64630074e-05]
#  [-1.57565393e-02  2.09453583e-03 -3.10536227e-04 -2.45830481e-04
#    5.37004536e-03]]
# torch.Size([48842, 107])
# torch.Size([48842, 112])

# %%
mi_matrix = torch.load('mutual_information_matrix_full.pt')
temp = mi_matrix.clone()
def clearData(mi_matrix):
    temp = torch.zeros_like(mi_matrix)
    for i in range(mi_matrix.shape[0]):
        for j in range(mi_matrix.shape[1]):
          k=i
          l=j
          if i >= 60 and i < 107:
            k+=1
            if i >= 105:
              k+=1
          if j >= 60 and j < 107:
            l+=1
            if j >= 105:
              l+=1
          if (k >= 107 and i<107) or (l >= 107 and j<107) :
            continue
          temp[i,j] = mi_matrix[k,j]
    return temp

# %%
import numpy as np
from sklearn.metrics import mutual_info_score
import time
mutual_information_matrix = torch.load('mutual_information_matrix_full.pt')

def calculate_mutual_information_matrix(X_encoded):
    n_features = X_encoded.shape[1]
    temp = clearData(mutual_information_matrix[:107,:107])
    mi_matrix = mutual_information_matrix
    mi_matrix[:107,:107] = temp
    for i in range(num_variables):
        for j in range(i + 1, num_variables):
            if not ((i>=105 and i<107) or (j>=105 and j<107)):
              continue
            start_time = time.time()
            X_col_i = X_encoded[:, i]
            X_col_j = X_encoded[:, j]
            mi_matrix[i, j] = mutual_info_score(X_col_i, X_col_j)
            mi_matrix[j, i] = mi_matrix[i, j]  # MI is symmetric
            end_time = time.time()
            processed = end_time-start_time
            print(i, " - ", j, " : ", mi_matrix[i, j], f" - {processed:4f} s")

    return mi_matrix

# Calculate mutual information
mi_matrix = torch.tensor(calculate_mutual_information_matrix(X_encoded)).float()

torch.save(mi_matrix, 'mutual_information_matrix_fullv3.pt')
# !cp 'mutual_information_matrix_fullv3.pt' /content/drive/MyDrive
# Out:
# 0  -  105  :  tensor(6.6708e-05)  - 0.028211 s
# 0  -  106  :  tensor(0.0001)  - 0.015138 s
# 1  -  105  :  tensor(9.6461e-05)  - 0.014884 s
# 1  -  106  :  tensor(5.0161e-05)  - 0.014739 s
# 2  -  105  :  tensor(2.5689e-05)  - 0.015042 s
# 2  -  106  :  tensor(6.0200e-05)  - 0.015033 s
# 3  -  105  :  tensor(1.7656e-05)  - 0.015339 s
# 3  -  106  :  tensor(9.7977e-06)  - 0.015207 s
# 4  -  105  :  tensor(0.0006)  - 0.011549 s
# 4  -  106  :  tensor(0.0003)  - 0.010646 s
# 5  -  105  :  tensor(0.0017)  - 0.015034 s
# 5  -  106  :  tensor(0.0004)  - 0.015103 s
# 6  -  105  :  tensor(0.0002)  - 0.014920 s
# 6  -  106  :  tensor(8.6182e-05)  - 0.015317 s
# 7  -  105  :  tensor(5.4102e-06)  - 0.015172 s
# 7  -  106  :  tensor(2.5491e-06)  - 0.015076 s
# 8  -  105  :  tensor(4.3283e-07)  - 0.015786 s
# 8  -  106  :  tensor(3.8616e-09)  - 0.014853 s
# 9  -  105  :  tensor(0.0001)  - 0.015497 s
# 9  -  106  :  tensor(9.8107e-07)  - 0.015178 s
# 10  -  105  :  tensor(0.0005)  - 0.015317 s
# 10  -  106  :  tensor(0.0001)  - 0.015286 s
# 11  -  105  :  tensor(0.0005)  - 0.015223 s
# 11  -  106  :  tensor(0.0002)  - 0.014923 s
# 12  -  105  :  tensor(0.0002)  - 0.015058 s
# 12  -  106  :  tensor(0.0002)  - 0.015677 s
# 13  -  105  :  tensor(0.0001)  - 0.015551 s
# 13  -  106  :  tensor(3.4552e-05)  - 0.015623 s
# 14  -  105  :  tensor(0.0001)  - 0.015403 s
# 14  -  106  :  tensor(3.1050e-05)  - 0.015484 s
# 15  -  105  :  tensor(2.9459e-05)  - 0.015855 s
# 15  -  106  :  tensor(5.8906e-05)  - 0.015819 s
# 16  -  105  :  tensor(6.8261e-05)  - 0.015671 s
# 16  -  106  :  tensor(0.0001)  - 0.014914 s
# 17  -  105  :  tensor(7.6453e-06)  - 0.015066 s
# 17  -  106  :  tensor(3.9279e-06)  - 0.015026 s
# 18  -  105  :  tensor(5.3945e-05)  - 0.015746 s
# 18  -  106  :  tensor(2.8662e-05)  - 0.015067 s
# 19  -  105  :  tensor(0.0014)  - 0.015228 s
# 19  -  106  :  tensor(0.0008)  - 0.015022 s
# 20  -  105  :  tensor(0.0008)  - 0.015160 s
# 20  -  106  :  tensor(0.0005)  - 0.014931 s
# 21  -  105  :  tensor(0.0010)  - 0.014530 s
# 21  -  106  :  tensor(0.0005)  - 0.014926 s
# 22  -  105  :  tensor(0.0016)  - 0.015817 s
# 22  -  106  :  tensor(0.0008)  - 0.015211 s
# 23  -  105  :  tensor(1.5460e-05)  - 0.021180 s
# 23  -  106  :  tensor(1.1804e-05)  - 0.019074 s
# 24  -  105  :  tensor(0.0026)  - 0.015871 s
# 24  -  106  :  tensor(0.0006)  - 0.015475 s
# 25  -  105  :  tensor(0.0007)  - 0.015123 s
# 25  -  106  :  tensor(0.0001)  - 0.015347 s
# 26  -  105  :  tensor(0.0003)  - 0.014956 s
# 26  -  106  :  tensor(0.0001)  - 0.014847 s
# 27  -  105  :  tensor(1.1809e-08)  - 0.014633 s
# 27  -  106  :  tensor(4.3641e-07)  - 0.014862 s
# 28  -  105  :  tensor(0.0078)  - 0.010612 s
# 28  -  106  :  tensor(0.0025)  - 0.010612 s
# 29  -  105  :  tensor(8.8145e-05)  - 0.014787 s
# 29  -  106  :  tensor(2.1779e-05)  - 0.015625 s
# 30  -  105  :  tensor(0.0060)  - 0.011413 s
# 30  -  106  :  tensor(0.0016)  - 0.014658 s
# 31  -  105  :  tensor(0.0002)  - 0.018648 s
# 31  -  106  :  tensor(0.0001)  - 0.018834 s
# 32  -  105  :  tensor(1.8024e-06)  - 0.018639 s
# 32  -  106  :  tensor(1.9605e-05)  - 0.017196 s
# 33  -  105  :  tensor(6.9244e-05)  - 0.015569 s
# 33  -  106  :  tensor(0.0001)  - 0.015098 s
# 34  -  105  :  tensor(0.0004)  - 0.015551 s
# 34  -  106  :  tensor(0.0002)  - 0.015316 s
# 35  -  105  :  tensor(5.4889e-07)  - 0.015185 s
# 35  -  106  :  tensor(1.2180e-06)  - 0.015303 s
# 36  -  105  :  tensor(1.8585e-05)  - 0.015666 s
# 36  -  106  :  tensor(1.5086e-05)  - 0.015715 s
# 37  -  105  :  tensor(0.0021)  - 0.016138 s
# 37  -  106  :  tensor(0.0010)  - 0.015576 s
# 38  -  105  :  tensor(3.9731e-05)  - 0.015440 s
# 38  -  106  :  tensor(9.9970e-05)  - 0.015255 s
# 39  -  105  :  tensor(0.0005)  - 0.016076 s
# 39  -  106  :  tensor(0.0002)  - 0.016443 s
# 40  -  105  :  tensor(0.0002)  - 0.016083 s
# 40  -  106  :  tensor(0.0001)  - 0.015123 s
# 41  -  105  :  tensor(0.0020)  - 0.014589 s
# 41  -  106  :  tensor(0.0009)  - 0.015034 s
# 42  -  105  :  tensor(6.7562e-05)  - 0.015699 s
# 42  -  106  :  tensor(4.7532e-05)  - 0.015333 s
# 43  -  105  :  tensor(0.0023)  - 0.015476 s
# 43  -  106  :  tensor(0.0008)  - 0.015472 s
# 44  -  105  :  tensor(9.7489e-06)  - 0.015282 s
# 44  -  106  :  tensor(2.0671e-07)  - 0.015069 s
# 45  -  105  :  tensor(6.4146e-06)  - 0.016743 s
# 45  -  106  :  tensor(3.7999e-05)  - 0.015859 s
# 46  -  105  :  tensor(8.5652e-06)  - 0.015693 s
# 46  -  106  :  tensor(2.4033e-05)  - 0.015416 s
# 47  -  105  :  tensor(9.0236e-05)  - 0.015655 s
# 47  -  106  :  tensor(5.1692e-06)  - 0.015620 s
# 48  -  105  :  tensor(0.0001)  - 0.016155 s
# 48  -  106  :  tensor(1.1215e-06)  - 0.015473 s
# 49  -  105  :  tensor(0.0061)  - 0.011718 s
# 49  -  106  :  tensor(0.0022)  - 0.011389 s
# 50  -  105  :  tensor(0.0006)  - 0.014478 s
# 50  -  106  :  tensor(0.0001)  - 0.014516 s
# 51  -  105  :  tensor(0.0005)  - 0.015320 s
# 51  -  106  :  tensor(0.0002)  - 0.015315 s
# 52  -  105  :  tensor(0.0043)  - 0.015960 s
# 52  -  106  :  tensor(0.0013)  - 0.015981 s
# 53  -  105  :  tensor(0.0008)  - 0.015368 s
# 53  -  106  :  tensor(0.0005)  - 0.015149 s
# 54  -  105  :  tensor(0.0005)  - 0.016270 s
# 54  -  106  :  tensor(0.0001)  - 0.016418 s
# 55  -  105  :  tensor(1.4316e-05)  - 0.015752 s
# 55  -  106  :  tensor(8.7724e-05)  - 0.015404 s
# 56  -  105  :  tensor(2.0863e-07)  - 0.016539 s
# 56  -  106  :  tensor(5.5349e-06)  - 0.015729 s
# 57  -  105  :  tensor(0.0004)  - 0.015423 s
# 57  -  106  :  tensor(0.0002)  - 0.015431 s
# 58  -  105  :  tensor(5.0328e-05)  - 0.015368 s
# 58  -  106  :  tensor(9.6562e-06)  - 0.015042 s
# 59  -  105  :  tensor(0.0004)  - 0.011042 s
# 59  -  106  :  tensor(0.0002)  - 0.010747 s
# 60  -  105  :  tensor(0.0021)  - 0.010848 s
# 60  -  106  :  tensor(0.0009)  - 0.010703 s
# 61  -  105  :  tensor(7.7141e-06)  - 0.015668 s
# 61  -  106  :  tensor(2.7959e-05)  - 0.014791 s
# 62  -  105  :  tensor(2.0982e-06)  - 0.015072 s
# 62  -  106  :  tensor(1.7475e-05)  - 0.014997 s
# 63  -  105  :  tensor(6.7980e-07)  - 0.015438 s
# 63  -  106  :  tensor(1.3820e-05)  - 0.014988 s
# 64  -  105  :  tensor(1.3361e-06)  - 0.015716 s
# 64  -  106  :  tensor(4.2192e-05)  - 0.014555 s
# 65  -  105  :  tensor(3.2246e-05)  - 0.014662 s
# 65  -  106  :  tensor(2.7823e-06)  - 0.014813 s
# 66  -  105  :  tensor(1.2564e-05)  - 0.015051 s
# 66  -  106  :  tensor(3.7812e-06)  - 0.014978 s
# 67  -  105  :  tensor(3.2727e-05)  - 0.015086 s
# 67  -  106  :  tensor(2.2481e-05)  - 0.015715 s
# 68  -  105  :  tensor(1.6476e-06)  - 0.015047 s
# 68  -  106  :  tensor(4.4106e-05)  - 0.014894 s
# 69  -  105  :  tensor(1.4003e-05)  - 0.015112 s
# 69  -  106  :  tensor(3.4040e-05)  - 0.014908 s
# 70  -  105  :  tensor(1.1983e-05)  - 0.014912 s
# 70  -  106  :  tensor(1.9554e-06)  - 0.014760 s
# 71  -  105  :  tensor(6.9985e-08)  - 0.014743 s
# 71  -  106  :  tensor(4.2949e-06)  - 0.014804 s
# 72  -  105  :  tensor(3.7111e-05)  - 0.015622 s
# 72  -  106  :  tensor(8.4929e-06)  - 0.014961 s
# 73  -  105  :  tensor(2.0107e-05)  - 0.015043 s
# 73  -  106  :  tensor(1.1339e-05)  - 0.014964 s
# 74  -  105  :  tensor(3.5379e-05)  - 0.015002 s
# 74  -  106  :  tensor(3.5973e-05)  - 0.014868 s
# 75  -  105  :  tensor(4.2224e-05)  - 0.014735 s
# 75  -  106  :  tensor(8.1847e-07)  - 0.015015 s
# 76  -  105  :  tensor(1.7654e-06)  - 0.014652 s
# 76  -  106  :  tensor(6.2728e-05)  - 0.014777 s
# 77  -  105  :  tensor(3.3093e-06)  - 0.014666 s
# 77  -  106  :  tensor(9.9700e-06)  - 0.014869 s
# 78  -  105  :  tensor(1.2491e-05)  - 0.015135 s
# 78  -  106  :  tensor(3.5206e-05)  - 0.016684 s
# 79  -  105  :  tensor(1.1743e-05)  - 0.015201 s
# 79  -  106  :  tensor(1.4681e-07)  - 0.014713 s
# 80  -  105  :  tensor(1.6664e-05)  - 0.015754 s
# 80  -  106  :  tensor(5.3326e-06)  - 0.014899 s
# 81  -  105  :  tensor(3.6003e-08)  - 0.014991 s
# 81  -  106  :  tensor(5.3230e-06)  - 0.014547 s
# 82  -  105  :  tensor(1.1809e-08)  - 0.015058 s
# 82  -  106  :  tensor(4.3641e-07)  - 0.014693 s
# 83  -  105  :  tensor(2.1680e-06)  - 0.014773 s
# 83  -  106  :  tensor(9.1981e-06)  - 0.015114 s
# 84  -  105  :  tensor(1.0814e-05)  - 0.014788 s
# 84  -  106  :  tensor(4.9804e-05)  - 0.015085 s
# 85  -  105  :  tensor(1.5110e-05)  - 0.015017 s
# 85  -  106  :  tensor(4.6982e-06)  - 0.014963 s
# 86  -  105  :  tensor(5.6762e-06)  - 0.014634 s
# 86  -  106  :  tensor(5.6921e-08)  - 0.015798 s
# 87  -  105  :  tensor(0.0003)  - 0.014812 s
# 87  -  106  :  tensor(0.0002)  - 0.014957 s
# 88  -  105  :  tensor(1.4013e-05)  - 0.015517 s
# 88  -  106  :  tensor(4.1002e-07)  - 0.014560 s
# 89  -  105  :  tensor(4.0614e-05)  - 0.014956 s
# 89  -  106  :  tensor(5.6921e-08)  - 0.016151 s
# 90  -  105  :  tensor(3.1881e-05)  - 0.015041 s
# 90  -  106  :  tensor(8.1763e-06)  - 0.014958 s
# 91  -  105  :  tensor(5.4695e-06)  - 0.014920 s
# 91  -  106  :  tensor(3.6725e-08)  - 0.014837 s
# 92  -  105  :  tensor(2.3126e-06)  - 0.014626 s
# 92  -  106  :  tensor(3.2885e-06)  - 0.015259 s
# 93  -  105  :  tensor(1.5357e-05)  - 0.015565 s
# 93  -  106  :  tensor(6.5684e-05)  - 0.014966 s
# 94  -  105  :  tensor(3.2788e-05)  - 0.015238 s
# 94  -  106  :  tensor(2.0083e-07)  - 0.014567 s
# 95  -  105  :  tensor(4.0509e-06)  - 0.015010 s
# 95  -  106  :  tensor(2.0577e-05)  - 0.014892 s
# 96  -  105  :  tensor(8.0406e-06)  - 0.015655 s
# 96  -  106  :  tensor(1.2095e-05)  - 0.014863 s
# 97  -  105  :  tensor(7.9849e-07)  - 0.014891 s
# 97  -  106  :  tensor(2.9985e-06)  - 0.014497 s
# 98  -  105  :  tensor(1.2491e-05)  - 0.015155 s
# 98  -  106  :  tensor(1.3687e-06)  - 0.014630 s
# 99  -  105  :  tensor(9.3892e-06)  - 0.015110 s
# 99  -  106  :  tensor(3.9723e-06)  - 0.014666 s
# 100  -  105  :  tensor(0.0001)  - 0.011118 s
# 100  -  106  :  tensor(5.4780e-05)  - 0.010618 s
# 101  -  105  :  tensor(5.2482e-06)  - 0.014967 s
# 101  -  106  :  tensor(8.7829e-10)  - 0.014596 s
# 102  -  105  :  tensor(2.0195e-05)  - 0.014687 s
# 102  -  106  :  tensor(2.2538e-05)  - 0.015197 s
# 103  -  105  :  tensor(3.5735e-06)  - 0.015068 s
# 103  -  106  :  tensor(3.3738e-05)  - 0.014873 s
# 104  -  105  :  tensor(0.0296)  - 0.010835 s
# 104  -  106  :  tensor(0.0079)  - 0.011297 s
# 105  -  106  :  tensor(0.0041)  - 0.015038 s
# 105  -  107  :  tensor(0.0119)  - 0.014832 s
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/cluster/_supervised.py:64: UserWarning: Clustering metrics expects discrete values but received binary values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/cluster/_supervised.py:64: UserWarning: Clustering metrics expects discrete values but received binary values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/cluster/_supervised.py:64: UserWarning: Clustering metrics expects discrete values but received binary values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/cluster/_supervised.py:64: UserWarning: Clustering metrics expects discrete values but received binary values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/cluster/_supervised.py:64: UserWarning: Clustering metrics expects discrete values but received binary values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/cluster/_supervised.py:64: UserWarning: Clustering metrics expects discrete values but received binary values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/cluster/_supervised.py:64: UserWarning: Clustering metrics expects discrete values but received binary values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/cluster/_supervised.py:64: UserWarning: Clustering metrics expects discrete values but received binary values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/cluster/_supervised.py:64: UserWarning: Clustering metrics expects discrete values but received binary values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/cluster/_supervised.py:64: UserWarning: Clustering metrics expects discrete values but received binary values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)
# <ipython-input-32-ccadcef37bcf>:27: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   mi_matrix = torch.tensor(calculate_mutual_information_matrix(X_encoded)).float()
# 105  -  108  :  tensor(0.0087)  - 0.013429 s
# 105  -  109  :  tensor(0.2851)  - 0.014081 s
# 105  -  110  :  tensor(0.0041)  - 0.013791 s
# 105  -  111  :  tensor(0.0056)  - 0.014162 s
# 106  -  107  :  tensor(0.0048)  - 0.013983 s
# 106  -  108  :  tensor(0.0037)  - 0.012660 s
# 106  -  109  :  tensor(0.0041)  - 0.014259 s
# 106  -  110  :  tensor(0.1887)  - 0.013669 s
# 106  -  111  :  tensor(0.0033)  - 0.014741 s

# %%
pip install dcor
# Out:
# Collecting dcor
#   Downloading dcor-0.6-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from dcor) (1.25.2)
# Requirement already satisfied: numba>=0.51 in /usr/local/lib/python3.10/dist-packages (from dcor) (0.58.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from dcor) (1.11.4)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from dcor) (1.4.2)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51->dcor) (0.41.1)
# Installing collected packages: dcor
# Successfully installed dcor-0.6

# %%
import dcor
# Initialize distance correlation matrix (consider symmetry)
distance_correlation_matrix = clearData(torch.load('distance_correlation_matrix_full.pt'))
dcor_matrix = distance_correlation_matrix
for i in range(X_encoded.shape[1]):
    X_col_i = X_encoded[:, i]
    for j in range(i + 1, X_encoded.shape[1]):
        if not ((i>=105 and i<107) or (j>=105 and j<107)):
          continue
        X_col_j = X_encoded[:, j]

        # Calculate distance correlation
        start_time = time.time()
        dcor_value = dcor.distance_correlation(X_col_i, X_col_j)
        dcor_matrix[i, j] = dcor_value
        dcor_matrix[j, i] = dcor_value  # Distance correlation is symmetric

        end_time = time.time()
        processed = end_time-start_time
        print(i, " - ", j, " : ", dcor_value, f" - {processed:4f} s")

# Save the matrix
torch.save(dcor_matrix, 'distance_correlation_matrix_fullv3.pt')
# !cp 'distance_correlation_matrix_fullv3.pt' /content/drive/MyDrive
# Out:
# 0  -  105  :  0.011213355182485247  - 0.080725 s
# 0  -  106  :  0.014170189919922577  - 0.125271 s
# 1  -  105  :  0.014414836111897781  - 0.122015 s
# 1  -  106  :  0.010405349416430187  - 0.123041 s
# 2  -  105  :  0.007258870393968656  - 0.122225 s
# 2  -  106  :  0.01127165182096131  - 0.125784 s
# 3  -  105  :  0.00429434152049267  - 0.121508 s
# 3  -  106  :  0.003168101436037406  - 0.127950 s
# 4  -  105  :  0.0356867719368177  - 0.127882 s
# 4  -  106  :  0.0229843961089595  - 0.121410 s
# 5  -  105  :  0.06581464568080314  - 0.126580 s
# 5  -  106  :  0.03170023667570466  - 0.168638 s
# 6  -  105  :  0.01900204726937539  - 0.123196 s
# 6  -  106  :  0.013503020321858007  - 0.122241 s
# 7  -  105  :  0.00326375793418361  - 0.126648 s
# 7  -  106  :  0.0022408225852264788  - 0.125521 s
# 8  -  105  :  0.0009511051757710437  - 0.125435 s
# 8  -  106  :  8.814760694931098e-05  - 0.138649 s
# 9  -  105  :  0.01527636532455883  - 0.121690 s
# 9  -  106  :  0.001391011050757997  - 0.126257 s
# 10  -  105  :  0.027628168132644633  - 0.122569 s
# 10  -  106  :  0.013947265979046298  - 0.125160 s
# 11  -  105  :  0.027817811712470785  - 0.131734 s
# 11  -  106  :  0.0162509649483217  - 0.124868 s
# 12  -  105  :  0.017609863725133543  - 0.128023 s
# 12  -  106  :  0.0165873713330995  - 0.122293 s
# 13  -  105  :  0.013006739146025069  - 0.127312 s
# 13  -  106  :  0.007577438607258269  - 0.122433 s
# 14  -  105  :  0.013951377912833038  - 0.126157 s
# 14  -  106  :  0.007433852623714105  - 0.123567 s
# 15  -  105  :  0.007463962444811233  - 0.125681 s
# 15  -  106  :  0.010243628425712435  - 0.126422 s
# 16  -  105  :  0.011118812543858924  - 0.122932 s
# 16  -  106  :  0.015184784377877614  - 0.131616 s
# 17  -  105  :  0.003869358055824327  - 0.136538 s
# 17  -  106  :  0.0028320802503877416  - 0.124616 s
# 18  -  105  :  0.010629678765071005  - 0.126090 s
# 18  -  106  :  0.007380445022588021  - 0.124946 s
# 19  -  105  :  0.05439637355539985  - 0.126260 s
# 19  -  106  :  0.04085681802022778  - 0.122108 s
# 20  -  105  :  0.046090632828431795  - 0.125478 s
# 20  -  106  :  0.035623013575410464  - 0.122403 s
# 21  -  105  :  0.04372554156630386  - 0.125679 s
# 21  -  106  :  0.030796102720342167  - 0.125640 s
# 22  -  105  :  0.06148163530918736  - 0.122701 s
# 22  -  106  :  0.04271416687950373  - 0.128227 s
# 23  -  105  :  0.005158557041920337  - 0.122193 s
# 23  -  106  :  0.004423263064274492  - 0.126597 s
# 24  -  105  :  0.08903731730122715  - 0.122514 s
# 24  -  106  :  0.04121152291332773  - 0.129577 s
# 25  -  105  :  0.03568996644462881  - 0.123043 s
# 25  -  106  :  0.01591203087830406  - 0.126889 s
# 26  -  105  :  0.02474273421980151  - 0.122549 s
# 26  -  106  :  0.015265865636497247  - 0.126295 s
# 27  -  105  :  0.00015324814792859893  - 0.131899 s
# 27  -  106  :  0.0009565739545541593  - 0.126043 s
# 28  -  105  :  0.12451657763850704  - 0.127834 s
# 28  -  106  :  0.07114846236922687  - 0.122109 s
# 29  -  105  :  0.012464107484842968  - 0.124235 s
# 29  -  106  :  0.006321871500856258  - 0.122171 s
# 30  -  105  :  0.10351719374712125  - 0.124327 s
# 30  -  106  :  0.0546796285813303  - 0.130324 s
# 31  -  105  :  0.018101588921952547  - 0.128176 s
# 31  -  106  :  0.01586392876752723  - 0.126389 s
# 32  -  105  :  0.0018887210174190175  - 0.121672 s
# 32  -  106  :  0.006107157123392874  - 0.126718 s
# 33  -  105  :  0.011418577663001092  - 0.124366 s
# 33  -  106  :  0.014310818029365985  - 0.124445 s
# 34  -  105  :  0.028114105441299574  - 0.122381 s
# 34  -  106  :  0.020431798271400625  - 0.126117 s
# 35  -  105  :  0.0010152757736653975  - 0.129196 s
# 35  -  106  :  0.0016564171080188665  - 0.146475 s
# 36  -  105  :  0.006053681140496941  - 0.125859 s
# 36  -  106  :  0.005443456017710609  - 0.122945 s
# 37  -  105  :  0.06917944569052709  - 0.126720 s
# 37  -  106  :  0.04748306257915722  - 0.122342 s
# 38  -  105  :  0.00868959775613068  - 0.125799 s
# 38  -  106  :  0.01332206096572109  - 0.126351 s
# 39  -  105  :  0.029584082662122917  - 0.128765 s
# 39  -  106  :  0.02012387427162107  - 0.128757 s
# 40  -  105  :  0.018415722958854786  - 0.155696 s
# 40  -  106  :  0.01457446351091913  - 0.129651 s
# 41  -  105  :  0.05748625969502861  - 0.127126 s
# 41  -  106  :  0.03802919835080434  - 0.121656 s
# 42  -  105  :  0.010583852929237489  - 0.128315 s
# 42  -  106  :  0.008713818945467366  - 0.121578 s
# 43  -  105  :  0.07209902963394853  - 0.142871 s
# 43  -  106  :  0.042813579671316083  - 0.136335 s
# 44  -  105  :  0.00434735425143455  - 0.126104 s
# 44  -  106  :  0.0006409567024715188  - 0.126668 s
# 45  -  105  :  0.003597579402278151  - 0.122028 s
# 45  -  106  :  0.008848621748996383  - 0.128697 s
# 46  -  105  :  0.004186428490553462  - 0.123047 s
# 46  -  106  :  0.007120162248791839  - 0.128016 s
# 47  -  105  :  0.013037613736376033  - 0.132132 s
# 47  -  106  :  0.0031838641847360336  - 0.123379 s
# 48  -  105  :  0.01538548375388727  - 0.145681 s
# 48  -  106  :  0.0014865548130688926  - 0.169198 s
# 49  -  105  :  0.11174592571317583  - 0.129296 s
# 49  -  106  :  0.06679964896814573  - 0.159694 s
# 50  -  105  :  0.03512110134370064  - 0.149130 s
# 50  -  106  :  0.015507114826134394  - 0.127663 s
# 51  -  105  :  0.029003559918565097  - 0.126095 s
# 51  -  106  :  0.01760130242434158  - 0.122683 s
# 52  -  105  :  0.08282945510731145  - 0.117132 s
# 52  -  106  :  0.046938628575551346  - 0.112040 s
# 53  -  105  :  0.03843823177868171  - 0.118856 s
# 53  -  106  :  0.03021593509629023  - 0.130934 s
# 54  -  105  :  0.03433759889406955  - 0.127516 s
# 54  -  106  :  0.015513780768647976  - 0.123237 s
# 55  -  105  :  0.005201911956348691  - 0.127125 s
# 55  -  106  :  0.011884798409740794  - 0.122802 s
# 56  -  105  :  0.0006470892303220939  - 0.124852 s
# 56  -  106  :  0.003369539704580596  - 0.126637 s
# 57  -  105  :  0.028043809611008216  - 0.123367 s
# 57  -  106  :  0.019401617836032833  - 0.129011 s
# 58  -  105  :  0.009453560184291861  - 0.127799 s
# 58  -  106  :  0.004241126545036253  - 0.122736 s
# 59  -  105  :  0.02701904201010381  - 0.132766 s
# 59  -  106  :  0.018956668299287924  - 0.122936 s
# 60  -  105  :  0.06314134476381109  - 0.126376 s
# 60  -  106  :  0.04173627991589512  - 0.122867 s
# 61  -  105  :  0.003996894745027247  - 0.125976 s
# 61  -  106  :  0.007826374647095805  - 0.123734 s
# 62  -  105  :  0.0021340020160867694  - 0.125938 s
# 62  -  106  :  0.006856811852011089  - 0.132131 s
# 63  -  105  :  0.0011771258546017702  - 0.123020 s
# 63  -  106  :  0.005567381180830291  - 0.122803 s
# 64  -  105  :  0.0016073720965653166  - 0.129601 s
# 64  -  106  :  0.010300628643631468  - 0.121458 s
# 65  -  105  :  0.007176739268407637  - 0.126079 s
# 65  -  106  :  0.002260940017118269  - 0.122994 s
# 66  -  105  :  0.004764719980264983  - 0.126776 s
# 66  -  106  :  0.0026458797621027896  - 0.126778 s
# 67  -  105  :  0.007310358241777857  - 0.140994 s
# 67  -  106  :  0.005947649676723153  - 0.128677 s
# 68  -  105  :  0.001759049699651121  - 0.124558 s
# 68  -  106  :  0.006722967778179642  - 0.126226 s
# 69  -  105  :  0.005031395943362192  - 0.124719 s
# 69  -  106  :  0.007316772489009292  - 0.125776 s
# 70  -  105  :  0.005123166253572684  - 0.124979 s
# 70  -  106  :  0.0020312971341907866  - 0.125438 s
# 71  -  105  :  0.00037157808685080987  - 0.126544 s
# 71  -  106  :  0.002698095771919661  - 0.124559 s
# 72  -  105  :  0.009159655927369935  - 0.150253 s
# 72  -  106  :  0.0039292024749437715  - 0.165874 s
# 73  -  105  :  0.006934745146249656  - 0.128607 s
# 73  -  106  :  0.00524210055914829  - 0.122715 s
# 74  -  105  :  0.007488198670583073  - 0.127384 s
# 74  -  106  :  0.00711800888828639  - 0.127481 s
# 75  -  105  :  0.007969672885820312  - 0.137907 s
# 75  -  106  :  0.0012491098842360468  - 0.161356 s
# 76  -  105  :  0.0013578649013251788  - 0.122133 s
# 76  -  106  :  0.0204388469934922  - 0.124013 s
# 77  -  105  :  0.0023977341227822534  - 0.134278 s
# 77  -  106  :  0.005109560919035186  - 0.126602 s
# 78  -  105  :  0.004437789357922068  - 0.133999 s
# 78  -  106  :  0.010174211592358406  - 0.128751 s
# 79  -  105  :  0.00539449833513903  - 0.140662 s
# 79  -  106  :  0.0005523878390937207  - 0.123136 s
# 80  -  105  :  0.006062360175632879  - 0.130222 s
# 80  -  106  :  0.003398820212372051  - 0.127100 s
# 81  -  105  :  0.00026938097844712714  - 0.127163 s
# 81  -  106  :  0.003472791558210515  - 0.128892 s
# 82  -  105  :  0.00015324814793473898  - 0.128304 s
# 82  -  106  :  0.0009565739545924853  - 0.124865 s
# 83  -  105  :  0.0021285677907330143  - 0.126629 s
# 83  -  106  :  0.00399196463976898  - 0.150549 s
# 84  -  105  :  0.004406153097810593  - 0.123217 s
# 84  -  106  :  0.008240007872380257  - 0.123898 s
# 85  -  105  :  0.005830986407436294  - 0.133595 s
# 85  -  106  :  0.0029051396388942077  - 0.120390 s
# 86  -  105  :  0.0030855618770036126  - 0.127139 s
# 86  -  106  :  0.0003336227859773594  - 0.122743 s
# 87  -  105  :  0.022372378002843776  - 0.126164 s
# 87  -  106  :  0.01926107391719058  - 0.123049 s
# 88  -  105  :  0.004811307414915875  - 0.128472 s
# 88  -  106  :  0.0008867965208102466  - 0.126843 s
# 89  -  105  :  0.00651355844559422  - 0.126712 s
# 89  -  106  :  0.00033362278592103127  - 0.127234 s
# 90  -  105  :  0.0067892025522114366  - 0.121960 s
# 90  -  106  :  0.003634625834271312  - 0.123683 s
# 91  -  105  :  0.003235611430640306  - 0.126057 s
# 91  -  106  :  0.0002716860894988931  - 0.122325 s
# 92  -  105  :  0.002094168707203607  - 0.158528 s
# 92  -  106  :  0.002449833902766303  - 0.135115 s
# 93  -  105  :  0.005093971943811193  - 0.132657 s
# 93  -  106  :  0.008205217479307612  - 0.160145 s
# 94  -  105  :  0.00752773018395193  - 0.160952 s
# 94  -  106  :  0.0006384036654213764  - 0.163920 s
# 95  -  105  :  0.002636343970058529  - 0.124044 s
# 95  -  106  :  0.00459153232539589  - 0.168121 s
# 96  -  105  :  0.0038370499508020763  - 0.149355 s
# 96  -  106  :  0.005258342895226798  - 0.130109 s
# 97  -  105  :  0.0012854860267548385  - 0.120008 s
# 97  -  106  :  0.0025628330780511823  - 0.154772 s
# 98  -  105  :  0.004437789357832047  - 0.128790 s
# 98  -  106  :  0.001572774632106336  - 0.152052 s
# 99  -  105  :  0.0038935245562601085  - 0.128300 s
# 99  -  106  :  0.0030480585679970094  - 0.122856 s
# 100  -  105  :  0.015906713177352674  - 0.130625 s
# 100  -  106  :  0.010256920990107513  - 0.166667 s
# 101  -  105  :  0.0033620403212503295  - 0.135670 s
# 101  -  106  :  4.1881736121767547e-05  - 0.122364 s
# 102  -  105  :  0.007198427831594255  - 0.124269 s
# 102  -  106  :  0.004805303390175575  - 0.159451 s
# 103  -  105  :  0.0026248358150700707  - 0.125255 s
# 103  -  106  :  0.007536076585824639  - 0.128375 s
# 104  -  105  :  0.26591953665749657  - 0.141598 s
# 104  -  106  :  0.1359691533401043  - 0.125340 s
# 105  -  106  :  0.06643549422521465  - 0.120055 s
# 105  -  107  :  0.03219863266144845  - 0.135602 s
# 105  -  108  :  0.037830764725325323  - 0.135031 s
# 105  -  109  :  0.6751417226980968  - 0.121880 s
# 105  -  110  :  0.04568341482361759  - 0.125039 s
# 105  -  111  :  0.01863647406067479  - 0.129422 s
# 106  -  107  :  0.008998563642378547  - 0.141241 s
# 106  -  108  :  0.016270393940164826  - 0.149607 s
# 106  -  109  :  0.04494188276033365  - 0.132074 s
# 106  -  110  :  0.687635658654685  - 0.156510 s
# 106  -  111  :  0.01500425179244071  - 0.130974 s

# %%
import time
import pandas as pd
from scipy.stats import chi2_contingency

chi2_matrix2 = clearData(torch.load('chi2_matrix_full.pt'))
theils_u_matrix2 = clearData(torch.load('theils_u_matrix_full.pt'))
cramers_v_matrix2 = clearData(torch.load('cramers_v_matrix_full.pt'))


torch.save(chi2_matrix2, 'chi2_matrix_fullv3.pt')
# !cp 'chi2_matrix_fullv3.pt' /content/drive/MyDrive

torch.save(theils_u_matrix2, 'theils_u_matrix_fullv3.pt')
# !cp 'theils_u_matrix_fullv3.pt' /content/drive/MyDrive

torch.save(cramers_v_matrix2, 'cramers_v_matrix_fullv3.pt')
# !cp 'cramers_v_matrix_fullv3.pt' /content/drive/MyDrive

# %%
pip install minepy
# Out:
# Collecting minepy
#   Downloading minepy-1.2.6.tar.gz (496 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 497.0/497.0 kB 8.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from minepy) (1.25.2)
# Building wheels for collected packages: minepy
#   Building wheel for minepy (setup.py) ... done
#   Created wheel for minepy: filename=minepy-1.2.6-cp310-cp310-linux_x86_64.whl size=187095 sha256=7ac6c38d1725ea1a0ed10833bc63164a4db5fb5c4177736a768f1b886db4cc46
#   Stored in directory: /root/.cache/pip/wheels/69/38/a6/825bb9b9ed81e6af43a0ef80c7cfe4cafcfdbc2f5cde2959d9
# Successfully built minepy
# Installing collected packages: minepy
# Successfully installed minepy-1.2.6

# %%
import minepy
from scipy.stats import spearmanr
import torch
import time
def calculate_mic(X_col_i, X_col_j):
    mic_instance = minepy.MINE()
    mic_instance.compute_score(X_col_i, X_col_j)
    return mic_instance.mic()

def calculate_spearman(X_col_i, X_col_j):
    return spearmanr(X_col_i, X_col_j)[0]


mic_matrix = clearData(torch.load('maximal_coefficient_matrix_full.pt'))
spearman_matrix = clearData(torch.load('spearmans_rank_matrix_full.pt'))

for i in range(X_encoded.shape[1]):
    X_col_i = X_encoded[:, i]
    for j in range(i + 1, X_encoded.shape[1]):
        if not ((i>=105 and i<107) or (j>=105 and j<107)):
          continue
        X_col_j = X_encoded[:, j]
        # MIC
        start_time = time.time()
        mic_value = calculate_mic(X_col_i, X_col_j)
        mic_matrix[i, j] = mic_value
        mic_matrix[j, i] = mic_value
        spearman_value = calculate_spearman(X_col_i, X_col_j)
        spearman_matrix[i, j] = spearman_value
        spearman_matrix[j, i] = spearman_value  # Symmetric
        end_time = time.time()
        processed = end_time-start_time
        print(i, "-", j, ": MIC:", mic_value, " Spr: ",spearman_value, f"- {processed:4f} s")


torch.save(mic_matrix, 'maximal_coefficient_matrix_fullv3.pt')
# !cp 'maximal_coefficient_matrix_fullv3.pt' /content/drive/MyDrive

torch.save(spearman_matrix, 'spearmans_rank_matrix_fullv3.pt')
# !cp 'spearmans_rank_matrix_fullv3.pt' /content/drive/MyDrive


pearsons_correlation_coefficient_matrix = torch.from_numpy(np.corrcoef(X_encoded.T)).float()
torch.save(pearsons_correlation_coefficient_matrix, 'pearsons_correlation_coefficient_matrix_fullv3.pt')
# !cp 'pearsons_correlation_coefficient_matrix_fullv3.pt' /content/drive/MyDrive
# Out:
# 0 - 105 : MIC: 9.623971703977778e-05  Spr:  -0.011213355182429503 - 3.329754 s
# 0 - 106 : MIC: 0.00016203395419357882  Spr:  -0.014170189919862757 - 3.379069 s
# 1 - 105 : MIC: 0.00013916323471166496  Spr:  0.014414836111962658 - 3.323823 s
# 1 - 106 : MIC: 7.236774707080304e-05  Spr:  0.010405349416486765 - 3.483836 s
# 2 - 105 : MIC: 3.706109308212788e-05  Spr:  0.007258870393958812 - 3.516222 s
# 2 - 106 : MIC: 8.684969565491538e-05  Spr:  0.011271651820968674 - 3.291816 s
# 3 - 105 : MIC: 2.5472225454523112e-05  Spr:  -0.004294341519496433 - 3.382299 s
# 3 - 106 : MIC: 1.4135059760521168e-05  Spr:  -0.0031681014353235094 - 3.511914 s
# 4 - 105 : MIC: 0.0008938486141713293  Spr:  -0.03568677193676292 - 2.672731 s
# 4 - 106 : MIC: 0.00037153602516418297  Spr:  -0.022984396108958003 - 2.789333 s
# 5 - 105 : MIC: 0.002439893843461072  Spr:  0.06581464568081996 - 3.292227 s
# 5 - 106 : MIC: 0.0006017351905059751  Spr:  0.03170023667575518 - 3.387356 s
# 6 - 105 : MIC: 0.0002463767293445326  Spr:  0.01900204726932067 - 3.139169 s
# 6 - 106 : MIC: 0.00012433397804001932  Spr:  0.013503020321830794 - 3.247625 s
# 7 - 105 : MIC: 7.805210321442717e-06  Spr:  -0.0032637579341698456 - 3.263164 s
# 7 - 106 : MIC: 3.677605829851037e-06  Spr:  -0.0022408225852505476 - 3.482413 s
# 8 - 105 : MIC: 6.244353590212787e-07  Spr:  0.0009511051755765044 - 3.387961 s
# 8 - 106 : MIC: 5.5711004556992675e-09  Spr:  8.814760943220913e-05 - 3.557333 s
# 9 - 105 : MIC: 0.00019047806607762287  Spr:  -0.015276365324515007 - 3.360914 s
# 9 - 106 : MIC: 1.4153898502856892e-06  Spr:  -0.0013910110507546587 - 3.476048 s
# 10 - 105 : MIC: 0.0006737489994558752  Spr:  -0.027628168132719524 - 3.289402 s
# 10 - 106 : MIC: 0.0001600245958143622  Spr:  -0.013947265979108217 - 3.394726 s
# 11 - 105 : MIC: 0.0006611143056777846  Spr:  -0.027817811712473946 - 3.273039 s
# 11 - 106 : MIC: 0.0002175212219960797  Spr:  -0.016250964948351154 - 3.372518 s
# 12 - 105 : MIC: 0.00026978935113397567  Spr:  -0.017609863725046707 - 3.335309 s
# 12 - 106 : MIC: 0.0002600615664986918  Spr:  -0.01658737133304733 - 3.446909 s
# 13 - 105 : MIC: 0.0001556362271720122  Spr:  -0.013006739146269916 - 3.366081 s
# 13 - 106 : MIC: 4.9847559819735774e-05  Spr:  -0.0075774386074223855 - 3.461848 s
# 14 - 105 : MIC: 0.00016557717552134163  Spr:  -0.013951377912745828 - 3.334224 s
# 14 - 106 : MIC: 4.479497852159114e-05  Spr:  -0.007433852623677134 - 3.441259 s
# 15 - 105 : MIC: 4.250027933013743e-05  Spr:  -0.007463962444809856 - 3.326046 s
# 15 - 106 : MIC: 8.498336427840622e-05  Spr:  -0.010243628425755723 - 3.413987 s
# 16 - 105 : MIC: 9.84791244225019e-05  Spr:  -0.01111881254388178 - 3.324263 s
# 16 - 106 : MIC: 0.00020661597069909806  Spr:  -0.01518478437792285 - 3.423181 s
# 17 - 105 : MIC: 1.1029817987894876e-05  Spr:  -0.003869358055794411 - 3.272457 s
# 17 - 106 : MIC: 5.666692177510753e-06  Spr:  0.0028320802503775566 - 3.369091 s
# 18 - 105 : MIC: 7.782614028033109e-05  Spr:  0.010629678765035034 - 3.278885 s
# 18 - 106 : MIC: 4.135059384838024e-05  Spr:  -0.007380445022565676 - 3.342430 s
# 19 - 105 : MIC: 0.001958974671187773  Spr:  0.054396373555359416 - 3.031363 s
# 19 - 106 : MIC: 0.0010989844103275513  Spr:  0.0408568180202508 - 3.012046 s
# 20 - 105 : MIC: 0.0011456872400204042  Spr:  0.04609063282856267 - 3.333177 s
# 20 - 106 : MIC: 0.0006656909859731338  Spr:  0.03562301357555718 - 3.436572 s
# 21 - 105 : MIC: 0.001433193986057409  Spr:  -0.04372554156627592 - 2.689710 s
# 21 - 106 : MIC: 0.0007106443316890103  Spr:  -0.030796102720363892 - 2.740243 s
# 22 - 105 : MIC: 0.0022539160803275705  Spr:  0.06148163530911886 - 3.204465 s
# 22 - 106 : MIC: 0.0010872221695923177  Spr:  0.04271416687951793 - 3.303938 s
# 23 - 105 : MIC: 2.2304147840750325e-05  Spr:  -0.005158557041665305 - 3.369324 s
# 23 - 106 : MIC: 1.7030024527115644e-05  Spr:  -0.004423263064099841 - 3.471580 s
# 24 - 105 : MIC: 0.0038176900744214906  Spr:  0.08903731730132307 - 3.313296 s
# 24 - 106 : MIC: 0.0008981533764739671  Spr:  0.04121152291343116 - 3.424210 s
# 25 - 105 : MIC: 0.000969374313114835  Spr:  -0.03568996644456898 - 2.792553 s
# 25 - 106 : MIC: 0.0001886383567051968  Spr:  -0.015912030878296252 - 2.901254 s
# 26 - 105 : MIC: 0.00046799511128887115  Spr:  -0.024742734219792784 - 2.977203 s
# 26 - 106 : MIC: 0.0001767041989320024  Spr:  -0.015265865636520274 - 3.094749 s
# 27 - 105 : MIC: 1.7036972675435315e-08  Spr:  -0.00015324814702585068 - 3.410919 s
# 27 - 106 : MIC: 6.296082175614029e-07  Spr:  0.0009565739546162081 - 3.515698 s
# 28 - 105 : MIC: 0.011246651548989187  Spr:  0.12451657763837308 - 2.537799 s
# 28 - 106 : MIC: 0.0036493244775517224  Spr:  0.07114846236924727 - 2.646210 s
# 29 - 105 : MIC: 0.00012716569855349908  Spr:  -0.012464107484686113 - 3.344081 s
# 29 - 106 : MIC: 3.142048153000146e-05  Spr:  -0.006321871500775599 - 3.429805 s
# 30 - 105 : MIC: 0.00861149892167859  Spr:  -0.10351719374695699 - 2.624213 s
# 30 - 106 : MIC: 0.0023182605645230307  Spr:  -0.05467962858131712 - 2.729553 s
# 31 - 105 : MIC: 0.00026460140167331315  Spr:  -0.018101588921896897 - 3.281715 s
# 31 - 106 : MIC: 0.00020962097907107914  Spr:  -0.015863928767494973 - 3.377537 s
# 32 - 105 : MIC: 2.6002690534327426e-06  Spr:  -0.001888721017329825 - 3.276135 s
# 32 - 106 : MIC: 2.828424628418846e-05  Spr:  -0.006107157123380935 - 3.379762 s
# 33 - 105 : MIC: 9.989775620696064e-05  Spr:  -0.011418577662952312 - 3.259452 s
# 33 - 106 : MIC: 0.0001654320602448991  Spr:  -0.014310818029310625 - 3.360200 s
# 34 - 105 : MIC: 0.0006155109693758467  Spr:  -0.028114105441277792 - 3.037114 s
# 34 - 106 : MIC: 0.0003257143453163693  Spr:  -0.0204317982714148 - 3.182034 s
# 35 - 105 : MIC: 7.918760767526837e-07  Spr:  -0.0010152757738184357 - 3.422505 s
# 35 - 106 : MIC: 1.7572645323744944e-06  Spr:  0.0016564171081817757 - 3.503422 s
# 36 - 105 : MIC: 2.6812203347420005e-05  Spr:  -0.006053681140468923 - 3.035630 s
# 36 - 106 : MIC: 2.176500169779698e-05  Spr:  -0.005443456017706404 - 3.165450 s
# 37 - 105 : MIC: 0.003031426331752945  Spr:  0.06917944569041132 - 3.233071 s
# 37 - 106 : MIC: 0.0014301609815632172  Spr:  0.04748306257914149 - 3.121928 s
# 38 - 105 : MIC: 5.731933618383947e-05  Spr:  -0.008689597756148363 - 3.279282 s
# 38 - 106 : MIC: 0.00014422663424602634  Spr:  -0.013322060965761637 - 3.390349 s
# 39 - 105 : MIC: 0.0007457547609215677  Spr:  -0.029584082662060352 - 3.330106 s
# 39 - 106 : MIC: 0.0003416858921005709  Spr:  -0.020123874271605204 - 3.345832 s
# 40 - 105 : MIC: 0.00026354694971106096  Spr:  -0.01841572295884138 - 3.179423 s
# 40 - 106 : MIC: 0.00016663541486816084  Spr:  -0.01457446351091523 - 3.329041 s
# 41 - 105 : MIC: 0.002919814097602164  Spr:  -0.05748625969492887 - 3.118379 s
# 41 - 106 : MIC: 0.0012518758634233883  Spr:  -0.038029198350788114 - 3.212206 s
# 42 - 105 : MIC: 9.747131707918935e-05  Spr:  -0.010583852928925355 - 3.383106 s
# 42 - 106 : MIC: 6.857391549230502e-05  Spr:  -0.00871381894521401 - 3.496471 s
# 43 - 105 : MIC: 0.0032822022454015503  Spr:  0.07209902963387012 - 3.076033 s
# 43 - 106 : MIC: 0.0011766768664463443  Spr:  0.04281357967132751 - 3.113564 s
# 44 - 105 : MIC: 1.4064752167389723e-05  Spr:  -0.00434735425139094 - 3.311341 s
# 44 - 106 : MIC: 2.982257810776914e-07  Spr:  -0.0006409567025951412 - 3.432729 s
# 45 - 105 : MIC: 9.254342240056302e-06  Spr:  0.0035975794022697887 - 3.056822 s
# 45 - 106 : MIC: 5.482124495119398e-05  Spr:  0.008848621749008913 - 3.159636 s
# 46 - 105 : MIC: 1.235697078199224e-05  Spr:  0.004186428490517901 - 3.282048 s
# 46 - 106 : MIC: 3.467289287828304e-05  Spr:  0.007120162248778968 - 3.449118 s
# 47 - 105 : MIC: 0.00013018329574020335  Spr:  -0.013037613736344319 - 3.220701 s
# 47 - 106 : MIC: 7.457595531008604e-06  Spr:  -0.003183864184691477 - 3.319242 s
# 48 - 105 : MIC: 0.00019336271038849947  Spr:  -0.015385483753835505 - 3.346846 s
# 48 - 106 : MIC: 1.618042381350016e-06  Spr:  -0.0014865548130626554 - 3.504600 s
# 49 - 105 : MIC: 0.008805527266628106  Spr:  0.11174592571301561 - 2.568936 s
# 49 - 106 : MIC: 0.003146646017554224  Spr:  0.06679964896814022 - 2.729165 s
# 50 - 105 : MIC: 0.0009294851073507978  Spr:  -0.03512110134364698 - 2.730880 s
# 50 - 106 : MIC: 0.00017805561407400705  Spr:  -0.015507114826137272 - 2.840658 s
# 51 - 105 : MIC: 0.0007435192462877522  Spr:  -0.029003559918579003 - 3.279688 s
# 51 - 106 : MIC: 0.00026352141655825356  Spr:  -0.01760130242436478 - 3.376421 s
# 52 - 105 : MIC: 0.006191451266076576  Spr:  -0.08282945510724289 - 2.951770 s
# 52 - 106 : MIC: 0.0018687149398383483  Spr:  -0.04693862857557806 - 3.045276 s
# 53 - 105 : MIC: 0.0011991602967436205  Spr:  -0.038438231778611276 - 3.192682 s
# 53 - 106 : MIC: 0.0007518565443454946  Spr:  -0.030215935096275317 - 3.166601 s
# 54 - 105 : MIC: 0.0007502147809329298  Spr:  0.03433759889411487 - 3.222268 s
# 54 - 106 : MIC: 0.00015942205630519287  Spr:  0.015513780768693067 - 3.329053 s
# 55 - 105 : MIC: 2.0653067662006728e-05  Spr:  -0.005201911956275187 - 3.358424 s
# 55 - 106 : MIC: 0.00012655960013959323  Spr:  -0.011884798409600468 - 3.444836 s
# 56 - 105 : MIC: 3.009850354785491e-07  Spr:  0.000647089230521762 - 3.273480 s
# 56 - 106 : MIC: 7.985220063540062e-06  Spr:  0.0033695397045691903 - 3.458322 s
# 57 - 105 : MIC: 0.000619284271915248  Spr:  -0.02804380961094151 - 3.133580 s
# 57 - 106 : MIC: 0.00029561702080133166  Spr:  -0.019401617836008498 - 3.187097 s
# 58 - 105 : MIC: 7.260857320705147e-05  Spr:  -0.009453560184417393 - 3.342947 s
# 58 - 106 : MIC: 1.3930995412082736e-05  Spr:  -0.004241126545078365 - 3.472689 s
# 59 - 105 : MIC: 0.0005594277592142529  Spr:  0.02701904201009674 - 2.965909 s
# 59 - 106 : MIC: 0.00027516303511088635  Spr:  0.01895666829930075 - 3.061224 s
# 60 - 105 : MIC: 0.003042368988427065  Spr:  0.06314134476373902 - 2.643266 s
# 60 - 106 : MIC: 0.0013227993287334865  Spr:  0.04173627991590686 - 2.739105 s
# 61 - 105 : MIC: 1.1129068330222577e-05  Spr:  0.003996894744970345 - 3.344789 s
# 61 - 106 : MIC: 4.033696024680073e-05  Spr:  0.007826374646976735 - 3.438519 s
# 62 - 105 : MIC: 3.0270065546632643e-06  Spr:  0.0021340020163050314 - 3.376464 s
# 62 - 106 : MIC: 2.521066890538422e-05  Spr:  0.006856811852687344 - 3.482157 s
# 63 - 105 : MIC: 9.807487017508364e-07  Spr:  0.0011771258545038433 - 3.373699 s
# 63 - 106 : MIC: 1.9937393078985823e-05  Spr:  0.00556738118064901 - 3.468413 s
# 64 - 105 : MIC: 1.9275469133780926e-06  Spr:  -0.0016073720966239655 - 3.369700 s
# 64 - 106 : MIC: 6.0870376789411864e-05  Spr:  0.010300628644219477 - 3.508321 s
# 65 - 105 : MIC: 4.6520865561620914e-05  Spr:  -0.007176739268111664 - 3.363938 s
# 65 - 106 : MIC: 4.0139720263318065e-06  Spr:  -0.002260940017021562 - 3.506827 s
# 66 - 105 : MIC: 1.8126040035105587e-05  Spr:  -0.004764719980458638 - 3.358987 s
# 66 - 106 : MIC: 5.455062837523621e-06  Spr:  -0.0026458797621405697 - 3.470259 s
# 67 - 105 : MIC: 4.721475773375465e-05  Spr:  -0.007310358241943884 - 3.369600 s
# 67 - 106 : MIC: 3.243292709255036e-05  Spr:  -0.005947649676869373 - 3.470112 s
# 68 - 105 : MIC: 2.3769995262571177e-06  Spr:  -0.0017590496994973805 - 3.369232 s
# 68 - 106 : MIC: 6.36311290466523e-05  Spr:  -0.006722967777530807 - 3.472212 s
# 69 - 105 : MIC: 2.0202313647732997e-05  Spr:  -0.005031395943284414 - 3.372524 s
# 69 - 106 : MIC: 4.910873782891887e-05  Spr:  -0.007316772488911637 - 3.461687 s
# 70 - 105 : MIC: 1.7287895333247722e-05  Spr:  0.005123166253404585 - 3.369205 s
# 70 - 106 : MIC: 2.8210586563118504e-06  Spr:  0.0020312971340699583 - 3.467504 s
# 71 - 105 : MIC: 1.0096694265083092e-07  Spr:  -0.0003715780867917175 - 3.365700 s
# 71 - 106 : MIC: 6.196208923984433e-06  Spr:  -0.002698095772322369 - 3.482002 s
# 72 - 105 : MIC: 5.3539629652170494e-05  Spr:  0.009159655927182583 - 3.373230 s
# 72 - 106 : MIC: 1.2252617648409733e-05  Spr:  -0.003929202474885728 - 3.466438 s
# 73 - 105 : MIC: 2.900839213268665e-05  Spr:  0.006934745146237646 - 3.371704 s
# 73 - 106 : MIC: 1.63586603941983e-05  Spr:  0.005242100559145713 - 3.487491 s
# 74 - 105 : MIC: 5.10417279899866e-05  Spr:  -0.007488198670057839 - 3.378728 s
# 74 - 106 : MIC: 5.189763267566694e-05  Spr:  -0.0071180088877967115 - 3.508130 s
# 75 - 105 : MIC: 6.091589080535159e-05  Spr:  -0.00796967288592573 - 3.368953 s
# 75 - 106 : MIC: 1.180802520576157e-06  Spr:  -0.0012491098842871667 - 3.481593 s
# 76 - 105 : MIC: 2.5469774330588155e-06  Spr:  -0.0013578649000899493 - 3.377032 s
# 76 - 106 : MIC: 9.049696902514098e-05  Spr:  0.020438846973706123 - 3.470073 s
# 77 - 105 : MIC: 4.774378370036323e-06  Spr:  -0.002397734122201855 - 3.375364 s
# 77 - 106 : MIC: 1.438372601264648e-05  Spr:  0.005109560917775784 - 3.493114 s
# 78 - 105 : MIC: 1.8021066685731013e-05  Spr:  -0.004437789358128928 - 3.374349 s
# 78 - 106 : MIC: 5.079181313687824e-05  Spr:  0.010174211592827097 - 3.484789 s
# 79 - 105 : MIC: 1.6941955610339844e-05  Spr:  0.005394498335247744 - 3.372852 s
# 79 - 106 : MIC: 2.1180501429989348e-07  Spr:  0.0005523878390325672 - 3.495737 s
# 80 - 105 : MIC: 2.4041779773600625e-05  Spr:  0.006062360175742124 - 3.371867 s
# 80 - 106 : MIC: 7.693303585046449e-06  Spr:  0.003398820212434179 - 3.464176 s
# 81 - 105 : MIC: 5.194130050170346e-08  Spr:  0.0002693809784285341 - 3.369508 s
# 81 - 106 : MIC: 7.67947839795351e-06  Spr:  0.003472791558526196 - 3.475282 s
# 82 - 105 : MIC: 1.7036972675435315e-08  Spr:  -0.00015324814702585068 - 3.369980 s
# 82 - 106 : MIC: 6.296082175614029e-07  Spr:  0.0009565739546162081 - 3.476435 s
# 83 - 105 : MIC: 3.127800781849978e-06  Spr:  0.002128567790762543 - 3.375554 s
# 83 - 106 : MIC: 1.3270112156317868e-05  Spr:  -0.003991964639901382 - 3.495777 s
# 84 - 105 : MIC: 1.56016199861115e-05  Spr:  -0.0044061530980140685 - 3.364902 s
# 84 - 106 : MIC: 7.185270005910941e-05  Spr:  -0.008240007872796329 - 3.468260 s
# 85 - 105 : MIC: 2.1798927808991454e-05  Spr:  0.0058309864075970575 - 3.383690 s
# 85 - 106 : MIC: 6.778104089805849e-06  Spr:  -0.002905139638946826 - 3.477138 s
# 86 - 105 : MIC: 8.189046015480135e-06  Spr:  -0.0030855618762211713 - 3.373475 s
# 86 - 106 : MIC: 8.211933348519275e-08  Spr:  -0.0003336227860974773 - 3.486453 s
# 87 - 105 : MIC: 0.0004405847219699472  Spr:  -0.022372378002801684 - 3.316863 s
# 87 - 106 : MIC: 0.00034519280476780364  Spr:  -0.019261073917187177 - 3.415353 s
# 88 - 105 : MIC: 2.0215957899127903e-05  Spr:  -0.004811307414556198 - 3.371239 s
# 88 - 106 : MIC: 5.915386492815356e-07  Spr:  -0.0008867965206818131 - 3.476574 s
# 89 - 105 : MIC: 5.859426429674188e-05  Spr:  -0.0065135584451176155 - 3.372706 s
# 89 - 106 : MIC: 8.211933348519275e-08  Spr:  -0.0003336227860974773 - 3.472382 s
# 90 - 105 : MIC: 4.599456571334838e-05  Spr:  -0.006789202552917371 - 3.365659 s
# 90 - 106 : MIC: 1.1795874162282237e-05  Spr:  -0.0036346258346862353 - 3.486039 s
# 91 - 105 : MIC: 7.890807593349854e-06  Spr:  -0.0032356114306005897 - 3.354275 s
# 91 - 106 : MIC: 5.2983023777560525e-08  Spr:  0.0002716860893377121 - 3.461928 s
# 92 - 105 : MIC: 3.336390307311236e-06  Spr:  -0.0020941687072066006 - 3.372468 s
# 92 - 106 : MIC: 4.744290424740842e-06  Spr:  -0.0024498339028193885 - 3.525960 s
# 93 - 105 : MIC: 2.2154943952496946e-05  Spr:  -0.005093971944026439 - 3.375147 s
# 93 - 106 : MIC: 9.476156057475274e-05  Spr:  -0.008205217479674908 - 3.472941 s
# 94 - 105 : MIC: 4.730349922119135e-05  Spr:  -0.007527730183684706 - 3.369150 s
# 94 - 106 : MIC: 2.897377174199507e-07  Spr:  0.0006384036652294053 - 3.473346 s
# 95 - 105 : MIC: 5.844269952245598e-06  Spr:  -0.002636343969956558 - 3.371509 s
# 95 - 106 : MIC: 2.968705049997264e-05  Spr:  -0.0045915323252286155 - 3.483877 s
# 96 - 105 : MIC: 1.1600080752836324e-05  Spr:  -0.003837049950778799 - 3.375057 s
# 96 - 106 : MIC: 1.74493131930231e-05  Spr:  0.005258342895198185 - 3.472679 s
# 97 - 105 : MIC: 1.151982135951212e-06  Spr:  0.0012854860266701437 - 3.374998 s
# 97 - 106 : MIC: 4.325958163163934e-06  Spr:  0.002562833077934568 - 3.475665 s
# 98 - 105 : MIC: 1.8021066685731013e-05  Spr:  -0.004437789358128928 - 3.380490 s
# 98 - 106 : MIC: 1.974559964279968e-06  Spr:  -0.0015727746322381725 - 3.473094 s
# 99 - 105 : MIC: 1.3545692715158362e-05  Spr:  -0.0038935245553981266 - 3.374332 s
# 99 - 106 : MIC: 5.730862716672253e-06  Spr:  0.0030480585673023424 - 3.490883 s
# 100 - 105 : MIC: 0.00019088729656861585  Spr:  0.01590671317730336 - 3.080146 s
# 100 - 106 : MIC: 7.903073746880666e-05  Spr:  0.010256920990086616 - 3.175084 s
# 101 - 105 : MIC: 7.571623999125322e-06  Spr:  0.003362040320998889 - 3.370143 s
# 101 - 106 : MIC: 1.2671095473734526e-09  Spr:  -4.188173835641067e-05 - 3.508605 s
# 102 - 105 : MIC: 2.9135766197334702e-05  Spr:  0.007198427830468165 - 3.375921 s
# 102 - 106 : MIC: 3.251507080202901e-05  Spr:  -0.004805303389438034 - 3.476671 s
# 103 - 105 : MIC: 5.15550300757277e-06  Spr:  -0.002624835815098354 - 3.362059 s
# 103 - 106 : MIC: 4.867368243144799e-05  Spr:  -0.007536076585788186 - 3.483523 s
# 104 - 105 : MIC: 0.042762803450379194  Spr:  0.2659195366570294 - 2.761214 s
# 104 - 106 : MIC: 0.011427994810784667  Spr:  0.13596915334005194 - 2.868531 s
# 105 - 106 : MIC: 0.00595873555654373  Spr:  -0.06643549422512904 - 3.224690 s
# 105 - 107 : MIC: 0.01714218249091512  Spr:  0.032975078086963906 - 2.096617 s
# 105 - 108 : MIC: 0.012546041066975546  Spr:  0.0438467146376978 - 2.040078 s
# 105 - 109 : MIC: 0.4113211210252679  Spr:  0.25463997209821776 - 3.109423 s
# 105 - 110 : MIC: 0.00595873555654405  Spr:  0.010011007898331856 - 3.226167 s
# 105 - 111 : MIC: 0.008100858391679436  Spr:  0.0018091792957024128 - 2.263552 s
# 106 - 107 : MIC: 0.006899828726254453  Spr:  0.00779097169873289 - 2.191106 s
# 106 - 108 : MIC: 0.005343692271845282  Spr:  0.03735627979359543 - 2.152856 s
# 106 - 109 : MIC: 0.005966456085985443  Spr:  -0.016829645132545503 - 3.220037 s
# 106 - 110 : MIC: 0.2723059391004988  Spr:  -0.15068764092290324 - 3.327817 s
# 106 - 111 : MIC: 0.004832890725127474  Spr:  0.009329156708338707 - 2.359888 s

# %%
import numpy as np
from sklearn.gaussian_process.kernels import RBF
from sklearn.preprocessing import OneHotEncoder

import torch
import torch.nn as nn
from google.colab import drive
drive.mount('/content/drive')

#https://github.com/clovaai/rebias/tree/master
def to_numpy(x):
    """convert Pytorch tensor to numpy array
    """
    return x.clone().detach().cpu().numpy()


class HSIC(nn.Module):
    """Base class for the finite sample estimator of Hilbert-Schmidt Independence Criterion (HSIC)
    ..math:: HSIC (X, Y) := || C_{x, y} ||^2_{HS}, where HSIC (X, Y) = 0 iif X and Y are independent.

    Empirically, we use the finite sample estimator of HSIC (with m observations) by,
    (1) biased estimator (HSIC_0)
        Gretton, Arthur, et al. "Measuring statistical dependence with Hilbert-Schmidt norms." 2005.
        :math: (m - 1)^2 tr KHLH.
        where K_{ij} = kernel_x (x_i, x_j), L_{ij} = kernel_y (y_i, y_j), H = 1 - m^{-1} 1 1 (Hence, K, L, H are m by m matrices).
    (2) unbiased estimator (HSIC_1)
        Song, Le, et al. "Feature selection via dependence maximization." 2012.
        :math: \frac{1}{m (m - 3)} \bigg[ tr (\tilde K \tilde L) + \frac{1^\top \tilde K 1 1^\top \tilde L 1}{(m-1)(m-2)} - \frac{2}{m-2} 1^\top \tilde K \tilde L 1 \bigg].
        where \tilde K and \tilde L are related to K and L by the diagonal entries of \tilde K_{ij} and \tilde L_{ij} are set to zero.

    Parameters
    ----------
    sigma_x : float
        the kernel size of the kernel function for X.
    sigma_y : float
        the kernel size of the kernel function for Y.
    algorithm: str ('unbiased' / 'biased')
        the algorithm for the finite sample estimator. 'unbiased' is used for our paper.
    reduction: not used (for compatibility with other losses).
    """
    def __init__(self, sigma_x, sigma_y=None, algorithm='unbiased',
                 reduction=None):
        super(HSIC, self).__init__()

        if sigma_y is None:
            sigma_y = sigma_x

        self.sigma_x = sigma_x
        self.sigma_y = sigma_y

        if algorithm == 'biased':
            self.estimator = self.biased_estimator
        elif algorithm == 'unbiased':
            self.estimator = self.unbiased_estimator
        else:
            raise ValueError('invalid estimator: {}'.format(algorithm))

    def _kernel_x(self, X):
        raise NotImplementedError

    def _kernel_y(self, Y):
        raise NotImplementedError

    def biased_estimator(self, input1, input2):
        """Biased estimator of Hilbert-Schmidt Independence Criterion
        Gretton, Arthur, et al. "Measuring statistical dependence with Hilbert-Schmidt norms." 2005.
        """
        K = self._kernel_x(input1)
        L = self._kernel_y(input2)

        KH = K - K.mean(0, keepdim=True)
        LH = L - L.mean(0, keepdim=True)

        N = len(input1)

        return torch.trace(KH @ LH / (N - 1) ** 2)

    def unbiased_estimator(self, input1, input2):
        """Unbiased estimator of Hilbert-Schmidt Independence Criterion
        Song, Le, et al. "Feature selection via dependence maximization." 2012.
        """
        kernel_XX = self._kernel_x(input1)
        kernel_YY = self._kernel_y(input2)

        tK = kernel_XX - torch.diag(kernel_XX)
        tL = kernel_YY - torch.diag(kernel_YY)

        N = len(input1)

        hsic = (
            torch.trace(tK @ tL)
            + (torch.sum(tK) * torch.sum(tL) / (N - 1) / (N - 2))
            - (2 * torch.sum(tK, 0).dot(torch.sum(tL, 0)) / (N - 2))
        )

        return hsic / (N * (N - 3))

    def forward(self, input1, input2, **kwargs):
        return self.estimator(input1, input2)


class RbfHSIC(HSIC):
    """Radial Basis Function (RBF) kernel HSIC implementation.
    """
    def _kernel(self, X, sigma):
        X = X.view(len(X), -1)
        XX = X @ X.t()
        X_sqnorms = torch.diag(XX)
        X_L2 = -2 * XX + X_sqnorms.unsqueeze(1) + X_sqnorms.unsqueeze(0)
        gamma = 1 / (2 * sigma ** 2)

        kernel_XX = torch.exp(-gamma * X_L2)
        return kernel_XX

    def _kernel_x(self, X):
        return self._kernel(X, self.sigma_x)

    def _kernel_y(self, Y):
        return self._kernel(Y, self.sigma_y)



class LinearHSIC(HSIC):
    """Linear kernel HSIC implementation.
    """
    def _kernel(self, X):
        return X @ X.t()

    def _kernel_x(self, X):
        return self._kernel(X)

    def _kernel_y(self, Y):
        return self._kernel(Y)

class JaccardHSIC(HSIC):
    """Jaccard Kernel HSIC Implementation"""

    def _kernel(self, X, Y):
        # Ensure binary data (PyTorch equivalent)
        if not torch.is_tensor(X) or not torch.is_tensor(Y):
            X = torch.tensor(X)
            Y = torch.tensor(Y)

        if not X.dtype == torch.bool and not Y.dtype == torch.bool:
            X = (X > 0).type(torch.int)
            Y = (Y > 0).type(torch.int)

        # Reshape if necessary
        if len(X.shape) == 1:
          X = X.view(-1, 1)
        if len(Y.shape) == 1:
          Y = Y.view(-1, 1)

        intersection = (X & Y).sum(dim=1)
        union = (X | Y).sum(dim=1)

        # Handle potential zeros using torch-friendly methods
        kernel_matrix = intersection / union
        kernel_matrix[union == 0] = 0

        return kernel_matrix

    def _kernel_x(self, X):
        return self._kernel(X, X)

    def _kernel_y(self, Y):
        return self._kernel(Y, Y)


import time

# Initialize HSIC matrix (consider symmetry when deciding size)
#hsic_matrix = clearData(torch.load('rbf_hsic_matrix_full.pt'))
linear_hsic_matrix = clearData(torch.load('linear_hsic_matrix_full.pt'))
# Hyperparameter for RbfHSIC
sigma = 1.0

for i in range(X_encoded.shape[1]):
    X_col_i = X_encoded[:, i].reshape(-1, 1)

    for j in range(i + 1, X_encoded.shape[1]):
        if not ((i>=105 and i<107) or (j>=105 and j<107)):
          continue
        X_col_j = X_encoded[:, j].reshape(-1, 1)


        # Create HSIC estimator with torch (on the GPU)
       # hsic_estimator = RbfHSIC(sigma_x=sigma, sigma_y=sigma).cuda()
        linear_hsic_estimator = LinearHSIC(sigma_x=sigma, sigma_y=sigma).cuda()

         # Random Sampling
        sample_indices = np.random.choice(X_col_i.shape[0], size=28500, replace=False)
        X_col_i_sampled = X_col_i[sample_indices]
        X_col_j_sampled = X_col_j[sample_indices]

        # Convert data to PyTorch tensors (on the GPU)
        X_torch = X_col_i_sampled.cuda()
        Y_torch = X_col_j_sampled.cuda()

        # Compute HSIC on the GPU
        start_time = time.time()
       # hsic_value = hsic_estimator(X_torch, Y_torch)
       # hsic_matrix[i, j] = hsic_value
      #  hsic_matrix[j, i] = hsic_value
        hsic_value = linear_hsic_estimator(X_torch, Y_torch)
        linear_hsic_matrix[i, j] = hsic_value
        linear_hsic_matrix[j, i] = hsic_value

        end_time = time.time()
        processed = end_time-start_time
        print(i, " - ", j, " : ", hsic_value, f" - {processed:4f} s")

#torch.save(hsic_matrix, 'rbf_hsic_matrix_fullv3.pt')
#!cp 'rbf_hsic_matrix_fullv3.pt' /content/drive/MyDrive

torch.save(linear_hsic_matrix, 'linear_hsic_matrix_fullv3.pt')
# !cp 'linear_hsic_matrix_fullv3.pt' /content/drive/MyDrive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 0  -  105  :  tensor(0.0007, device='cuda:0', dtype=torch.float64)  - 2.585455 s
# 0  -  106  :  tensor(0.0010, device='cuda:0', dtype=torch.float64)  - 2.444153 s
# 1  -  105  :  tensor(-0.0013, device='cuda:0', dtype=torch.float64)  - 2.444841 s
# 1  -  106  :  tensor(-0.0008, device='cuda:0', dtype=torch.float64)  - 2.444113 s
# 2  -  105  :  tensor(-0.0011, device='cuda:0', dtype=torch.float64)  - 2.443949 s
# 2  -  106  :  tensor(-0.0013, device='cuda:0', dtype=torch.float64)  - 2.444057 s
# 3  -  105  :  tensor(2.8012e-05, device='cuda:0', dtype=torch.float64)  - 2.444344 s
# 3  -  106  :  tensor(2.8786e-05, device='cuda:0', dtype=torch.float64)  - 2.443995 s
# 4  -  105  :  tensor(0.0056, device='cuda:0', dtype=torch.float64)  - 2.568030 s
# 4  -  106  :  tensor(0.0029, device='cuda:0', dtype=torch.float64)  - 2.444065 s
# 5  -  105  :  tensor(-0.0061, device='cuda:0', dtype=torch.float64)  - 2.444026 s
# 5  -  106  :  tensor(-0.0025, device='cuda:0', dtype=torch.float64)  - 2.443983 s
# 6  -  105  :  tensor(-0.0024, device='cuda:0', dtype=torch.float64)  - 2.444239 s
# 6  -  106  :  tensor(-0.0015, device='cuda:0', dtype=torch.float64)  - 2.444134 s
# 7  -  105  :  tensor(0.0010, device='cuda:0', dtype=torch.float64)  - 2.444186 s
# 7  -  106  :  tensor(-0.0004, device='cuda:0', dtype=torch.float64)  - 2.444094 s
# 8  -  105  :  tensor(6.7763e-05, device='cuda:0', dtype=torch.float64)  - 2.444182 s
# 8  -  106  :  tensor(3.2101e-05, device='cuda:0', dtype=torch.float64)  - 2.443963 s
# 9  -  105  :  tensor(0.0012, device='cuda:0', dtype=torch.float64)  - 2.444112 s
# 9  -  106  :  tensor(-0.0002, device='cuda:0', dtype=torch.float64)  - 2.443960 s
# 10  -  105  :  tensor(0.0026, device='cuda:0', dtype=torch.float64)  - 2.443957 s
# 10  -  106  :  tensor(0.0007, device='cuda:0', dtype=torch.float64)  - 2.626192 s
# 11  -  105  :  tensor(0.0031, device='cuda:0', dtype=torch.float64)  - 2.443957 s
# 11  -  106  :  tensor(0.0019, device='cuda:0', dtype=torch.float64)  - 2.443829 s
# 12  -  105  :  tensor(0.0013, device='cuda:0', dtype=torch.float64)  - 2.443984 s
# 12  -  106  :  tensor(0.0007, device='cuda:0', dtype=torch.float64)  - 2.443974 s
# 13  -  105  :  tensor(0.0004, device='cuda:0', dtype=torch.float64)  - 2.443923 s
# 13  -  106  :  tensor(0.0002, device='cuda:0', dtype=torch.float64)  - 2.444998 s
# 14  -  105  :  tensor(0.0008, device='cuda:0', dtype=torch.float64)  - 2.444039 s
# 14  -  106  :  tensor(0.0003, device='cuda:0', dtype=torch.float64)  - 2.443984 s
# 15  -  105  :  tensor(0.0007, device='cuda:0', dtype=torch.float64)  - 2.443933 s
# 15  -  106  :  tensor(0.0005, device='cuda:0', dtype=torch.float64)  - 2.443915 s
# 16  -  105  :  tensor(0.0010, device='cuda:0', dtype=torch.float64)  - 2.443969 s
# 16  -  106  :  tensor(0.0007, device='cuda:0', dtype=torch.float64)  - 2.441411 s
# 17  -  105  :  tensor(0.0011, device='cuda:0', dtype=torch.float64)  - 2.441492 s
# 17  -  106  :  tensor(-1.7286e-05, device='cuda:0', dtype=torch.float64)  - 2.444061 s
# 18  -  105  :  tensor(-0.0011, device='cuda:0', dtype=torch.float64)  - 2.443953 s
# 18  -  106  :  tensor(0.0005, device='cuda:0', dtype=torch.float64)  - 2.443878 s
# 19  -  105  :  tensor(-0.0106, device='cuda:0', dtype=torch.float64)  - 2.444111 s
# 19  -  106  :  tensor(-0.0049, device='cuda:0', dtype=torch.float64)  - 2.510067 s
# 20  -  105  :  tensor(-0.0028, device='cuda:0', dtype=torch.float64)  - 2.443978 s
# 20  -  106  :  tensor(-0.0016, device='cuda:0', dtype=torch.float64)  - 2.443908 s
# 21  -  105  :  tensor(0.0093, device='cuda:0', dtype=torch.float64)  - 2.444066 s
# 21  -  106  :  tensor(0.0044, device='cuda:0', dtype=torch.float64)  - 2.443959 s
# 22  -  105  :  tensor(-0.0075, device='cuda:0', dtype=torch.float64)  - 2.443951 s
# 22  -  106  :  tensor(-0.0034, device='cuda:0', dtype=torch.float64)  - 2.444128 s
# 23  -  105  :  tensor(0.0001, device='cuda:0', dtype=torch.float64)  - 2.444179 s
# 23  -  106  :  tensor(1.3212e-05, device='cuda:0', dtype=torch.float64)  - 2.443866 s
# 24  -  105  :  tensor(-0.0063, device='cuda:0', dtype=torch.float64)  - 2.444110 s
# 24  -  106  :  tensor(-0.0017, device='cuda:0', dtype=torch.float64)  - 2.443801 s
# 25  -  105  :  tensor(0.0063, device='cuda:0', dtype=torch.float64)  - 2.444046 s
# 25  -  106  :  tensor(0.0027, device='cuda:0', dtype=torch.float64)  - 2.444053 s
# 26  -  105  :  tensor(0.0034, device='cuda:0', dtype=torch.float64)  - 2.444618 s
# 26  -  106  :  tensor(0.0028, device='cuda:0', dtype=torch.float64)  - 2.443866 s
# 27  -  105  :  tensor(0.0001, device='cuda:0', dtype=torch.float64)  - 2.443831 s
# 27  -  106  :  tensor(3.8086e-06, device='cuda:0', dtype=torch.float64)  - 2.449579 s
# 28  -  105  :  tensor(-0.0244, device='cuda:0', dtype=torch.float64)  - 2.443883 s
# 28  -  106  :  tensor(-0.0097, device='cuda:0', dtype=torch.float64)  - 2.443830 s
# 29  -  105  :  tensor(0.0010, device='cuda:0', dtype=torch.float64)  - 2.444302 s
# 29  -  106  :  tensor(0.0002, device='cuda:0', dtype=torch.float64)  - 2.443827 s
# 30  -  105  :  tensor(0.0221, device='cuda:0', dtype=torch.float64)  - 2.443876 s
# 30  -  106  :  tensor(0.0078, device='cuda:0', dtype=torch.float64)  - 2.443998 s
# 31  -  105  :  tensor(0.0015, device='cuda:0', dtype=torch.float64)  - 2.443882 s
# 31  -  106  :  tensor(0.0010, device='cuda:0', dtype=torch.float64)  - 2.444103 s
# 32  -  105  :  tensor(0.0007, device='cuda:0', dtype=torch.float64)  - 2.441446 s
# 32  -  106  :  tensor(0.0007, device='cuda:0', dtype=torch.float64)  - 2.443751 s
# 33  -  105  :  tensor(0.0008, device='cuda:0', dtype=torch.float64)  - 2.443932 s
# 33  -  106  :  tensor(0.0008, device='cuda:0', dtype=torch.float64)  - 2.443974 s
# 34  -  105  :  tensor(0.0032, device='cuda:0', dtype=torch.float64)  - 2.444019 s
# 34  -  106  :  tensor(0.0031, device='cuda:0', dtype=torch.float64)  - 2.443925 s
# 35  -  105  :  tensor(-3.1265e-07, device='cuda:0', dtype=torch.float64)  - 2.443882 s
# 35  -  106  :  tensor(2.5212e-05, device='cuda:0', dtype=torch.float64)  - 2.444021 s
# 36  -  105  :  tensor(-0.0002, device='cuda:0', dtype=torch.float64)  - 2.443888 s
# 36  -  106  :  tensor(0.0011, device='cuda:0', dtype=torch.float64)  - 2.444174 s
# 37  -  105  :  tensor(-0.0124, device='cuda:0', dtype=torch.float64)  - 2.444037 s
# 37  -  106  :  tensor(-0.0060, device='cuda:0', dtype=torch.float64)  - 2.441129 s
# 38  -  105  :  tensor(0.0006, device='cuda:0', dtype=torch.float64)  - 2.444151 s
# 38  -  106  :  tensor(0.0007, device='cuda:0', dtype=torch.float64)  - 2.444972 s
# 39  -  105  :  tensor(0.0035, device='cuda:0', dtype=torch.float64)  - 2.443945 s
# 39  -  106  :  tensor(0.0016, device='cuda:0', dtype=torch.float64)  - 2.443946 s
# 40  -  105  :  tensor(0.0022, device='cuda:0', dtype=torch.float64)  - 2.444040 s
# 40  -  106  :  tensor(0.0015, device='cuda:0', dtype=torch.float64)  - 2.443954 s
# 41  -  105  :  tensor(0.0084, device='cuda:0', dtype=torch.float64)  - 2.443840 s
# 41  -  106  :  tensor(0.0047, device='cuda:0', dtype=torch.float64)  - 2.441109 s
# 42  -  105  :  tensor(0.0004, device='cuda:0', dtype=torch.float64)  - 2.443881 s
# 42  -  106  :  tensor(0.0002, device='cuda:0', dtype=torch.float64)  - 2.443755 s
# 43  -  105  :  tensor(-0.0109, device='cuda:0', dtype=torch.float64)  - 2.441769 s
# 43  -  106  :  tensor(-0.0061, device='cuda:0', dtype=torch.float64)  - 2.444079 s
# 44  -  105  :  tensor(3.2149e-05, device='cuda:0', dtype=torch.float64)  - 2.442800 s
# 44  -  106  :  tensor(8.7813e-05, device='cuda:0', dtype=torch.float64)  - 2.441953 s
# 45  -  105  :  tensor(-0.0014, device='cuda:0', dtype=torch.float64)  - 2.443955 s
# 45  -  106  :  tensor(-0.0013, device='cuda:0', dtype=torch.float64)  - 2.443921 s
# 46  -  105  :  tensor(-0.0004, device='cuda:0', dtype=torch.float64)  - 2.443826 s
# 46  -  106  :  tensor(-0.0006, device='cuda:0', dtype=torch.float64)  - 2.544526 s
# 47  -  105  :  tensor(0.0015, device='cuda:0', dtype=torch.float64)  - 2.441637 s
# 47  -  106  :  tensor(8.3922e-05, device='cuda:0', dtype=torch.float64)  - 2.443950 s
# 48  -  105  :  tensor(0.0010, device='cuda:0', dtype=torch.float64)  - 2.444002 s
# 48  -  106  :  tensor(2.4655e-05, device='cuda:0', dtype=torch.float64)  - 2.443938 s
# 49  -  105  :  tensor(-0.0220, device='cuda:0', dtype=torch.float64)  - 2.443870 s
# 49  -  106  :  tensor(-0.0105, device='cuda:0', dtype=torch.float64)  - 2.444084 s
# 50  -  105  :  tensor(0.0077, device='cuda:0', dtype=torch.float64)  - 2.443939 s
# 50  -  106  :  tensor(0.0028, device='cuda:0', dtype=torch.float64)  - 2.443724 s
# 51  -  105  :  tensor(0.0027, device='cuda:0', dtype=torch.float64)  - 2.442317 s
# 51  -  106  :  tensor(0.0013, device='cuda:0', dtype=torch.float64)  - 2.460988 s
# 52  -  105  :  tensor(0.0149, device='cuda:0', dtype=torch.float64)  - 2.444024 s
# 52  -  106  :  tensor(0.0065, device='cuda:0', dtype=torch.float64)  - 2.443812 s
# 53  -  105  :  tensor(0.0054, device='cuda:0', dtype=torch.float64)  - 2.444081 s
# 53  -  106  :  tensor(0.0040, device='cuda:0', dtype=torch.float64)  - 2.443944 s
# 54  -  105  :  tensor(-0.0036, device='cuda:0', dtype=torch.float64)  - 2.443824 s
# 54  -  106  :  tensor(-0.0006, device='cuda:0', dtype=torch.float64)  - 2.443913 s
# 55  -  105  :  tensor(0.0004, device='cuda:0', dtype=torch.float64)  - 2.443901 s
# 55  -  106  :  tensor(0.0006, device='cuda:0', dtype=torch.float64)  - 2.443918 s
# 56  -  105  :  tensor(-0.0007, device='cuda:0', dtype=torch.float64)  - 2.443929 s
# 56  -  106  :  tensor(0.0005, device='cuda:0', dtype=torch.float64)  - 2.443766 s
# 57  -  105  :  tensor(0.0042, device='cuda:0', dtype=torch.float64)  - 2.443864 s
# 57  -  106  :  tensor(0.0024, device='cuda:0', dtype=torch.float64)  - 2.443723 s
# 58  -  105  :  tensor(0.0003, device='cuda:0', dtype=torch.float64)  - 2.442321 s
# 58  -  106  :  tensor(0.0001, device='cuda:0', dtype=torch.float64)  - 2.443833 s
# 59  -  105  :  tensor(-0.0027, device='cuda:0', dtype=torch.float64)  - 2.443923 s
# 59  -  106  :  tensor(-0.0016, device='cuda:0', dtype=torch.float64)  - 2.443762 s
# 60  -  105  :  tensor(-0.0108, device='cuda:0', dtype=torch.float64)  - 2.443925 s
# 60  -  106  :  tensor(-0.0048, device='cuda:0', dtype=torch.float64)  - 2.443811 s
# 61  -  105  :  tensor(1.4760e-05, device='cuda:0', dtype=torch.float64)  - 2.443892 s
# 61  -  106  :  tensor(-0.0007, device='cuda:0', dtype=torch.float64)  - 2.443860 s
# 62  -  105  :  tensor(-4.0206e-05, device='cuda:0', dtype=torch.float64)  - 2.443868 s
# 62  -  106  :  tensor(3.8774e-05, device='cuda:0', dtype=torch.float64)  - 2.444351 s
# 63  -  105  :  tensor(9.4540e-05, device='cuda:0', dtype=torch.float64)  - 2.443863 s
# 63  -  106  :  tensor(-0.0002, device='cuda:0', dtype=torch.float64)  - 2.444741 s
# 64  -  105  :  tensor(-0.0001, device='cuda:0', dtype=torch.float64)  - 2.444000 s
# 64  -  106  :  tensor(-0.0002, device='cuda:0', dtype=torch.float64)  - 2.443977 s
# 65  -  105  :  tensor(0.0003, device='cuda:0', dtype=torch.float64)  - 2.540225 s
# 65  -  106  :  tensor(2.7973e-05, device='cuda:0', dtype=torch.float64)  - 2.443943 s
# 66  -  105  :  tensor(0.0002, device='cuda:0', dtype=torch.float64)  - 2.444029 s
# 66  -  106  :  tensor(0.0001, device='cuda:0', dtype=torch.float64)  - 2.441915 s
# 67  -  105  :  tensor(8.9521e-05, device='cuda:0', dtype=torch.float64)  - 2.551538 s
# 67  -  106  :  tensor(6.4271e-05, device='cuda:0', dtype=torch.float64)  - 2.443993 s
# 68  -  105  :  tensor(-2.8676e-05, device='cuda:0', dtype=torch.float64)  - 2.444177 s
# 68  -  106  :  tensor(7.7475e-05, device='cuda:0', dtype=torch.float64)  - 2.443978 s
# 69  -  105  :  tensor(-6.4938e-05, device='cuda:0', dtype=torch.float64)  - 2.443984 s
# 69  -  106  :  tensor(0.0001, device='cuda:0', dtype=torch.float64)  - 2.443923 s
# 70  -  105  :  tensor(-5.5628e-05, device='cuda:0', dtype=torch.float64)  - 2.443972 s
# 70  -  106  :  tensor(-0.0001, device='cuda:0', dtype=torch.float64)  - 2.443895 s
# 71  -  105  :  tensor(-2.8537e-07, device='cuda:0', dtype=torch.float64)  - 2.443964 s
# 71  -  106  :  tensor(-1.7944e-05, device='cuda:0', dtype=torch.float64)  - 2.444395 s
# 72  -  105  :  tensor(-0.0001, device='cuda:0', dtype=torch.float64)  - 2.443787 s
# 72  -  106  :  tensor(0.0003, device='cuda:0', dtype=torch.float64)  - 2.443835 s
# 73  -  105  :  tensor(-6.3495e-05, device='cuda:0', dtype=torch.float64)  - 2.441162 s
# 73  -  106  :  tensor(-0.0001, device='cuda:0', dtype=torch.float64)  - 2.443886 s
# 74  -  105  :  tensor(5.2992e-05, device='cuda:0', dtype=torch.float64)  - 2.444080 s
# 74  -  106  :  tensor(7.6740e-05, device='cuda:0', dtype=torch.float64)  - 2.443752 s
# 75  -  105  :  tensor(0.0002, device='cuda:0', dtype=torch.float64)  - 2.443782 s
# 75  -  106  :  tensor(-8.8467e-06, device='cuda:0', dtype=torch.float64)  - 2.443764 s
# 76  -  105  :  tensor(5.5576e-06, device='cuda:0', dtype=torch.float64)  - 2.444710 s
# 76  -  106  :  tensor(0., device='cuda:0', dtype=torch.float64)  - 2.443965 s
# 77  -  105  :  tensor(1.0090e-05, device='cuda:0', dtype=torch.float64)  - 2.444263 s
# 77  -  106  :  tensor(-3.9417e-05, device='cuda:0', dtype=torch.float64)  - 2.443832 s
# 78  -  105  :  tensor(0.0001, device='cuda:0', dtype=torch.float64)  - 2.443988 s
# 78  -  106  :  tensor(-1.8995e-05, device='cuda:0', dtype=torch.float64)  - 2.443925 s
# 79  -  105  :  tensor(-6.8046e-05, device='cuda:0', dtype=torch.float64)  - 2.443846 s
# 79  -  106  :  tensor(2.8215e-05, device='cuda:0', dtype=torch.float64)  - 2.563554 s
# 80  -  105  :  tensor(-9.5220e-05, device='cuda:0', dtype=torch.float64)  - 2.443847 s
# 80  -  106  :  tensor(7.5739e-05, device='cuda:0', dtype=torch.float64)  - 2.443951 s
# 81  -  105  :  tensor(2.4152e-05, device='cuda:0', dtype=torch.float64)  - 2.444146 s
# 81  -  106  :  tensor(-0.0001, device='cuda:0', dtype=torch.float64)  - 2.441194 s
# 82  -  105  :  tensor(5.6741e-05, device='cuda:0', dtype=torch.float64)  - 2.444079 s
# 82  -  106  :  tensor(5.9067e-06, device='cuda:0', dtype=torch.float64)  - 2.443807 s
# 83  -  105  :  tensor(-0.0001, device='cuda:0', dtype=torch.float64)  - 2.443812 s
# 83  -  106  :  tensor(-2.2164e-05, device='cuda:0', dtype=torch.float64)  - 2.441463 s
# 84  -  105  :  tensor(5.5926e-05, device='cuda:0', dtype=torch.float64)  - 2.444160 s
# 84  -  106  :  tensor(0.0001, device='cuda:0', dtype=torch.float64)  - 2.443896 s
# 85  -  105  :  tensor(-2.9435e-05, device='cuda:0', dtype=torch.float64)  - 2.443781 s
# 85  -  106  :  tensor(0.0002, device='cuda:0', dtype=torch.float64)  - 2.488810 s
# 86  -  105  :  tensor(1.9459e-05, device='cuda:0', dtype=torch.float64)  - 2.443781 s
# 86  -  106  :  tensor(4.5366e-05, device='cuda:0', dtype=torch.float64)  - 2.444158 s
# 87  -  105  :  tensor(0.0019, device='cuda:0', dtype=torch.float64)  - 2.443911 s
# 87  -  106  :  tensor(0.0010, device='cuda:0', dtype=torch.float64)  - 2.528952 s
# 88  -  105  :  tensor(1.5473e-05, device='cuda:0', dtype=torch.float64)  - 2.444148 s
# 88  -  106  :  tensor(-4.5012e-05, device='cuda:0', dtype=torch.float64)  - 2.444623 s
# 89  -  105  :  tensor(9.5299e-05, device='cuda:0', dtype=torch.float64)  - 2.444638 s
# 89  -  106  :  tensor(-2.1435e-05, device='cuda:0', dtype=torch.float64)  - 2.443740 s
# 90  -  105  :  tensor(6.7066e-05, device='cuda:0', dtype=torch.float64)  - 2.444098 s
# 90  -  106  :  tensor(7.9294e-05, device='cuda:0', dtype=torch.float64)  - 2.444378 s
# 91  -  105  :  tensor(0.0001, device='cuda:0', dtype=torch.float64)  - 2.443823 s
# 91  -  106  :  tensor(0.0001, device='cuda:0', dtype=torch.float64)  - 2.443821 s
# 92  -  105  :  tensor(-5.3435e-05, device='cuda:0', dtype=torch.float64)  - 2.444164 s
# 92  -  106  :  tensor(0.0001, device='cuda:0', dtype=torch.float64)  - 2.546637 s
# 93  -  105  :  tensor(3.2716e-05, device='cuda:0', dtype=torch.float64)  - 2.444404 s
# 93  -  106  :  tensor(0.0001, device='cuda:0', dtype=torch.float64)  - 2.444327 s
# 94  -  105  :  tensor(0.0003, device='cuda:0', dtype=torch.float64)  - 2.443937 s
# 94  -  106  :  tensor(-6.5685e-05, device='cuda:0', dtype=torch.float64)  - 2.443696 s
# 95  -  105  :  tensor(4.4619e-05, device='cuda:0', dtype=torch.float64)  - 2.441821 s
# 95  -  106  :  tensor(4.1638e-05, device='cuda:0', dtype=torch.float64)  - 2.441558 s
# 96  -  105  :  tensor(6.2835e-05, device='cuda:0', dtype=torch.float64)  - 2.443830 s
# 96  -  106  :  tensor(-6.3044e-05, device='cuda:0', dtype=torch.float64)  - 2.443841 s
# 97  -  105  :  tensor(9.2937e-05, device='cuda:0', dtype=torch.float64)  - 2.443423 s
# 97  -  106  :  tensor(-3.2621e-05, device='cuda:0', dtype=torch.float64)  - 2.443910 s
# 98  -  105  :  tensor(3.6263e-05, device='cuda:0', dtype=torch.float64)  - 2.443682 s
# 98  -  106  :  tensor(-1.9868e-05, device='cuda:0', dtype=torch.float64)  - 2.443763 s
# 99  -  105  :  tensor(2.8214e-05, device='cuda:0', dtype=torch.float64)  - 2.441257 s
# 99  -  106  :  tensor(-1.6935e-05, device='cuda:0', dtype=torch.float64)  - 2.443675 s
# 100  -  105  :  tensor(-0.0012, device='cuda:0', dtype=torch.float64)  - 2.444089 s
# 100  -  106  :  tensor(-0.0003, device='cuda:0', dtype=torch.float64)  - 2.444120 s
# 101  -  105  :  tensor(0.0001, device='cuda:0', dtype=torch.float64)  - 2.460116 s
# 101  -  106  :  tensor(1.0485e-05, device='cuda:0', dtype=torch.float64)  - 2.444360 s
# 102  -  105  :  tensor(-1.2663e-05, device='cuda:0', dtype=torch.float64)  - 2.443713 s
# 102  -  106  :  tensor(3.2524e-05, device='cuda:0', dtype=torch.float64)  - 2.443836 s
# 103  -  105  :  tensor(0.0001, device='cuda:0', dtype=torch.float64)  - 2.443678 s
# 103  -  106  :  tensor(0.0001, device='cuda:0', dtype=torch.float64)  - 2.443850 s
# 104  -  105  :  tensor(-0.0505, device='cuda:0', dtype=torch.float64)  - 2.443722 s
# 104  -  106  :  tensor(-0.0195, device='cuda:0', dtype=torch.float64)  - 2.443723 s
# 105  -  106  :  tensor(0.0074, device='cuda:0', dtype=torch.float64)  - 2.443704 s
# 105  -  107  :  tensor(-0.0004, device='cuda:0', dtype=torch.float64)  - 2.554715 s
# 105  -  108  :  tensor(-8.4989e-05, device='cuda:0', dtype=torch.float64)  - 2.445594 s
# 105  -  109  :  tensor(-0.0161, device='cuda:0', dtype=torch.float64)  - 2.477322 s
# 105  -  110  :  tensor(0.0006, device='cuda:0', dtype=torch.float64)  - 2.440900 s
# 105  -  111  :  tensor(-0.0002, device='cuda:0', dtype=torch.float64)  - 2.444752 s
# 106  -  107  :  tensor(0.0003, device='cuda:0', dtype=torch.float64)  - 2.450801 s
# 106  -  108  :  tensor(4.0092e-05, device='cuda:0', dtype=torch.float64)  - 2.444432 s
# 106  -  109  :  tensor(0.0008, device='cuda:0', dtype=torch.float64)  - 2.554432 s
# 106  -  110  :  tensor(-0.0066, device='cuda:0', dtype=torch.float64)  - 2.443563 s
# 106  -  111  :  tensor(-0.0002, device='cuda:0', dtype=torch.float64)  - 2.444755 s

# %%
pip install pypair
# Out:
# Requirement already satisfied: pypair in /usr/local/lib/python3.10/dist-packages (3.0.9)

# %%
from pypair.contingency import (
    AgreementMixin,
    BinaryMixin,
    CategoricalMixin,
    ConfusionMixin
)

def get_measures(clazz):
    """
    Gets all the measures of a clazz.

    :param clazz: Clazz.
    :return: List of measures.
    """
    is_property = lambda v: isinstance(v, property)
    is_public = lambda n: not n.startswith('_')
    is_valid = lambda n, v: is_public(n) and is_property(v)

    measures = [n for n, v in clazz.__dict__.items() if is_valid(n, v)]
    return sorted(measures)
print("AgreementMixin: ")
print(get_measures(AgreementMixin))
print("BinaryMixin: ")
print(get_measures(BinaryMixin))
print("CategoricalMixin: ")
print(get_measures(CategoricalMixin))
print("ConfusionMixin: ")
print(get_measures(ConfusionMixin))
# Out:
# AgreementMixin:
# ['chohen_k', 'cohen_light_k']
# BinaryMixin:
# ['ample', 'anderberg', 'baroni_urbani_buser_i', 'baroni_urbani_buser_ii', 'braun_banquet', 'chisq', 'chord', 'cole_i', 'cole_ii', 'contingency_coefficient', 'cosine', 'cramer_v', 'dennis', 'dice', 'disperson', 'driver_kroeber', 'euclid', 'eyraud', 'fager_mcgowan', 'faith', 'forbes_ii', 'forbesi', 'fossum', 'gilbert_wells', 'goodman_kruskal', 'gower', 'gower_legendre', 'hamann', 'hamming', 'hellinger', 'inner_product', 'intersection', 'jaccard', 'jaccard_3w', 'jaccard_distance', 'johnson', 'kulcyznski_ii', 'kulczynski_i', 'lance_williams', 'mcconnaughey', 'mcnemar_test', 'mean_manhattan', 'michael', 'mountford', 'ochia_i', 'ochia_ii', 'odds_ratio', 'pattern_difference', 'pearson_heron_i', 'pearson_heron_ii', 'pearson_i', 'peirce', 'person_ii', 'roger_tanimoto', 'russel_rao', 'shape_difference', 'simpson', 'size_difference', 'sokal_michener', 'sokal_sneath_i', 'sokal_sneath_ii', 'sokal_sneath_iii', 'sokal_sneath_iv', 'sokal_sneath_v', 'sorensen_dice', 'sorgenfrei', 'stiles', 'tanimoto_distance', 'tanimoto_i', 'tanimoto_ii', 'tarantula', 'tarwid', 'tetrachoric', 'tschuprow_t', 'vari', 'yule_q', 'yule_q_difference', 'yule_w', 'yule_y']
# CategoricalMixin:
# ['adjusted_rand_index', 'chisq', 'chisq_dof', 'gk_lambda', 'gk_lambda_reversed', 'mutual_information', 'phi', 'uncertainty_coefficient', 'uncertainty_coefficient_reversed']
# ConfusionMixin:
# ['acc', 'ba', 'bm', 'dor', 'f1', 'fdr', 'fn', 'fnr', 'fomr', 'fp', 'fpr', 'mcc', 'mk', 'n', 'nlr', 'npv', 'plr', 'ppv', 'precision', 'prevalence', 'pt', 'recall', 'sensitivity', 'specificity', 'tn', 'tnr', 'tp', 'tpr', 'ts']

# %%
from abc import ABC
from functools import lru_cache, reduce
from itertools import chain, product
from math import sqrt, log2, pi, log, cos

import pandas as pd
from scipy import stats
from scipy.special import binom

from pypair.decorator import timeit, similarity, distance
from pypair.util import MeasureMixin


class CategoricalMixin(object):
    """
    Categorical computations based off a contingency table.
    """



    def chisq(self):
        """
        The `chi-square statistic <https://en.wikipedia.org/wiki/Chi-square_distribution>`_ :math:`\\chi^2`,
        is defined as follows.

        :math:`\\sum_i \\sum_j \\frac{(O_{ij} - E_{ij})^2}{E_{ij}}`

        In a contingency table, :math:`O_ij` is the observed cell count corresponding to the :math:`i` row
        and :math:`j` column. :math:`E_ij` is the expected cell count corresponding to the :math:`i` row and
        :math:`j` column.

        :math:`E_i = \\frac{N_{i*} N_{*j}}{N}`

        Where :math:`N_{i*}` is the i-th row marginal, :math:`N_{*j}` is the j-th column marginal and
        :math:`N` is the sum of all the values in the contingency cells (or the total size of the data).

        References

        - `Chi-Square Statistic Definition <https://www.investopedia.com/terms/c/chi-square-statistic.asp>`_

        :return: Chi-square statistic.
        """
        n = self._n
        r = self._r
        c = self._k
        row_marginals = self._r_margs
        col_marginals = self._k_margs

        get_expected = lambda i, j: row_marginals[i] * col_marginals[j] / n
        expected = [[get_expected(i, j) for j in range(c)] for i in range(r)]

        chisq = sum([(o - e) ** 2 / e for o, e in zip(chain(*self._table), chain(*expected))])
        return chisq



    def chisq_dof(self):
        """
        Returns the degrees of freedom form :math:`\\chi^2`, which is defined as :math:`(R - 1)(C - 1)`,
        where :math:`R` is the number of rows and :math:`C` is the number of columns in a contingency
        table induced by two categorical variables.

        :return: Degrees of freedom.
        """
        return (self._r - 1) * (self._k - 1)



    def phi(self):
        """
        Gets :math:`\\phi`.

        :math:`\\phi = \\sqrt{\\frac{\\chi^2}{N}}`

        :return: :math:`\\phi`.
        """
        return sqrt(self.chisq() / self._n)



    def uncertainty_coefficient(self):
        """
        The `uncertainty coefficient <https://en.wikipedia.org/wiki/Uncertainty_coefficient>`_ :math:`U(X|Y)`
        for two variables :math:`X` and :math:`Y` is defined as follows.

        :math:`U(X|Y) = \\frac{I(X;Y)}{H(X)}`

        Where,

        - :math:`H(X) = -\\sum_x P(x) \\log P(x)`
        - :math:`I(X;Y) = \\sum_y \\sum_x P(x, y) \\log \\frac{P(x, y)}{P(x) P(y)}`

        :math:`H(X)` is called the entropy of :math:`X` and :math:`I(X;Y)` is the mutual information
        between :math:`X` and :math:`Y`. Note that :math:`I(X;Y) < H(X)` and both values are positive.
        As such, the uncertainty coefficient may be viewed as the normalized mutual information
        between :math:`X` and :math:`Y` and in the range :math:`[0, 1]`.

        :return: Uncertainty coefficient.
        """
        n = self._n

        h_b = map(lambda j: self._k_margs[j] / n, range(self._k))
        h_b = map(lambda p: p * log(p), h_b)
        h_b = -reduce(lambda x, y: x + y, h_b)

        i_ab = self.mutual_information()

        e = i_ab / h_b

        return e



    def uncertainty_coefficient_reversed(self):
        """
        `Uncertainty coefficient <https://en.wikipedia.org/wiki/Uncertainty_coefficient>`_.

        :return: Uncertainty coefficient.
        """
        n = self._n

        h_b = map(lambda i: self._r_margs[i] / n, range(self._r))
        h_b = map(lambda p: p * log(p), h_b)
        h_b = -reduce(lambda x, y: x + y, h_b)

        i_ab = self.mutual_information()

        e = i_ab / h_b

        return e



    def mutual_information(self):
        """
        The `mutual information <https://en.wikipedia.org/wiki/Mutual_information>`_ between
        two variables :math:`X` and :math:`Y` is denoted as :math:`I(X;Y)`.  :math:`I(X;Y)` is
        unbounded and in the range :math:`[0, \\infty]`. A higher mutual information
        value implies strong association. The formula for :math:`I(X;Y)` is defined as follows.

        :math:`I(X;Y) = \\sum_y \\sum_x P(x, y) \\log \\frac{P(x, y)}{P(x) P(y)}`

        :return: Mutual information.
        """
        n = self._n

        get_p_a = lambda i: self._r_margs[i] / n
        get_p_b = lambda j: self._k_margs[j] / n
        get_p_ab = lambda i, j: self._table[i][j] / n
        get_mi = lambda i, j: get_p_ab(i, j) * log(get_p_ab(i, j) / get_p_a(i) / get_p_b(j))

        mi = sum((get_mi(i, j) for i, j in product(*[range(self._r), range(self._k)])))

        return mi



    def gk_lambda(self):
        """
        Goodman-Kruskal's lambda is the `proportional reduction in error`
        of predicting one variable `b` given another `a`: :math:`\\lambda_{B|A}`.

        - The probability of an error in predicting the column category: :math:`P_e = 1 - \\frac{\\max_{c} N_{* c}}{N}`
        - The probability of an error in predicting the column category given the row category: :math:`P_{e|r} = 1 - \\frac{\\sum_r \\max_{c} N_{r c}}{N}`

        Where,

        - :math:`\\max_{c} N_{* c}` is the maximum of the column marginals
        - :math:`\\sum_r \\max_{c} N_{r c}` is the sum over the maximum value per row
        - :math:`N` is the total

        Thus, :math:`\\lambda_{B|A} = \\frac{P_e - P_{e|r}}{P_e}`.

        The way the contingency table is setup by default is that `a` is on
        the rows and `b` is on the columns. Note that Goodman-Kruskal's lambda
        is not symmetric: :math:`\\lambda_{B|A}` does not necessarily equal
        :math:`\\lambda_{A|B}`. By default, :math:`\\lambda_{B|A}` is computed, but
        if you desire the reverse, use `goodman_kruskal_lambda_reversed()`.

        References

        - `Goodman-Kruskal's lambda <https://en.wikipedia.org/wiki/Goodman_and_Kruskal%27s_lambda>`_.
        - `Correlation <http://cda.psych.uiuc.edu/web_407_spring_2014/correlation_week4.pdf>`_.

        :return: Goodman-Kruskal's lambda.
        """
        n = self._n
        r = self._r

        x = sum([max(self._table[i]) for i in range(r)])
        y = max(self._k_margs)
        gkl = (x - y) / (n - y)
        return gkl



    def gk_lambda_reversed(self):
        """
        Computes :math:`\\lambda_{A|B}`.

        :return: Goodman-Kruskal's lambda.
        """
        n = self._n
        r = self._r
        c = self._k

        x = sum([max([self._table[i][j] for i in range(r)]) for j in range(c)])
        y = max(self._r_margs)
        gkl = (x - y) / (n - y)
        return gkl



    def adjusted_rand_index(self):
        """
        The Adjusted Rand Index (ARI) should yield a value between
        [0, 1], however, negative values can also arise when the index
        is less than the expected value. This function uses `binom()`
        from `scipy.special`, and when n >= 300, the results are too
        large and may cause overflow.

        TODO: use a different way to compute binomial coefficient

        References

        - `Adjusted Rand Index <https://en.wikipedia.org/wiki/Rand_index#Adjusted_Rand_index>`_.
        - `Python binomial coefficient <https://stackoverflow.com/questions/26560726/python-binomial-coefficient>`_.

        :return: Adjusted Rand Index.
        """
        a_i = sum([int(binom(a, 2)) for a in self._r_margs])
        b_j = sum([int(binom(b, 2)) for b in self._k_margs])
        n_ij = sum([int(binom(n, 2)) for n in chain(*self._table)])
        n = binom(self._n, 2)

        top = (n_ij - (a_i * b_j) / n)
        bot = 0.5 * (a_i + b_j) - (a_i * b_j) / n
        s = top / bot
        return s


class BinaryMixin(object):
    """
    Binary computations based off of `a`, `b`, `c` and `d` from a 2x2 contingency table.
    """



    def __abcdn(self):
        """
        Gets a, b, c, d, n.

        :returns: a, b, c, d, n
        """
        return self._a, self._b, self._c, self._d, self._n


    @timeit
    def __sigma(self):
        """
        Gets :math:`\\max(a, b) + \\max(c, d) + \\max(a, c) + \\max(b, d)`.

        :returns: :math:`\\max(a, b) + \\max(c, d) + \\max(a, c) + \\max(b, d)`.
        """
        a, b, c, d, n = self.__abcdn()
        return max(a, b) + max(c, d) + max(a, c) + max(b, d)


    @timeit
    def __sigma_prime(self):
        """
        Gets :math:`\\max(a + c, b + d) + \\max(a + b, c + d)`.

        :return: :math:`\\max(a + c, b + d) + \\max(a + b, c + d)`
        """
        a, b, c, d, n = self.__abcdn()
        return max(a + c, b + d) + max(a + b, c + d)


    @timeit
    @similarity

    def jaccard_3w(self):
        """
        3W-Jaccard

        :math:`\\frac{3a}{3a+b+c}`

        :return: 3W-Jaccard.
        """
        a, b, c, d, n = self.__abcdn()
        return 3 * a / (3 * a + b + c)


    @timeit
    @similarity

    def ample(self):
        """
        Ample

        :math:`\\left|\\frac{a(c+d)}{c(a+b)}\\right|`

        :return: Ample.
        """
        a, b, c, d, n = self.__abcdn()
        return abs((a * (c + d)) / (c * (a + b)))


    @timeit
    @similarity

    def anderberg(self):
        """
        Anderberg

        :math:`\\frac{\\sigma-\\sigma'}{2n}`

        :return: Anderberg.
        """
        *_, n = self.__abcdn()
        return (self.__sigma() - self.__sigma_prime()) / (2 * n)


    @timeit
    @similarity

    def baroni_urbani_buser_i(self):
        """
        Baroni-Urbani-Buser-I

        :math:`\\frac{\\sqrt{ad}+a}{\\sqrt{ad}+a+b+c}`

        :return: Baroni-Urbani-Buser-I.
        """
        a, b, c, d, n = self.__abcdn()
        return (sqrt(a * d) + a) / (sqrt(a * d) + a + b + c)


    @timeit
    @similarity

    def baroni_urbani_buser_ii(self):
        """
        Baroni-Urbani-Buser-II

        :math:`\\frac{\\sqrt{ad}+a-(b+c)}{\\sqrt{ad}+a+b+c}`

        :return: Baroni-Urbani-Buser-II.
        """
        a, b, c, d, n = self.__abcdn()
        return (sqrt(a * d) + a - (b + c)) / (sqrt(a * d) + a + b + c)


    @timeit
    @similarity

    def braun_banquet(self):
        """
        Braun-Banquet

        :math:`\\frac{a}{\\max(a+b,a+c)}`

        :return: Braun-Banquet.
        """
        a, b, c, d, n = self.__abcdn()
        return a / max(a + b, a + c)


    @timeit
    @similarity

    def cole_i(self):
        """
        Cole-I

        :math:`\\frac{\\sqrt{2}(ad-bc)}{\\sqrt{(ad-bc)^2-(a+b)(a+c)(b+d)(c+d)}}`

        :return: Cole-I.
        """
        a, b, c, d, n = self.__abcdn()
        return (2 * (a * d - b * c) ** 2) / ((a * d - b * c) ** 2 - (a + b) * (a + c) * (b + d) * (c + d))


    @timeit
    @similarity

    def cole_ii(self):
        """
        Cole-II

        :math:`\\frac{ad-bc}{\\min((a+b)(a+c),(b+d)(c+d))}`

        :return: Cole-II.
        """
        a, b, c, d, n = self.__abcdn()
        return (2 * (a * d - b * c) ** 2) / ((a * d - b * c) ** 2 - (a + b) * (a + c) * (b + d) * (c + d))


    @timeit
    @similarity

    def cosine(self):
        """
        Cosine

        :math:`\\frac{a}{(a+b)(a+c)}`

        :return: Cosine.
        """
        a, b, c, d, n = self.__abcdn()
        return a / ((a + b) * (a + c))


    @timeit
    @similarity

    def dennis(self):
        """
        Dennis

        :math:`\\frac{ad-bc}{\\sqrt{n(a+b)(a+c)}}`

        :return: Dennis.
        """
        a, b, c, d, n = self.__abcdn()
        return (a * d - b * c) / sqrt(n * (a + b) * (a + c))


    @timeit
    @similarity

    def dice(self):
        """
        Dice; Czekanowski; Nei-Li

        :math:`\\frac{2a}{2a+b+c}`

        :return: Dice.
        """
        a, b, c, d, n = self.__abcdn()
        return (2 * a) / (2 * a + b + c)


    @timeit
    @similarity

    def disperson(self):
        """
        Disperson

        :math:`\\frac{ad-bc}{(a+b+c+d)^2}`

        :return: Disperson.
        """
        a, b, c, d, n = self.__abcdn()
        return (a * d - b * c) / (a + b + c + d) ** 2


    @timeit
    @similarity

    def driver_kroeber(self):
        """
        Driver-Kroeber

        :math:`\\frac{a}{2}\\left(\\frac{1}{a+b}+\\frac{1}{a+c}\\right)`

        :return: Driver-Kroeber.
        """
        a, b, c, d, n = self.__abcdn()
        return (a / 2) * ((1 / (a + b)) + (1 / (a + c)))


    @timeit
    @similarity

    def eyraud(self):
        """
        Eyraud

        :math:`\\frac{n^2(na-(a+b)(a+c))}{(a+b)(a+c)(b+d)(c+d)}`

        :return: Eyraud.
        """
        a, b, c, d, n = self.__abcdn()
        return (n ** 2 * (n * a - (a + b) * (a + c))) / ((a + b) * (a + c) * (b + d) * (c + d))


    @timeit
    @similarity

    def fager_mcgowan(self):
        """
        Fager-McGowan

        :math:`\\frac{a}{\\sqrt{(a+b)(a+c)}}-\\frac{max(a+b,a+c)}{2}`

        :return: Fager-McGowan.
        """
        a, b, c, d, n = self.__abcdn()
        return a / sqrt((a + b) * (a + c)) - max(a + b, a + c) / 2


    @timeit
    @similarity

    def faith(self):
        """
        Faith

        :math:`\\frac{a+0.5d}{a+b+c+d}`

        :return: Faith.
        """
        a, b, c, d, n = self.__abcdn()
        return (a + 0.5 * d) / (a + b + c + d)


    @timeit
    @similarity

    def forbes_ii(self):
        """
        Forbes-II

        :math:`\\frac{na-(a+b)(a+c)}{n \\min(a+b,a+c) - (a+b)(a+c)}`

        :return: Forbes-II.
        """
        a, b, c, d, n = self.__abcdn()
        return (n * a - (a + b) * (a + c)) / (n * min(a + b, a + c) - (a + b) * (a + c))


    @timeit
    @similarity

    def forbesi(self):
        """
        Forbesi

        :math:`\\frac{na}{(a+b)(a+c)}`

        :return: Forbesi.
        """
        a, b, c, d, n = self.__abcdn()
        return (n * a) / ((a + b) * (a + c))


    @timeit
    @similarity

    def fossum(self):
        """
        Fossum

        :math:`\\frac{n(a-0.5)^2}{(a+b)(a+c)}`

        :return: Fossum.
        """
        a, b, c, d, n = self.__abcdn()
        return (n * (a - 0.5) ** 2) / ((a + b) * (a + c))


    @timeit
    @similarity

    def gilbert_wells(self):
        """
        Gilbert-Wells

        :math:`\\log a - \\log n - \\log \\frac{a+b}{n} - \\log \\frac{a+c}{n}`

        :return: Gilbert-Wells.
        """
        a, b, c, d, n = self.__abcdn()
        return log(a) - log(n) - log((a + b) / n) - log((a + c) / n)


    @timeit
    @similarity

    def goodman_kruskal(self):
        """
        Goodman-Kruskal

        :math:`\\frac{\\sigma - \\sigma'}{2n-\\sigma'}`

        :return: Goodman-Kruskal.
        """
        *_, n = self.__abcdn()
        return (self.__sigma() - self.__sigma_prime()) / (2 * n - self.__sigma_prime())


    @timeit
    @similarity

    def gower(self):
        """
        Gower

        :math:`\\frac{a+d}{\\sqrt{(a+b)(a+c)(b+d)(c+d)}}`

        :return: Gower.
        """
        a, b, c, d, n = self.__abcdn()
        return (a + d) / sqrt((a + b) * (a + c) * (b + d) * (c + d))


    @timeit
    @similarity

    def gower_legendre(self):
        """
        Gower-Legendre

        :math:`\\frac{a+d}{a+0.5b+0.5c+d}`

        :return: Gower-Legendre.
        """
        a, b, c, d, n = self.__abcdn()
        return (a + d) / (a + 0.5 * (b + c) + d)


    @timeit
    @similarity

    def hamann(self):
        """
        Hamann.

        :math:`\\frac{(a+d)-(b+c)}{a+b+c+d}`

        :return: Hamann.
        """
        a, b, c, d, n = self.__abcdn()
        return ((a + d) - (b + c)) / (a + b + c + d)


    @timeit
    @similarity

    def inner_product(self):
        """
        Inner-product.

        :math:`a+d`

        :return: Inner-product.
        """
        a, b, c, d, n = self.__abcdn()
        return a + d


    @timeit
    @similarity

    def intersection(self):
        """
        Intersection

        :math:`a`

        :return: Intersection.
        """
        a, *_ = self.__abcdn()
        return a


    @timeit
    @similarity

    def jaccard(self):
        """
        Jaccard

        :math:`\\frac{a}{a+b+c}`

        :return: Jaccard.
        """
        a, b, c, d, n = self.__abcdn()
        return a / (a + b + c)


    @timeit
    @similarity

    def johnson(self):
        """
        Johnson.

        :math:`\\frac{a}{a+b}+\\frac{a}{a+c}`

        :return: Johnson.
        """
        a, b, c, d, n = self.__abcdn()
        return a / (a + b) + a / (a + c)


    @timeit
    @similarity

    def kulczynski_i(self):
        """
        Kulczynski-I

        :math:`\\frac{a}{b+c}`

        :return: Kulczynski-I.
        """
        a, b, c, d, n = self.__abcdn()
        return a / (b + c)


    @timeit
    @similarity

    def kulcyznski_ii(self):
        """
        Kulczynski-II

        :math:`\\frac{0.5a(2a+b+c)}{(a+b)(a+c)}`

        :return: Kulczynski-II.
        """
        a, b, c, d, n = self.__abcdn()
        return 0.5 * ((a / (a + b)) * (a / (a + c)))


    @timeit
    @similarity

    def mcconnaughey(self):
        """
        McConnaughey

        :math:`\\frac{a^2 - bc}{(a+b)(a+c)}`

        :return: McConnaughey.
        """
        a, b, c, d, n = self.__abcdn()
        return (a ** 2 - b * c) / ((a + d) ** 2 + (b + c) ** 2)


    @timeit
    @similarity

    def michael(self):
        """
        Michael

        :math:`\\frac{4(ad-bc)}{(a+d)^2+(b+c)^2}`

        :return: Michael.
        """
        a, b, c, d, n = self.__abcdn()
        return (4 * (a * d - b * c)) / ((a + d) ** 2 + (b + c) ** 2)


    @timeit
    @similarity

    def mountford(self):
        """
        Mountford

        :math:`\\frac{a}{0.5(ab + ac) + bc}`

        :return: Mountford.
        """
        a, b, c, d, n = self.__abcdn()
        return a / (0.5 * (a * b + a * c) + b * c)


    @timeit
    @similarity

    def ochia_i(self):
        """
        Ochia-I

        Also known as `Fowlkes-Mallows Index <https://en.wikipedia.org/wiki/Fowlkes%E2%80%93Mallows_index>`_.
        This measure is typically used to judge the similarity between two clusters.
        A larger value indicates that the clusters are more similar.

        :math:`\\frac{a}{\\sqrt{(a+b)(a+c)}}`

        :return: Ochai-I.
        """
        a, b, c, d, n = self.__abcdn()
        return sqrt((a / (a + b)) * (a / (a + c)))


    @timeit
    @similarity

    def ochia_ii(self):
        """
        Ochia-II

        :math:`\\frac{ad}{\\sqrt{(a+b)(a+c)(b+d)(c+d)}}`

        :return: Ochia-II.
        """
        a, b, c, d, n = self.__abcdn()
        return (a * d) / sqrt((a + b) * (a + c) * (b + d) * (c + d))


    @timeit
    @similarity

    def pearson_heron_i(self):
        """
        Pearson-Heron-I

        :math:`\\frac{ad-bc}{\\sqrt{(a+b)(a+c)(b+d)(c+d)}}`

        :return: Pearson-Heron-I.
        """
        a, b, c, d, n = self.__abcdn()
        return (a * d - b * c) / sqrt((a + b) * (a + c) * (b + d) * (c + d))


    @timeit
    @similarity

    def pearson_heron_ii(self):
        """
        Pearson-Heron-II

        :math:`\\sqrt{\\frac{\\chi^2}{n+\\chi^2}}`

        :return: Pearson-Heron-II.
        """
        a, b, c, d, n = self.__abcdn()
        return cos((pi * sqrt(b * c)) / (sqrt(a * d) + sqrt(b * c)))


    @timeit
    @similarity

    def pearson_i(self):
        """
        Pearson-I

        :math:`\\chi^2=\\frac{n(ad-bc)^2}{(a+b)(a+c)(c+d)(b+d)}`

        :return: Pearson-I.
        """
        a, b, c, d, n = self.__abcdn()
        return (n * (a * d - b * c) ** 2) / ((a + b) * (a + c) * (c + d) * (b + d))


    @timeit
    @similarity

    def chisq(self):
        """
        :math:`\\chi^2` (alias for Pearson-I)

        :return: :math:`\\chi^2`.
        """
        return self.pearson_i


    @timeit
    @similarity

    def person_ii(self):
        """
        Pearson-II

        :math:`\\sqrt{\\frac{\\rho}{n+\\rho}}`

        - :math:`\\rho=\\frac{ad-bc}{\\sqrt{(a+b)(a+c)(b+d)(c+d)}}`

        :return: Pearson-II.
        """
        *_, n = self.__abcdn()
        chisq = self.chisq()
        return sqrt(chisq / (n + chisq))


    @timeit
    @similarity

    def peirce(self):
        """
        Peirce

        :math:`\\frac{ab+bc}{ab+2bc+cd}`

        :return: Peirce.
        """
        a, b, c, d, n = self.__abcdn()
        return (a * b + b * c) / (a * b + 2 * b * c + c * d)


    @timeit
    @similarity

    def roger_tanimoto(self):
        """
        Roger-Tanimoto

        :math:`\\frac{a+d}{a+2b+2c+d}`

        :return: Roger-Tanimoto.
        """
        a, b, c, d, n = self.__abcdn()
        return (a + d) / (a + 2 * (b + c) + d)


    @timeit
    @similarity

    def russel_rao(self):
        """
        Russel-Rao

        :math:`\\frac{a}{a+b+c+d}`

        :return: Russel-Rao.
        """
        a, b, c, d, n = self.__abcdn()
        return a / (a + b + c + d)


    @timeit
    @similarity

    def simpson(self):
        """
        Simpson (or `Overlap <https://en.wikipedia.org/wiki/Overlap_coefficient>`_).

        :math:`\\frac{a}{\\min(a+b,a+c)}`

        :return: Simpson.
        """
        a, b, c, d, n = self.__abcdn()
        return a / min(a + b, a + c)


    @timeit
    @similarity

    def sokal_michener(self):
        """
        Sokal-Michener

        :math:`\\frac{a+d}{a+b+c+d}`

        :return: Sokal-Michener.
        """
        a, b, c, d, n = self.__abcdn()
        return (a + d) / (a + b + c + d)


    @timeit
    @similarity

    def sokal_sneath_i(self):
        """
        Sokal-Sneath-I


        :math:`\\frac{a}{a+2b+2c}`

        :return: Sokal-Sneath-I.
        """
        a, b, c, d, n = self.__abcdn()
        return a / (a + 2 * (b + c))


    @timeit
    @similarity

    def sokal_sneath_ii(self):
        """
        Sokal-Sneath-II

        :math:`\\frac{2a+2d}{2a+b+c+2d}`

        :return: Sokal-Sneath-II.
        """
        a, b, c, d, n = self.__abcdn()
        return 2 * (a + d) / (2 * (a + d) + b + c)


    @timeit
    @similarity

    def sokal_sneath_iii(self):
        """
        Sokal-Sneath-III

        :math:`\\frac{a+d}{b+c}`

        :return: Sokal-Sneath-III.
        """
        a, b, c, d, n = self.__abcdn()
        return (a + d) / (b + c)


    @timeit
    @similarity

    def sokal_sneath_iv(self):
        """
        Sokal-Sneath-IV

        :math:`\\frac{ad}{(a+b)(a+c)(b+d)\\sqrt{c+d}}`

        :return: Sokal-Sneath-IV.
        """
        a, b, c, d, n = self.__abcdn()
        return 0.25 * ((a / (a + b)) + (a / (a + c)) + (d / (b + d)) + (d / (b + d)))


    @timeit
    @similarity

    def sokal_sneath_v(self):
        """
        Sokal-Sneath-V

        :math:`\\frac{1}{4}\\left(\\frac{a}{a+b}+\\frac{a}{a+c}+\\frac{d}{b+d}+\\frac{d}{b+d}\\right)`

        :return: Sokal-Sneath-V.
        """
        a, b, c, d, n = self.__abcdn()
        return (a * d) / ((a + b) * (a + c) * (b + d) * sqrt(c + d))


    @timeit
    @similarity

    def sorensen_dice(self):
        """
        Sørensen–Dice

        :math:`\\frac{2(a + d)}{2(a + d) + b + c}`

        :return: Sørensen–Dice,
        """
        a, b, c, d, n = self.__abcdn()
        return 2 * (a + d) / (2 * (a + d) + b + c)


    @timeit
    @similarity

    def sorgenfrei(self):
        """
        Sorgenfrei

        :math:`\\frac{a^2}{(a+b)(a+c)}`

        :return: Sorgenfrei.
        """
        a, b, c, d, n = self.__abcdn()
        return a ** 2 / ((a + b) * (a + c))


    @timeit
    @similarity

    def stiles(self):
        """
        Stiles

        :math:`\\log_{10} \\frac{n\\left(|ad-bc|-\\frac{n}{2}\\right)^2}{(a+b)(a+c)(b+d)(c+d)}`

        :return: Stiles.
        """
        a, b, c, d, n = self.__abcdn()
        return log((n * (abs(a * d - b * c) - 0.5) ** 2) / ((a + b) * (a + c) * (b + d) * (c + d)), 10)


    @timeit
    @similarity

    def tanimoto_i(self):
        """
        Tanimoto-I

        :math:`\\frac{a}{2a+b+c}`

        :return: Tanimoto-I.
        """
        a, b, c, d, n = self.__abcdn()
        return a / (2 * a + b + c)


    @timeit
    @similarity

    def tanimoto_ii(self):
        """
        Tanimoto-II

        :math:`\\frac{a}{b + c}`

        :return: Tanimoto-II.
        """
        a, b, c, d, n = self.__abcdn()
        return a / (b + c)


    @timeit
    @similarity

    def tarwid(self):
        """
        Tarwind

        :math:`\\frac{na - (a+b)(a+c)}{na + (a+b)(a+c)}`

        :return: Tarwind.
        """
        a, b, c, d, n = self.__abcdn()
        return (n * a - (a + b) * (a + c)) / (n * a + (a + b) * (a + c))


    @timeit
    @similarity

    def tarantula(self):
        """
        Tarantula

        :math:`\\frac{a(c+d)}{c(a+b)}`

        :return: Tarantula.
        """
        a, b, c, d, n = self.__abcdn()
        return a * (c + d) / (c * (a + b))


    @timeit
    @similarity

    def yule_q(self):
        """
        Yule's Q

        :math:`\\frac{ad-bc}{ad+bc}`

        Also, Yule's Q is based off of the odds ratio or cross-product ratio, :math:`\\alpha`.

        :math:`Q = \\frac{\\alpha - 1}{\\alpha + 1}`

        Yule's Q is the same as Goodman-Kruskal's :math:`\\lambda` for 2 x 2 contingency tables and is also
        a measure of proportional reduction in error (PRE).

        :return: Yule's Q.
        """
        a, b, c, d, n = self.__abcdn()
        return (a * d - b * c) / (a * d + b * c)


    @timeit
    @similarity

    def yule_w(self):
        """
        Yule's w

        :math:`\\frac{\\sqrt{ad}-\\sqrt{bc}}{\\sqrt{ad}+\\sqrt{bc}}`

        :return: Yule's w.
        """
        a, b, c, d, n = self.__abcdn()
        return (sqrt(a * d) - sqrt(b * c)) / (sqrt(a * d) + sqrt(b * c))


    @timeit
    @distance

    def chord(self):
        """
        Chord

        :math:`\\sqrt{2\\left(1 - \\frac{a}{\\sqrt{(a+b)(a+c)}}\\right)}`

        :return: Chord (distance).
        """
        a, b, c, d, n = self.__abcdn()
        return sqrt(2 * (1 - a / sqrt((a + b) * (a + c))))


    @timeit
    @distance

    def euclid(self):
        """
        Euclid

        :math:`\\sqrt{b+c}`

        :return: Euclid (distance).
        """
        a, b, c, d, n = self.__abcdn()
        return sqrt(b + c)


    @timeit
    @distance

    def hamming(self):
        """
        Hamming; Canberra; Manhattan; Cityblock; Minkowski

        :math:`b+c`

        :return: Hamming (distance).
        """
        a, b, c, d, n = self.__abcdn()
        return b + c


    @timeit
    @distance

    def hellinger(self):
        """
        Hellinger

        :math:`2\\sqrt{1 - \\frac{a}{\\sqrt{(a+b)(a+c)}}}`

        :return: Hellinger (distance).
        """
        a, b, c, d, n = self.__abcdn()
        return 2 * sqrt(1 - a / sqrt((a + b) * (a + c)))


    @timeit
    @distance

    def jaccard_distance(self):
        """
        Jaccard

        :math:`\\frac{b + c}{a + b + c}`

        :return: Jaccard (distance).
        """
        a, b, c, d, n = self.__abcdn()
        return (b + c) / (a + b + c)


    @timeit
    @distance

    def lance_williams(self):
        """
        Lance-Williams; Bray-Curtis

        :math:`\\frac{b+c}{2a+b+c}`

        :return: Lance-Williams (distance).
        """
        a, b, c, d, n = self.__abcdn()
        return (b + c) / (2 * a + b + c)


    @timeit
    @distance

    def mean_manhattan(self):
        """
        Mean-Manhattan

        :math:`\\frac{b+c}{a+b+c+d}`

        :return: Mean-Manhattan (distance).
        """
        a, b, c, d, n = self.__abcdn()
        return (b + c) / (a + b + c + d)


    @timeit
    @distance

    def pattern_difference(self):
        """
        Pattern difference

        :math:`\\frac{4bc}{(a+b+c+d)^2}`

        :return: Pattern difference (distance).
        """
        a, b, c, d, n = self.__abcdn()
        return (4 * b * c) / (a + b + c + d) ** 2


    @timeit
    @distance

    def shape_difference(self):
        """
        Shape difference

        :math:`\\frac{n(b+c)-(b-c)^2}{(a+b+c+d)^2}`

        :return: Shape difference (distance).
        """
        a, b, c, d, n = self.__abcdn()
        return (n * (b + c) - (b - c) ** 2) / (a + b + c + d) ** 2


    @timeit
    @distance

    def size_difference(self):
        """
        Size difference

        :math:`\\frac{(b+c)^2}{(a+b+c+d)^2}`

        :return: Size difference (distance).
        """
        a, b, c, d, n = self.__abcdn()
        return (b + c) ** 2 / (a + b + c + d) ** 2


    @timeit
    @distance

    def vari(self):
        """
        Vari

        :math:`\\frac{b+c}{4a+4b+4c+4d}`

        :return: Vari (distance).
        """
        a, b, c, d, n = self.__abcdn()
        return (b + c) / (4 * (a + b + c + d))


    @timeit
    @distance

    def yule_q_difference(self):
        """
        Yule's q

        :math:`\\frac{2bc}{ad+bc}`

        :return: Yule's q (distance).
        """
        a, b, c, d, n = self.__abcdn()
        return 2 * b * c / (a * d + b * c)


    @timeit
    @distance

    def tanimoto_distance(self):
        """
        `Tanimoto similarity and distance <https://en.wikipedia.org/wiki/Jaccard_index#Tanimoto_similarity_and_distance>`_.

        :return: Tanimoto distance.
        """
        d = -log2(self.roger_tanimoto())
        return d


    @timeit

    def cramer_v(self):
        """
        `Cramer's V <https://en.wikipedia.org/wiki/Cram%C3%A9r%27s_V>`_.

        :return: Cramer's V.
        """
        *_, n = self.__abcdn()
        chisq = self.chisq()
        s = sqrt(chisq / n)
        return s


    @timeit

    def contingency_coefficient(self):
        """
        `Contingency coefficient <https://en.wikipedia.org/wiki/Contingency_table#Cram%C3%A9r's_V_and_the_contingency_coefficient_C>`_.

        :return: Contingency coefficient.
        """
        *_, n = self.__abcdn()
        chisq = self.chisq()
        s = sqrt(chisq / (n + chisq))
        return s


    @timeit

    def tschuprow_t(self):
        """
        `Tschuprow's T <https://en.wikipedia.org/wiki/Tschuprow%27s_T>`_.

        :return: Tschuprow's T.
        """
        s = sqrt(self.chisq())
        return s


    @timeit

    def mcnemar_test(self):
        """
        `McNemar's test <https://en.wikipedia.org/wiki/McNemar%27s_test>`_.

        :return: A tuple. First element is chi-square test statistics. Second element is p-value.
        """
        a, b, c, d, n = self.__abcdn()
        chisq = (b - c) ** 2 / (b + c)
        p = 1 - stats.chi2.cdf(chisq, 1)
        return chisq, p


    @timeit

    def odds_ratio(self):
        """
        `Odds ratio <https://en.wikipedia.org/wiki/Contingency_table#Odds_ratio>`_. The odds
        ratio is also referred to as the `cross-product ratio`.

        :return: Odds ratio.
        """
        a, b, c, d, n = self.__abcdn()

        p_11 = a / n
        p_10 = b / n
        p_01 = c / n
        p_00 = d / n

        ratio = (p_11 * p_00) / (p_10 * p_01)
        return ratio


    @timeit

    def yule_y(self):
        """
        Yule's Y is based off of the odds ratio or cross-product ratio, :math:`\\alpha`.

        :math:`Y = \\frac{\\sqrt\\alpha - 1}{\\sqrt\\alpha + 1}`

        :return: Yule's Y.
        """
        alpha = sqrt(self.odds_ratio())
        q = (alpha - 1) / (alpha + 1)
        return q


    @timeit

    def tetrachoric(self):
        """
        Tetrachoric correlation ranges from :math:`[-1, 1]`, where 0 indicates no agreement,
        1 indicates perfect agreement and -1 indicates perfect disagreement.

        - if :math:`b=0` or :math:`c=0`, 1.0
        - if :math:`a=0` or :math:`b=0`, -1.0
        - else, :math:`\\frac{y-1}{y+1}, y={\\left(\\frac{da}{bc}\\right)}^{\\frac{\\pi}{4}}`

        References

        - `Tetrachoric correlation <https://www.andrews.edu/~calkins/math/edrm611/edrm13.htm#TETRA>`_.
        - `Tetrachoric Correlation: Definition, Examples, Formula <https://www.statisticshowto.com/tetrachoric-correlation/>`_.
        - `Tetrachoric Correlation Estimation <https://www.real-statistics.com/correlation/polychoric-correlation/tetrachoric-correlation-estimation/>`_.

        :return: Tetrachoric correlation.
        """
        a, b, c, d, n = self.__abcdn()

        if b == 0 or c == 0:
            return 1.0
        if d == 0 or a == 0:
            return -1.0

        y = pow((d * a) / (b * c), pi / 4.0)
        p = (y - 1) / (y + 1)
        return p

    @timeit
    @similarity

    def tversky_index(self, theta=1, phi=0):
        """
        Compute's Tversky's Index.

        :math:`\\frac{a}{a+\\theta b+\\phi c}`

        :math:`\\theta` and :math:`\\phi` are typically between :math:`[0,1]`
        and :math:`\\theta + \\phi = 1`.

        :param theta: Weight :math:`[0,1]` of how important match on row variable is. Default 1.
        :param phi: Weight :math:`[0,1]` of how important match on column variable is. Default 0.
        :return: Tversky's Index.
        """
        a, b, c, _ = self.__abcd
        return a / (a + theta * b + phi * c)


class ConfusionMixin(object):
    """
    Confusion matrix computations.
    """


    def tp(self):
        """
        TP

        :return: TP.
        """
        return self._tp


    def fn(self):
        """
        FN

        :return: FN.
        """
        return self._fn


    def fp(self):
        """
        FP

        :return: FP.
        """
        return self._fp


    def tn(self):
        """
        TN

        :return: TN.
        """
        return self._tn


    def n(self):
        """
        :math:`N = TP + FN + FP + TN`

        :return: N.
        """
        return self._n


    def __counts(self):
        """
        Returns TP, FN, FP, TN, N.

        :return: TP, FN, FP, TN, N.
        """
        return self._tp, self._fn, self._fp, self._tn, self._n



    def tpr(self):
        """
        True positive rate.

        :math:`TPR = \\frac{TP}{TP + FN}`

        Aliases

        - sensitivity
        - recall
        - hit rate
        - power
        - probability of detection

        :return: TPR.
        """
        tp, fn, fp, tn, n = self.__counts()
        return tp / (tp + fn)



    def tnr(self):
        """
        True negative rate.

        :math:`TNR = \\frac{TN}{TN + FP}`

        Aliases

        - specificity
        - selectivity

        :return: TNR.
        """
        tp, fn, fp, tn, n = self.__counts()
        return tn / (tn + fp)



    def ppv(self):
        """
        Positive predictive value.

        :math:`PPV = \\frac{TP}{TP + FP}`

        Aliases

        - precision

        :return: PPV.
        """
        tp, fn, fp, tn, n = self.__counts()
        return tp / (tp + fp)



    def npv(self):
        """
        Negative predictive value.

        :math:`NPV = \\frac{TN}{TN + FN}`

        :return: NPV.
        """
        tp, fn, fp, tn, n = self.__counts()
        return tn / (tn + fn)



    def fnr(self):
        """
        False negative rate.

        :math:`FNR = \\frac{FN}{FN + TP}`

        Aliases

        - miss rate

        :return: FNR.
        """
        tp, fn, fp, tn, n = self.__counts()
        return fn / (fn + tp)



    def fpr(self):
        """
        False positive rate.

        :math:`FPR = \\frac{FP}{FP + TN}`

        Aliases

        - fall-out
        - probability of false alarm

        :return: FPR.
        """
        tp, fn, fp, tn, n = self.__counts()
        return fp / (fp + tn)



    def fdr(self):
        """
        False discovery rate.

        :math:`FDR = \\frac{FP}{FP + TP}`

        :return: FDR.
        """
        tp, fn, fp, tn, n = self.__counts()
        return fp / (fp + tp)



    def fomr(self):
        """
        False omission rate.

        :math:`FOR = \\frac{FN}{FN + TN}`

        :return: FOR.
        """
        tp, fn, fp, tn, n = self.__counts()
        return fn / (fn + tn)



    def pt(self):
        """
        Prevalence threshold.

        :math:`PT = \\frac{\\sqrt{TPR(-TNR + 1)} + TNR - 1}{TPR + TNR - 1}`

        :return: Prevalence threshold.
        """
        tpr = self.tpr()
        tnr = self.tnr()

        return (sqrt(tpr * (-tnr + 1)) + tnr - 1) / (tpr + tnr - 1)



    def ts(self):
        """
        Threat score.

        :math:`TS = \\frac{TP}{TP + FN + FP}`

        Aliases

        - critical success index (CSI).

        :return: TS.
        """
        tp, fn, fp, tn, n = self.__counts()
        return tp / (tp + fn + fp)



    def acc(self):
        """
        Accuracy.

        :math:`ACC = \\frac{TP + TN}{TP + TN + FP + FN}`

        :return: Accuracy.
        """
        tp, fn, fp, tn, n = self.__counts()
        return (tp + tn) / (tp + tn + fp + fn)



    def ba(self):
        """
        Balanced accuracy.

        :math:`BA = \\frac{TPR + TNR}{2}`

        :return: Balanced accuracy.
        """
        return (self.tpr() + self.tnr()) / 2



    def f1(self):
        """
        F1 score: harmonic mean of precision and sensitivity.

        :math:`F1 = \\frac{PPV \\times TPR}{PPV + TPR}`

        :return: F1.
        """
        return 2 * (self.ppv() * self.tpr()) / (self.ppv() + self.tpr())



    def mcc(self):
        """
        Matthew's correlation coefficient.

        :math:`MCC = \\frac{TP + TN - FP \\times FN}{\\sqrt{(TP + FP)(TP + FN)(TN + FP)(TN + FN)}}`

        :return: MCC.
        """
        tp, fn, fp, tn, n = self.__counts()

        return (tp + tn - fp * fn) / sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))



    def bm(self):
        """
        Bookmaker informedness.

        :math:`BI = TPR + TNR - 1`

        :return: BM.
        """
        return self.tpr() + self.tnr() - 1



    def mk(self):
        """
        Markedness.

        :math:`MK = PPV + NPV - 1`

        Aliases

        - deltaP

        :return: Markedness.
        """
        return self.ppv() + self.npv() - 1



    def sensitivity(self):
        """
        Alias to TPR.

        :return: Sensitivity.
        """
        return self.tpr()



    def specificity(self):
        """
        Alias to TNR.

        :return: Specificity.
        """
        return self.tnr()



    def precision(self):
        """
        Alias to PPV.

        :return: PPV.
        """
        return self.ppv()



    def recall(self):
        """
        Alias to TPR.

        :return: TPR.
        """
        return self.tpr()



    def prevalence(self):
        """
        Prevalence.

        :math:`\\frac{TP + FN}{N}`

        :return: Prevalence.
        """
        tp, fn, fp, tn, n = self.__counts()
        return (tp + fn) / n



    def plr(self):
        """
        Positive likelihood ratio.

        :math:`PLR = \\frac{TPR}{FPR}`

        Aliases

        - LR+

        :return: PLR.
        """
        return self.tpr() / self.fpr()



    def nlr(self):
        """
        Negative likelihood ratio.

        :math:`NLR = \\frac{FNR}{TNR}`

        Aliases

        - LR-

        :return: NLR.
        """
        return self.fnr() / self.tnr()



    def dor(self):
        """
        Diagnostic odds ratio.

        :math:`\\frac{PLR}{NLR}`

        :return: DOR.
        """
        return self.plr() / self.nlr()


class AgreementMixin(object):
    """
    Agreement computations.
    """



    def chohen_k(self):
        """
        Computes Cohen's :math:`\\kappa`.

        - :math:`\\kappa = \\frac{\\theta_1 - \\theta_2}{1 - \\theta_2}`
        - :math:`\\theta_1 = \\sum_i p_{ii}`
        - :math:`\\theta_2 = \\sum_i p_{i+}p_{+i}`

        :return: :math:`\\kappa`.
        """
        theta_1 = sum([self._table[i][i] for i in range(self._r)])
        theta_2 = sum([self._r_margs[i] * self._k_margs[i] for i in range(self._r)])
        k = (theta_1 - theta_2) / (1 - theta_2)
        return k



    def cohen_light_k(self):
        """
        Cohen-Light :math:`\\kappa`. :math:`\\kappa` is a measure of conditional agreement.
        Several :math:`\\kappa`, one for each unique value, will be computed and returned.

        - :math:`\\kappa = \\frac{\\theta_1 - \\theta_2}{1 - \\theta_2}`
        - :math:`\\theta_1 = \\frac{p_{ii}}{p_{i+}}`
        - :math:`\\theta_2 = p_{+i}`

        :return: A list of :math:`\\kappa`.
        """
        theta_1 = lambda i: self._table[i][i] / self._r_margs[i]
        theta_2 = lambda i: self._k_margs[i]
        kappa = lambda t_1, t_2: (t_1 - t_2) / (1 - t_2)

        kappas = [kappa(theta_1(i), theta_2(i)) for i in range(self._r)]
        return kappas


class ContingencyTable(MeasureMixin, ABC):
    """
    Abstract contingency table. All other tables inherit from this one.
    """

    def __init__(self, table):
        """
        ctor.

        :param table: A table of counts (list of lists).
        """
        n_rows = len(table)
        n_cols = len(table[0])

        self._r_margs = [sum(table[r]) for r in range(n_rows)]
        self._k_margs = [sum([table[r][c] for r in range(len(table))]) for c in range(n_cols)]
        self._n = sum(self._r_margs)
        self._r = len(self._r_margs)
        self._k = len(self._k_margs)
        self._table = table

    @staticmethod
    def _to_binary_counts(a, b, a_0=0, a_1=1, b_0=0, b_1=1):
        def to_count(x, y):
            _a, _b, _c, _d = 0, 0, 0, 0

            if x == a_1 and y == b_1:
                _a = 1
            elif x == a_1 and y == b_0:
                _b = 1
            elif x == a_0 and y == b_1:
                _c = 1
            else:
                _d = 1
            return _a, _b, _c, _d

        def add_count(x, y):
            return x[0] + y[0], x[1] + y[1], x[2] + y[2], x[3] + y[3]

        is_valid = lambda x, y: x is not None and y is not None

        counts = (to_count(x, y) for x, y in zip(a, b) if is_valid(x, y))
        counts = reduce(lambda x, y: add_count(x, y), counts)
        counts = add_count(counts, (1, 1, 1, 1))
        return counts

    @staticmethod
    def _to_categorical_counts(a, b, a_vals=None, b_vals=None):
        df = pd.DataFrame({'a': a, 'b': b})
        contingency_table = pd.crosstab(df['a'], df['b'])
        table = contingency_table.values.tolist()
        return table


class CategoricalTable(CategoricalMixin, ContingencyTable):
    """
    Represents a contingency table for categorical variables.

    References

    - `Contingency table <https://en.wikipedia.org/wiki/Contingency_table>`_
    - `More Correlation Coefficients <https://www.andrews.edu/~calkins/math/edrm611/edrm13.htm#TETRA>`_
    """

    def __init__(self, a, b, a_vals=None, b_vals=None):
        """
        ctor. If `a_vals` or `b_vals` are `None`, then the possible
        values will be determined empirically from the data.

        :param a: Iterable list.
        :param b: Iterable list.
        :param a_vals: All possible values in a. Defaults to `None`.
        :param b_vals: All possible values in b. Defaults to `None`.
        """
        table = ContingencyTable._to_categorical_counts(a, b, a_vals=a_vals, b_vals=b_vals)
        super().__init__(table)


class BinaryTable(CategoricalMixin, BinaryMixin, ContingencyTable):
    """
    Represents a contingency table for binary variables.
    """

    def __init__(self, a, b, a_0=0, a_1=1, b_0=0, b_1=1):
        """
        ctor.

        :param a: Iterable list.
        :param b: Iterable list.
        :param a_0: The zero value for a. Defaults to 0.
        :param a_1: The one value for a. Defaults to 1.
        :param b_0: The zero value for b. Defaults to 0.
        :param b_1: The zero value for b. Defaults to 1.
        """
        self.n = len(a)
        a, b, c, d = ContingencyTable._to_binary_counts(a, b, a_0=a_0, a_1=a_1, b_0=b_0, b_1=b_1)
        super().__init__([[a, b], [c, d]])
        self._a = a
        self._b = b
        self._c = c
        self._d = d


class ConfusionMatrix(ConfusionMixin, ContingencyTable):
    """
    Represents a `confusion matrix <https://en.wikipedia.org/wiki/Confusion_matrix>`_. The confusion
    matrix looks like what is shown below for two binary variables `a` and `b`;
    `a` is in the rows and `b` in the columns. Most of the statistics around performance comes
    from the counts of `TN`, `FN`, `FP` and `TP`.

    .. list-table:: Confusion Matrix
       :widths: 25 25 25

       * -
         - b=0
         - b=1
       * - a=0
         - TN
         - FP
       * - a=1
         - FN
         - TP
    """

    def __init__(self, a, b, a_0=0, a_1=1, b_0=0, b_1=1):
        """
        ctor. Note that `a` is the ground truth and `b` is the prediction.

        :param a: Binary variable (iterable). Ground truth.
        :param b: Binary variable (iterable). Prediction.
        :param a_0: The zero value for a. Defaults to 0.
        :param a_1: The one value for a. Defaults to 1.
        :param b_0: The zero value for b. Defaults to 0.
        :param b_1: The zero value for b. Defaults to 1.
        """
        tp, fn, fp, tn = ContingencyTable._to_binary_counts(a, b, a_0=a_0, a_1=a_1, b_0=b_0, b_1=b_1)
        super().__init__([[tp, fn], [fp, tn]])
        self._tp = tp
        self._fn = fn
        self._fp = fp
        self._tn = tn


class AgreementTable(AgreementMixin, ContingencyTable):
    """
    Represents a contingency table for agreement data against one variable. The variable is typically
    a rating variable (e.g. dislike, neutral, like), and the data is a pairing of ratings over
    the same set of items. The agreement table that is induced by the data is typically squared,
    where the number of rows and columns are equal.
    """

    def __init__(self, a, b, a_vals=None, b_vals=None):
        """
        ctor.

        :param a: Categorical variable.
        :param b: Categorical variable.
        :param a_vals: Values in `a`. Default `None`; figure out empirically.
        :param b_vals: Values in `b`. Default `None`; figure out empirically.
        """
        table = ContingencyTable._to_categorical_counts(a, b, a_vals=a_vals, b_vals=b_vals)
        super().__init__(table)

        if self._k != self._r:
            raise ValueError(f'Table not symmetric: rows={self._r}, cols={self._k}')


class CategoricalStats(CategoricalMixin, ContingencyTable):
    """
    Computes categorical stats.
    """

    def __init__(self, table):
        """
        ctor.

        :param table: Contingency table.
        """
        super().__init__(table)


class BinaryStats(CategoricalMixin, BinaryMixin, ContingencyTable):
    """
    Computes binary stats.
    """

    def __init__(self, table):
        """
        ctor.

        :param table: Contingency table.
        """
        super().__init__(table)
        self._a = table[0][0]
        self._b = table[0][1]
        self._c = table[1][0]
        self._d = table[1][1]


class ConfusionStats(ConfusionMixin, ContingencyTable):
    """
    Computes confusion matrix stats.
    """

    def __init__(self, table):
        """
        ctor.

        :param table: Contingency table.
        """
        super().__init__(table)
        self._tp = table[0][0]
        self._fn = table[0][1]
        self._fp = table[1][0]
        self._tn = table[1][1]


class AgreementStats(AgreementMixin, ContingencyTable):
    """
    Computes agreement stats.
    """

    def __init__(self, table):
        """
        ctor.

        :param table: Contingency table.
        """
        super().__init__(table)
        if self._k != self._r:
            raise ValueError(f'Table not symmetric: rows={self._r}, cols={self._k}')

# %%
from tempfile import tempdir
import time
def extract_measures_to_matrix(matrix, measure_class):
    """
    Extracts measures from a pypair measure class and creates a matrix.
    Args:
        measure_class: A pypair measure class (e.g., AgreementMixin).
    Returns:
        tuple:
            - measure_matrix (torch.Tensor): Matrix where each cell contains a dictionary of measures.
            - feature_names (list): List of corresponding feature names.
    """
    feature_names = ['workclass_?', 'workclass_Federal-gov', 'workclass_Local-gov'
, 'workclass_Never-worked', 'workclass_Private', 'workclass_Self-emp-inc'
, 'workclass_Self-emp-not-inc', 'workclass_State-gov'
, 'workclass_Without-pay', 'workclass_nan', 'education_10th', 'education_11th'
, 'education_12th', 'education_1st-4th', 'education_5th-6th'
, 'education_7th-8th', 'education_9th', 'education_Assoc-acdm'
, 'education_Assoc-voc', 'education_Bachelors', 'education_Doctorate'
, 'education_HS-grad', 'education_Masters', 'education_Preschool'
, 'education_Prof-school', 'education_Some-college'
, 'marital-status_Divorced', 'marital-status_Married-AF-spouse'
, 'marital-status_Married-civ-spouse'
, 'marital-status_Married-spouse-absent', 'marital-status_Never-married'
, 'marital-status_Separated', 'marital-status_Widowed', 'occupation_?'
, 'occupation_Adm-clerical', 'occupation_Armed-Forces'
, 'occupation_Craft-repair', 'occupation_Exec-managerial'
, 'occupation_Farming-fishing', 'occupation_Handlers-cleaners'
, 'occupation_Machine-op-inspct', 'occupation_Other-service'
, 'occupation_Priv-house-serv', 'occupation_Prof-specialty'
, 'occupation_Protective-serv', 'occupation_Sales', 'occupation_Tech-support'
, 'occupation_Transport-moving', 'occupation_nan', 'relationship_Husband'
, 'relationship_Not-in-family', 'relationship_Other-relative'
, 'relationship_Own-child', 'relationship_Unmarried', 'relationship_Wife'
, 'race_Amer-Indian-Eskimo', 'race_Asian-Pac-Islander', 'race_Black'
, 'race_Other', 'race_White', 'sex_Male', 'native-country_?'
, 'native-country_Cambodia', 'native-country_Canada', 'native-country_China'
, 'native-country_Columbia', 'native-country_Cuba'
, 'native-country_Dominican-Republic', 'native-country_Ecuador'
, 'native-country_El-Salvador', 'native-country_England'
, 'native-country_France', 'native-country_Germany', 'native-country_Greece'
, 'native-country_Guatemala', 'native-country_Haiti'
, 'native-country_Holand-Netherlands', 'native-country_Honduras'
, 'native-country_Hong', 'native-country_Hungary', 'native-country_India'
, 'native-country_Iran', 'native-country_Ireland', 'native-country_Italy'
, 'native-country_Jamaica', 'native-country_Japan', 'native-country_Laos'
, 'native-country_Mexico', 'native-country_Nicaragua'
, 'native-country_Outlying-US(Guam-USVI-etc)', 'native-country_Peru'
, 'native-country_Philippines', 'native-country_Poland'
, 'native-country_Portugal', 'native-country_Puerto-Rico'
, 'native-country_Scotland', 'native-country_South', 'native-country_Taiwan'
, 'native-country_Thailand', 'native-country_Trinadad&Tobago'
, 'native-country_United-States', 'native-country_Vietnam'
, 'native-country_Yugoslavia', 'native-country_nan', 'income_>50K'
, 'capital-gain-binary_1', 'capital-loss-binary_1']
    # Calculate measures pairwise
    for i in range(len(feature_names)):
        X_col_i = X_encoded[:, i]
        for j in range(i + 1, len(feature_names)):
            if not ((i>=105 and i<107) or (j>=105 and j<107)):
              continue
            start_time = time.time()
            X_col_j = X_encoded[:, j]
            if issubclass(measure_class, ConfusionMixin):
                table = ConfusionMatrix(X_col_i, X_col_j)
                measures = ['acc', 'ba', 'bm', 'dor', 'f1', 'fdr', 'fn', 'fnr', 'fomr', 'fp', 'fpr', 'mcc', 'mk', 'n', 'nlr', 'npv', 'plr', 'ppv', 'precision', 'prevalence', 'pt', 'recall', 'sensitivity', 'specificity', 'tn', 'tnr', 'tp', 'tpr', 'ts']
            elif issubclass(measure_class, AgreementMixin):
                table = AgreementTable(X_col_i, X_col_j)
                measures = ['chohen_k', 'cohen_light_k']
            elif issubclass(measure_class, BinaryMixin):
                table = BinaryTable(X_col_i, X_col_j)
                measures = ['ample', 'anderberg', 'baroni_urbani_buser_i', 'baroni_urbani_buser_ii', 'braun_banquet', 'chisq', 'chord', 'cole_i', 'cole_ii', 'contingency_coefficient', 'cosine', 'cramer_v', 'dennis', 'dice', 'disperson', 'driver_kroeber', 'euclid', 'eyraud', 'fager_mcgowan', 'faith', 'forbes_ii', 'forbesi', 'fossum', 'gilbert_wells', 'goodman_kruskal', 'gower', 'gower_legendre', 'hamann', 'hamming', 'hellinger', 'inner_product', 'intersection', 'jaccard', 'jaccard_3w', 'jaccard_distance', 'johnson', 'kulcyznski_ii', 'kulczynski_i', 'lance_williams', 'mcconnaughey', 'mcnemar_test', 'mean_manhattan', 'michael', 'mountford', 'ochia_i', 'ochia_ii', 'odds_ratio', 'pattern_difference', 'pearson_heron_i', 'pearson_heron_ii', 'pearson_i', 'peirce', 'person_ii', 'roger_tanimoto', 'russel_rao', 'shape_difference', 'simpson', 'size_difference', 'sokal_michener', 'sokal_sneath_i', 'sokal_sneath_ii', 'sokal_sneath_iii', 'sokal_sneath_iv', 'sokal_sneath_v', 'sorensen_dice', 'sorgenfrei', 'stiles', 'tanimoto_distance', 'tanimoto_i', 'tanimoto_ii', 'tarantula', 'tarwid', 'tetrachoric', 'tschuprow_t', 'vari', 'yule_q', 'yule_q_difference', 'yule_w', 'yule_y']
            else:
                table = CategoricalTable(X_col_i, X_col_j)
                measures = ['adjusted_rand_index', 'chisq', 'chisq_dof', 'gk_lambda', 'gk_lambda_reversed', 'mutual_information', 'phi', 'uncertainty_coefficient', 'uncertainty_coefficient_reversed']
            for measure_name in measures:
                start_time = time.time()
                try:
                    exists=True
                    if measure_name == 'chohen_k':
                      measure_value = table.chohen_k()
                    elif measure_name == 'ample':
                      measure_value = table.ample()
                    elif measure_name == 'anderberg':
                      measure_value = table.anderberg()
                    elif measure_name == 'baroni_urbani_buser_i':
                      measure_value = table.baroni_urbani_buser_i()
                    elif measure_name == 'baroni_urbani_buser_ii':
                      measure_value = table.baroni_urbani_buser_ii()
                    elif measure_name == 'braun_banquet':
                      measure_value = table.braun_banquet()
                    elif measure_name == 'chisq':
                      measure_value = table.chisq()
                    elif measure_name == 'chord':
                      measure_value = table.chord()
                    elif measure_name == 'cole_i':
                      measure_value = table.cole_i()
                    elif measure_name == 'cole_ii':
                      measure_value = table.cole_ii()
                    elif measure_name == 'contingency_coefficient':
                      measure_value = table.contingency_coefficient()
                    elif measure_name == 'cosine':
                      measure_value = table.cosine()
                    elif measure_name == 'cramer_v':
                      measure_value = table.cramer_v()
                    elif measure_name == 'dennis':
                      measure_value = table.dennis()
                    elif measure_name == 'dice':
                      measure_value = table.dice()
                    elif measure_name == 'disperson':
                      measure_value = table.disperson()
                    elif measure_name == 'driver_kroeber':
                      measure_value = table.driver_kroeber()
                    elif measure_name == 'euclid':
                      measure_value = table.euclid()
                    elif measure_name == 'eyraud':
                      measure_value = table.eyraud()
                    elif measure_name == 'fager_mcgowan':
                      measure_value = table.fager_mcgowan()
                    elif measure_name == 'faith':
                      measure_value = table.faith()
                    elif measure_name == 'forbes_ii':
                      measure_value = table.forbes_ii()
                    elif measure_name == 'forbesi':
                      measure_value = table.forbesi()
                    elif measure_name == 'fossum':
                      measure_value = table.fossum()
                    elif measure_name == 'gilbert_wells':
                      measure_value = table.gilbert_wells()
                    elif measure_name == 'goodman_kruskal':
                      measure_value = table.goodman_kruskal()
                    elif measure_name == 'gower':
                      measure_value = table.gower()
                    elif measure_name == 'gower_legendre':
                      measure_value = table.gower_legendre()
                    elif measure_name == 'hamann':
                      measure_value = table.hamann()
                    elif measure_name == 'hamming':
                      measure_value = table.hamming()
                    elif measure_name == 'hellinger':
                      measure_value = table.hellinger()
                    elif measure_name == 'inner_product':
                      measure_value = table.inner_product()
                    elif measure_name == 'intersection':
                      measure_value = table.intersection()
                    elif measure_name == 'jaccard':
                      measure_value = table.jaccard()
                    elif measure_name == 'jaccard_3w':
                      measure_value = table.jaccard_3w()
                    elif measure_name == 'jaccard_distance':
                      measure_value = table.jaccard_distance()
                    elif measure_name == 'johnson':
                      measure_value = table.johnson()
                    elif measure_name == 'kulcyznski_ii':
                      measure_value = table.kulcyznski_ii()
                    elif measure_name == 'kulczynski_i':
                      measure_value = table.kulczynski_i()
                    elif measure_name == 'lance_williams':
                      measure_value = table.lance_williams()
                    elif measure_name == 'mcconnaughey':
                      measure_value = table.mcconnaughey()
                    elif measure_name == 'mcnemar_test':
                      measure_value = table.mcnemar_test()
                    elif measure_name == 'mean_manhattan':
                      measure_value = table.mean_manhattan()
                    elif measure_name == 'michael':
                      measure_value = table.michael()
                    elif measure_name == 'mountford':
                      measure_value = table.mountford()
                    elif measure_name == 'ochia_i':
                      measure_value = table.ochia_i()
                    elif measure_name == 'ochia_ii':
                      measure_value = table.ochia_ii()
                    elif measure_name == 'odds_ratio':
                      measure_value = table.odds_ratio()
                    elif measure_name == 'pattern_difference':
                      measure_value = table.pattern_difference()
                    elif measure_name == 'pearson_heron_i':
                      measure_value = table.pearson_heron_i()
                    elif measure_name == 'pearson_heron_ii':
                      measure_value = table.pearson_heron_ii()
                    elif measure_name == 'pearson_i':
                      measure_value = table.pearson_i()
                    elif measure_name == 'peirce':
                      measure_value = table.peirce()
                    elif measure_name == 'person_ii':
                      measure_value = table.person_ii()
                    elif measure_name == 'roger_tanimoto':
                      measure_value = table.roger_tanimoto()
                    elif measure_name == 'russel_rao':
                      measure_value = table.russel_rao()
                    elif measure_name == 'shape_difference':
                      measure_value = table.shape_difference()
                    elif measure_name == 'simpson':
                      measure_value = table.simpson()
                    elif measure_name == 'size_difference':
                      measure_value = table.size_difference()
                    elif measure_name == 'sokal_michener':
                      measure_value = table.sokal_michener()
                    elif measure_name == 'sokal_sneath_i':
                      measure_value = table.sokal_sneath_i()
                    elif measure_name == 'sokal_sneath_ii':
                      measure_value = table.sokal_sneath_ii()
                    elif measure_name == 'sokal_sneath_iii':
                      measure_value = table.sokal_sneath_iii()
                    elif measure_name == 'sokal_sneath_iv':
                      measure_value = table.sokal_sneath_iv()
                    elif measure_name == 'sokal_sneath_v':
                      measure_value = table.sokal_sneath_v()
                    elif measure_name == 'sorensen_dice':
                      measure_value = table.sorensen_dice()
                    elif measure_name == 'sorgenfrei':
                      measure_value = table.sorgenfrei()
                    elif measure_name == 'stiles':
                      measure_value = table.stiles()
                    elif measure_name == 'tanimoto_distance':
                      measure_value = table.tanimoto_distance()
                    elif measure_name == 'tanimoto_i':
                      measure_value = table.tanimoto_i()
                    elif measure_name == 'tanimoto_ii':
                      measure_value = table.tanimoto_ii()
                    elif measure_name == 'tarantula':
                      measure_value = table.tarantula()
                    elif measure_name == 'tarwid':
                      measure_value = table.tarwid()
                    elif measure_name == 'tetrachoric':
                      measure_value = table.tetrachoric()
                    elif measure_name == 'tschuprow_t':
                      measure_value = table.tschuprow_t()
                    elif measure_name == 'vari':
                      measure_value = table.vari()
                    elif measure_name == 'yule_q':
                      measure_value = table.yule_q()
                    elif measure_name == 'yule_q_difference':
                      measure_value = table.yule_q_difference()
                    elif measure_name == 'yule_w':
                      measure_value = table.yule_w()
                    elif measure_name == 'yule_y':
                      measure_value = table.yule_y()
                    elif measure_name == 'adjusted_rand_index':
                      measure_value = table.adjusted_rand_index()
                    elif measure_name == 'chisq':
                      measure_value = table.chisq()
                    elif measure_name == 'chisq_dof':
                      measure_value = table.chisq_dof()
                    elif measure_name == 'gk_lambda':
                      measure_value = table.gk_lambda()
                    elif measure_name == 'gk_lambda_reversed':
                      measure_value = table.gk_lambda_reversed()
                    elif measure_name == 'phi':
                      measure_value = table.phi()
                    elif measure_name == 'acc':
                      measure_value = table.acc()
                    elif measure_name == 'ba':
                      measure_value = table.ba()
                    elif measure_name == 'bm':
                      measure_value = table.bm()
                    elif measure_name == 'dor':
                      measure_value = table.dor()
                    elif measure_name == 'f1':
                      measure_value = table.f1()
                    elif measure_name == 'fdr':
                      measure_value = table.fdr()
                    elif measure_name == 'fn':
                      measure_value = table.fn()
                    elif measure_name == 'fnr':
                      measure_value = table.fnr()
                    elif measure_name == 'fomr':
                      measure_value = table.fomr()
                    elif measure_name == 'fp':
                      measure_value = table.fp()
                    elif measure_name == 'fpr':
                      measure_value = table.fpr()
                    elif measure_name == 'mcc':
                      measure_value = table.mcc()
                    elif measure_name == 'mk':
                      measure_value = table.mk()
                    elif measure_name == 'n':
                      measure_value = table.n()
                    elif measure_name == 'nlr':
                      measure_value = table.nlr()
                    elif measure_name == 'npv':
                      measure_value = table.npv()
                    elif measure_name == 'plr':
                      measure_value = table.plr()
                    elif measure_name == 'ppv':
                      measure_value = table.ppv()
                    elif measure_name == 'precision':
                      measure_value = table.precision()
                    elif measure_name == 'prevalence':
                      measure_value = table.prevalence()
                    elif measure_name == 'pt':
                      measure_value = table.pt()
                    elif measure_name == 'recall':
                      measure_value = table.recall()
                    elif measure_name == 'sensitivity':
                      measure_value = table.sensitivity()
                    elif measure_name == 'specificity':
                      measure_value = table.specificity()
                    elif measure_name == 'tn':
                      measure_value = table.tn()
                    elif measure_name == 'tnr':
                      measure_value = table.tnr()
                    elif measure_name == 'tp':
                      measure_value = table.tp()
                    elif measure_name == 'tpr':
                      measure_value = table.tpr()
                    elif measure_name == 'ts':
                      measure_value = table.tpr()
                    else:
                      measure_value = None
                      exists=False
                    if exists:
                      matrix[i][j][measure_name] = measure_value
                      matrix[j][i][measure_name] = measure_value
                      end_time = time.time()
                      processed = end_time - start_time
                      print(feature_names[i], "-", feature_names[j]," - ",measure_name, ": ",measure_value, f"- {processed:4f} s")
                except Exception as e:
                    print(f"Error calculating {measure_name}: {e}")

    return matrix, feature_names

import pickle



def load_measure_matrix(filename):
    with open(filename, 'rb') as f:
        data = pickle.load(f)
    return data['matrix'], data['feature_names']


def process_matrix(filename):
  matrix, feature_names = load_measure_matrix(filename)
  temp = [[{} for _ in range(len(matrix))] for _ in range(len(matrix))]
  for i in range(len(matrix)):
      for j in range(len(matrix[i])):
          k, l = i, j
          if i >= 60 and i < 107:
              k += 1
              if i >= 105:
                  k += 1
          if j >= 60 and j < 107:
              l += 1
              if j >= 105:
                  l += 1
          if (k >= 107 and i < 107) or (l >= 107 and j < 107):
              continue
          if k < len(matrix) and l < len(matrix[k]):
              temp[i][j] = matrix[k][l]
  return temp

import time
measure_classes = [AgreementMixin, BinaryMixin,CategoricalMixin,ConfusionMixin]
import pickle
ll = 0
for measure_class in measure_classes:
    if ll == 0:
      matrix, feature_names = extract_measures_to_matrix(process_matrix('agreement_matrix.pkl'),measure_class)
    if ll == 1:
      matrix, feature_names = extract_measures_to_matrix(process_matrix('binary_matrix.pkl'),measure_class)
    if ll == 2:
      matrix, feature_names = extract_measures_to_matrix(process_matrix('categorical_matrix.pkl'),measure_class)
    if ll == 3:
      matrix, feature_names = extract_measures_to_matrix(process_matrix('confusion_matrix.pkl'),measure_class)

    matrix_name = measure_class.__name__.lower().replace('mixin', '') + '_matrixv3.pkl'
    with open(matrix_name, 'wb') as f:
        pickle.dump({'matrix': matrix, 'feature_names': feature_names}, f)
    if matrix_name=='agreement_matrixv3.pkl':
      # !cp 'agreement_matrixv3.pkl' /content/drive/MyDrive
    if matrix_name=='binary_matrixv3.pkl':
      # !cp 'binary_matrixv3.pkl' /content/drive/MyDrive
    if matrix_name=='categorical_matrixv3.pkl':
      # !cp 'categorical_matrixv3.pkl' /content/drive/MyDrive
    if matrix_name=='confusion_matrixv3.pkl':
      # !cp 'confusion_matrixv3.pkl' /content/drive/MyDrive
# Out:
# Streaming output truncated to the last 5000 lines.
# education_Bachelors - capital-gain-binary_1  -  ppv :  0.23160762942779292 - 0.000005 s
# education_Bachelors - capital-gain-binary_1  -  precision :  0.23160762942779292 - 0.000005 s
# education_Bachelors - capital-gain-binary_1  -  prevalence :  0.16433280104819228 - 0.000004 s
# education_Bachelors - capital-gain-binary_1  -  pt :  0.4468168174297853 - 0.000008 s
# education_Bachelors - capital-gain-binary_1  -  recall :  0.11648187367634234 - 0.000038 s
# education_Bachelors - capital-gain-binary_1  -  sensitivity :  0.11648187367634234 - 0.000013 s
# education_Bachelors - capital-gain-binary_1  -  specificity :  0.9240059776084667 - 0.000015 s
# education_Bachelors - capital-gain-binary_1  -  tn :  37717 - 0.000005 s
# education_Bachelors - capital-gain-binary_1  -  tnr :  0.9240059776084667 - 0.000004 s
# education_Bachelors - capital-gain-binary_1  -  tp :  935 - 0.000005 s
# education_Bachelors - capital-gain-binary_1  -  tpr :  0.11648187367634234 - 0.000009 s
# education_Bachelors - capital-gain-binary_1  -  ts :  0.11648187367634234 - 0.000004 s
# education_Bachelors - capital-loss-binary_1  -  acc :  0.8106907423330467 - 0.000018 s
# education_Bachelors - capital-loss-binary_1  -  ba :  0.5116775643832677 - 0.000008 s
# education_Bachelors - capital-loss-binary_1  -  bm :  0.02335512876653545 - 0.000007 s
# education_Bachelors - capital-loss-binary_1  -  dor :  1.5827632424660578 - 0.000009 s
# education_Bachelors - capital-loss-binary_1  -  f1 :  0.10319076714188728 - 0.000008 s
# education_Bachelors - capital-loss-binary_1  -  fdr :  0.7670753064798599 - 0.000005 s
# education_Bachelors - capital-loss-binary_1  -  fn :  7495 - 0.000005 s
# education_Bachelors - capital-loss-binary_1  -  fnr :  0.9337236825713218 - 0.000005 s
# education_Bachelors - capital-loss-binary_1  -  fomr :  0.16096817147029766 - 0.000005 s
# education_Bachelors - capital-loss-binary_1  -  fp :  1752 - 0.000005 s
# education_Bachelors - capital-loss-binary_1  -  fpr :  0.04292118866214263 - 0.000006 s
# education_Bachelors - capital-loss-binary_1  -  mcc :  -0.07013299933782534 - 0.000008 s
# education_Bachelors - capital-loss-binary_1  -  mk :  0.0719565220498426 - 0.000007 s
# education_Bachelors - capital-loss-binary_1  -  n :  48846 - 0.000005 s
# education_Bachelors - capital-loss-binary_1  -  nlr :  0.9755974863408704 - 0.000005 s
# education_Bachelors - capital-loss-binary_1  -  npv :  0.8390318285297024 - 0.000005 s
# education_Bachelors - capital-loss-binary_1  -  plr :  1.5441398408226117 - 0.000005 s
# education_Bachelors - capital-loss-binary_1  -  ppv :  0.2329246935201401 - 0.000004 s
# education_Bachelors - capital-loss-binary_1  -  precision :  0.2329246935201401 - 0.000005 s
# education_Bachelors - capital-loss-binary_1  -  prevalence :  0.16433280104819228 - 0.000005 s
# education_Bachelors - capital-loss-binary_1  -  pt :  0.44590418919123076 - 0.000007 s
# education_Bachelors - capital-loss-binary_1  -  recall :  0.0662763174286782 - 0.000023 s
# education_Bachelors - capital-loss-binary_1  -  sensitivity :  0.0662763174286782 - 0.000005 s
# education_Bachelors - capital-loss-binary_1  -  specificity :  0.9570788113378573 - 0.000005 s
# education_Bachelors - capital-loss-binary_1  -  tn :  39067 - 0.000008 s
# education_Bachelors - capital-loss-binary_1  -  tnr :  0.9570788113378573 - 0.000005 s
# education_Bachelors - capital-loss-binary_1  -  tp :  532 - 0.000005 s
# education_Bachelors - capital-loss-binary_1  -  tpr :  0.0662763174286782 - 0.000005 s
# education_Bachelors - capital-loss-binary_1  -  ts :  0.0662763174286782 - 0.000004 s
# education_Doctorate - capital-gain-binary_1  -  acc :  0.9099823936453343 - 0.000017 s
# education_Doctorate - capital-gain-binary_1  -  ba :  0.5583818896268735 - 0.000013 s
# education_Doctorate - capital-gain-binary_1  -  bm :  0.11676377925374704 - 0.000015 s
# education_Doctorate - capital-gain-binary_1  -  dor :  2.792456234565859 - 0.000009 s
# education_Doctorate - capital-gain-binary_1  -  f1 :  0.050938916468810706 - 0.000006 s
# education_Doctorate - capital-gain-binary_1  -  fdr :  0.9707703740401288 - 0.000005 s
# education_Doctorate - capital-gain-binary_1  -  fn :  478 - 0.000004 s
# education_Doctorate - capital-gain-binary_1  -  fnr :  0.802013422818792 - 0.000004 s
# education_Doctorate - capital-gain-binary_1  -  fomr :  0.01066749983262291 - 0.000004 s
# education_Doctorate - capital-gain-binary_1  -  fp :  3919 - 0.000005 s
# education_Doctorate - capital-gain-binary_1  -  fpr :  0.08122279792746114 - 0.000005 s
# education_Doctorate - capital-gain-binary_1  -  mcc :  -0.02535655566139837 - 0.000007 s
# education_Doctorate - capital-gain-binary_1  -  mk :  0.01856212612724817 - 0.000006 s
# education_Doctorate - capital-gain-binary_1  -  n :  48846 - 0.000004 s
# education_Doctorate - capital-gain-binary_1  -  nlr :  0.8729139349666534 - 0.000006 s
# education_Doctorate - capital-gain-binary_1  -  npv :  0.9893325001673771 - 0.000004 s
# education_Doctorate - capital-gain-binary_1  -  plr :  2.4375739599370476 - 0.000005 s
# education_Doctorate - capital-gain-binary_1  -  ppv :  0.02922962595987119 - 0.000004 s
# education_Doctorate - capital-gain-binary_1  -  precision :  0.02922962595987119 - 0.000005 s
# education_Doctorate - capital-gain-binary_1  -  prevalence :  0.012201613233427507 - 0.000005 s
# education_Doctorate - capital-gain-binary_1  -  pt :  0.3904308238727815 - 0.000008 s
# education_Doctorate - capital-gain-binary_1  -  recall :  0.19798657718120805 - 0.000023 s
# education_Doctorate - capital-gain-binary_1  -  sensitivity :  0.19798657718120805 - 0.000005 s
# education_Doctorate - capital-gain-binary_1  -  specificity :  0.9187772020725389 - 0.000005 s
# education_Doctorate - capital-gain-binary_1  -  tn :  44331 - 0.000005 s
# education_Doctorate - capital-gain-binary_1  -  tnr :  0.9187772020725389 - 0.000004 s
# education_Doctorate - capital-gain-binary_1  -  tp :  118 - 0.000005 s
# education_Doctorate - capital-gain-binary_1  -  tpr :  0.19798657718120805 - 0.000005 s
# education_Doctorate - capital-gain-binary_1  -  ts :  0.19798657718120805 - 0.000004 s
# education_Doctorate - capital-loss-binary_1  -  acc :  0.9438643901240634 - 0.000018 s
# education_Doctorate - capital-loss-binary_1  -  ba :  0.5349325381646208 - 0.000012 s
# education_Doctorate - capital-loss-binary_1  -  bm :  0.06986507632924166 - 0.000005 s
# education_Doctorate - capital-loss-binary_1  -  dor :  2.721152569379896 - 0.000007 s
# education_Doctorate - capital-loss-binary_1  -  f1 :  0.04791666666666666 - 0.000008 s
# education_Doctorate - capital-loss-binary_1  -  fdr :  0.9697898423817863 - 0.000005 s
# education_Doctorate - capital-loss-binary_1  -  fn :  527 - 0.000005 s
# education_Doctorate - capital-loss-binary_1  -  fnr :  0.8842281879194631 - 0.000004 s
# education_Doctorate - capital-loss-binary_1  -  fomr :  0.011318242343541944 - 0.000005 s
# education_Doctorate - capital-loss-binary_1  -  fp :  2215 - 0.000005 s
# education_Doctorate - capital-loss-binary_1  -  fpr :  0.045906735751295336 - 0.000005 s
# education_Doctorate - capital-loss-binary_1  -  mcc :  -0.02027439132212461 - 0.000007 s
# education_Doctorate - capital-loss-binary_1  -  mk :  0.0188919152746716 - 0.000006 s
# education_Doctorate - capital-loss-binary_1  -  n :  48846 - 0.000004 s
# education_Doctorate - capital-loss-binary_1  -  nlr :  0.9267733261021852 - 0.000005 s
# education_Doctorate - capital-loss-binary_1  -  npv :  0.988681757656458 - 0.000005 s
# education_Doctorate - capital-loss-binary_1  -  plr :  2.521891617555714 - 0.000005 s
# education_Doctorate - capital-loss-binary_1  -  ppv :  0.03021015761821366 - 0.000004 s
# education_Doctorate - capital-loss-binary_1  -  precision :  0.03021015761821366 - 0.000005 s
# education_Doctorate - capital-loss-binary_1  -  prevalence :  0.012201613233427507 - 0.000004 s
# education_Doctorate - capital-loss-binary_1  -  pt :  0.38639182423747676 - 0.000008 s
# education_Doctorate - capital-loss-binary_1  -  recall :  0.11577181208053691 - 0.000023 s
# education_Doctorate - capital-loss-binary_1  -  sensitivity :  0.11577181208053691 - 0.000005 s
# education_Doctorate - capital-loss-binary_1  -  specificity :  0.9540932642487047 - 0.000007 s
# education_Doctorate - capital-loss-binary_1  -  tn :  46035 - 0.000005 s
# education_Doctorate - capital-loss-binary_1  -  tnr :  0.9540932642487047 - 0.000005 s
# education_Doctorate - capital-loss-binary_1  -  tp :  69 - 0.000005 s
# education_Doctorate - capital-loss-binary_1  -  tpr :  0.11577181208053691 - 0.000005 s
# education_Doctorate - capital-loss-binary_1  -  ts :  0.11577181208053691 - 0.000005 s
# education_HS-grad - capital-gain-binary_1  -  acc :  0.6363468861319248 - 0.000016 s
# education_HS-grad - capital-gain-binary_1  -  ba :  0.48714592497705816 - 0.000007 s
# education_HS-grad - capital-gain-binary_1  -  bm :  -0.02570815004588367 - 0.000008 s
# education_HS-grad - capital-gain-binary_1  -  dor :  0.6976265194171041 - 0.000008 s
# education_HS-grad - capital-gain-binary_1  -  f1 :  0.10391968924986128 - 0.000006 s
# education_HS-grad - capital-gain-binary_1  -  fdr :  0.744860044587565 - 0.000005 s
# education_HS-grad - capital-gain-binary_1  -  fn :  14756 - 0.000004 s
# education_HS-grad - capital-gain-binary_1  -  fnr :  0.9347523121753453 - 0.000005 s
# education_HS-grad - capital-gain-binary_1  -  fomr :  0.3293088442054052 - 0.000004 s
# education_HS-grad - capital-gain-binary_1  -  fp :  3007 - 0.000005 s
# education_HS-grad - capital-gain-binary_1  -  fpr :  0.09095583787053842 - 0.000005 s
# education_HS-grad - capital-gain-binary_1  -  mcc :  -0.14431060963343634 - 0.000008 s
# education_HS-grad - capital-gain-binary_1  -  mk :  -0.07416888879297023 - 0.000005 s
# education_HS-grad - capital-gain-binary_1  -  n :  48846 - 0.000004 s
# education_HS-grad - capital-gain-binary_1  -  nlr :  1.0282804192765087 - 0.000005 s
# education_HS-grad - capital-gain-binary_1  -  npv :  0.6706911557945948 - 0.000005 s
# education_HS-grad - capital-gain-binary_1  -  plr :  0.7173556898846313 - 0.000005 s
# education_HS-grad - capital-gain-binary_1  -  ppv :  0.25513995541243495 - 0.000004 s
# education_HS-grad - capital-gain-binary_1  -  precision :  0.25513995541243495 - 0.000005 s
# education_HS-grad - capital-gain-binary_1  -  prevalence :  0.32317897064242723 - 0.000004 s
# education_HS-grad - capital-gain-binary_1  -  pt :  0.5414277417579422 - 0.000008 s
# education_HS-grad - capital-gain-binary_1  -  recall :  0.06524768782465476 - 0.000024 s
# education_HS-grad - capital-gain-binary_1  -  sensitivity :  0.06524768782465476 - 0.000005 s
# education_HS-grad - capital-gain-binary_1  -  specificity :  0.9090441621294616 - 0.000005 s
# education_HS-grad - capital-gain-binary_1  -  tn :  30053 - 0.000004 s
# education_HS-grad - capital-gain-binary_1  -  tnr :  0.9090441621294616 - 0.000005 s
# education_HS-grad - capital-gain-binary_1  -  tp :  1030 - 0.000004 s
# education_HS-grad - capital-gain-binary_1  -  tpr :  0.06524768782465476 - 0.000005 s
# education_HS-grad - capital-gain-binary_1  -  ts :  0.06524768782465476 - 0.000004 s
# education_HS-grad - capital-loss-binary_1  -  acc :  0.6542193833681366 - 0.000020 s
# education_HS-grad - capital-loss-binary_1  -  ba :  0.49306735987664413 - 0.000013 s
# education_HS-grad - capital-loss-binary_1  -  bm :  -0.013865280246711742 - 0.000013 s
# education_HS-grad - capital-loss-binary_1  -  dor :  0.7188999590708174 - 0.000011 s
# education_HS-grad - capital-loss-binary_1  -  f1 :  0.0653016048699502 - 0.000007 s
# education_HS-grad - capital-loss-binary_1  -  fdr :  0.7416812609457093 - 0.000016 s
# education_HS-grad - capital-loss-binary_1  -  fn :  15196 - 0.000006 s
# education_HS-grad - capital-loss-binary_1  -  fnr :  0.9626251108577221 - 0.000005 s
# education_HS-grad - capital-loss-binary_1  -  fomr :  0.32636055152270094 - 0.000004 s
# education_HS-grad - capital-loss-binary_1  -  fp :  1694 - 0.000005 s
# education_HS-grad - capital-loss-binary_1  -  fpr :  0.05124016938898972 - 0.000005 s
# education_HS-grad - capital-loss-binary_1  -  mcc :  -0.10913194322610174 - 0.000008 s
# education_HS-grad - capital-loss-binary_1  -  mk :  -0.06804181246841023 - 0.000006 s
# education_HS-grad - capital-loss-binary_1  -  n :  48846 - 0.000005 s
# education_HS-grad - capital-loss-binary_1  -  nlr :  1.0146141097033823 - 0.000008 s
# education_HS-grad - capital-loss-binary_1  -  npv :  0.6736394484772991 - 0.000005 s
# education_HS-grad - capital-loss-binary_1  -  plr :  0.7294060419384354 - 0.000005 s
# education_HS-grad - capital-loss-binary_1  -  ppv :  0.2583187390542907 - 0.000004 s
# education_HS-grad - capital-loss-binary_1  -  precision :  0.2583187390542907 - 0.000006 s
# education_HS-grad - capital-loss-binary_1  -  prevalence :  0.32317897064242723 - 0.000005 s
# education_HS-grad - capital-loss-binary_1  -  pt :  0.5393589897941803 - 0.000010 s
# education_HS-grad - capital-loss-binary_1  -  recall :  0.03737488914227797 - 0.000039 s
# education_HS-grad - capital-loss-binary_1  -  sensitivity :  0.03737488914227797 - 0.000005 s
# education_HS-grad - capital-loss-binary_1  -  specificity :  0.9487598306110103 - 0.000005 s
# education_HS-grad - capital-loss-binary_1  -  tn :  31366 - 0.000005 s
# education_HS-grad - capital-loss-binary_1  -  tnr :  0.9487598306110103 - 0.000004 s
# education_HS-grad - capital-loss-binary_1  -  tp :  590 - 0.000005 s
# education_HS-grad - capital-loss-binary_1  -  tpr :  0.03737488914227797 - 0.000005 s
# education_HS-grad - capital-loss-binary_1  -  ts :  0.03737488914227797 - 0.000004 s
# education_Masters - capital-gain-binary_1  -  acc :  0.8796216680997421 - 0.000019 s
# education_Masters - capital-gain-binary_1  -  ba :  0.5374346253815399 - 0.000021 s
# education_Masters - capital-gain-binary_1  -  bm :  0.07486925076307971 - 0.000005 s
# education_Masters - capital-gain-binary_1  -  dor :  2.125587121562212 - 0.000007 s
# education_Masters - capital-gain-binary_1  -  f1 :  0.1218637992831541 - 0.000006 s
# education_Masters - capital-gain-binary_1  -  fdr :  0.8989348526133267 - 0.000005 s
# education_Masters - capital-gain-binary_1  -  fn :  2251 - 0.000006 s
# education_Masters - capital-gain-binary_1  -  fnr :  0.84655885671305 - 0.000005 s
# education_Masters - capital-gain-binary_1  -  fomr :  0.05023544377245642 - 0.000004 s
# education_Masters - capital-gain-binary_1  -  fp :  3629 - 0.000005 s
# education_Masters - capital-gain-binary_1  -  fpr :  0.07857189252387035 - 0.000005 s
# education_Masters - capital-gain-binary_1  -  mcc :  -0.05451815145253852 - 0.000010 s
# education_Masters - capital-gain-binary_1  -  mk :  0.0508297036142169 - 0.000006 s
# education_Masters - capital-gain-binary_1  -  n :  48846 - 0.000004 s
# education_Masters - capital-gain-binary_1  -  nlr :  0.9187465086471553 - 0.000005 s
# education_Masters - capital-gain-binary_1  -  npv :  0.9497645562275435 - 0.000011 s
# education_Masters - capital-gain-binary_1  -  plr :  1.952875746760639 - 0.000006 s
# education_Masters - capital-gain-binary_1  -  ppv :  0.10106514738667327 - 0.000004 s
# education_Masters - capital-gain-binary_1  -  precision :  0.10106514738667327 - 0.000006 s
# education_Masters - capital-gain-binary_1  -  prevalence :  0.05443639192564386 - 0.000005 s
# education_Masters - capital-gain-binary_1  -  pt :  0.41710927043045126 - 0.000009 s
# education_Masters - capital-gain-binary_1  -  recall :  0.15344114328695 - 0.000023 s
# education_Masters - capital-gain-binary_1  -  sensitivity :  0.15344114328695 - 0.000005 s
# education_Masters - capital-gain-binary_1  -  specificity :  0.9214281074761297 - 0.000005 s
# education_Masters - capital-gain-binary_1  -  tn :  42558 - 0.000005 s
# education_Masters - capital-gain-binary_1  -  tnr :  0.9214281074761297 - 0.000005 s
# education_Masters - capital-gain-binary_1  -  tp :  408 - 0.000005 s
# education_Masters - capital-gain-binary_1  -  tpr :  0.15344114328695 - 0.000004 s
# education_Masters - capital-gain-binary_1  -  ts :  0.15344114328695 - 0.000005 s
# education_Masters - capital-loss-binary_1  -  acc :  0.9080170331245138 - 0.000017 s
# education_Masters - capital-loss-binary_1  -  ba :  0.5200193169626429 - 0.000026 s
# education_Masters - capital-loss-binary_1  -  bm :  0.04003863392528584 - 0.000036 s
# education_Masters - capital-loss-binary_1  -  dor :  1.9811613283246927 - 0.000028 s
# education_Masters - capital-loss-binary_1  -  f1 :  0.0910378312765527 - 0.000013 s
# education_Masters - capital-loss-binary_1  -  fdr :  0.9014886164623468 - 0.000010 s
# education_Masters - capital-loss-binary_1  -  fn :  2434 - 0.000007 s
# education_Masters - capital-loss-binary_1  -  fnr :  0.9153817224520496 - 0.000007 s
# education_Masters - capital-loss-binary_1  -  fomr :  0.052274386839053305 - 0.000011 s
# education_Masters - capital-loss-binary_1  -  fp :  2059 - 0.000008 s
# education_Masters - capital-loss-binary_1  -  fpr :  0.04457964362266439 - 0.000007 s
# education_Masters - capital-loss-binary_1  -  mcc :  -0.04346436828045631 - 0.000008 s
# education_Masters - capital-loss-binary_1  -  mk :  0.04623699669860004 - 0.000006 s
# education_Masters - capital-loss-binary_1  -  n :  48846 - 0.000004 s
# education_Masters - capital-loss-binary_1  -  nlr :  0.9580931747392317 - 0.000006 s
# education_Masters - capital-loss-binary_1  -  npv :  0.9477256131609467 - 0.000004 s
# education_Masters - capital-loss-binary_1  -  plr :  1.8981371467251982 - 0.000005 s
# education_Masters - capital-loss-binary_1  -  ppv :  0.09851138353765324 - 0.000004 s
# education_Masters - capital-loss-binary_1  -  precision :  0.09851138353765324 - 0.000015 s
# education_Masters - capital-loss-binary_1  -  prevalence :  0.05443639192564386 - 0.000005 s
# education_Masters - capital-loss-binary_1  -  pt :  0.42056937848713033 - 0.000011 s
# education_Masters - capital-loss-binary_1  -  recall :  0.08461827754795036 - 0.000026 s
# education_Masters - capital-loss-binary_1  -  sensitivity :  0.08461827754795036 - 0.000005 s
# education_Masters - capital-loss-binary_1  -  specificity :  0.9554203563773356 - 0.000007 s
# education_Masters - capital-loss-binary_1  -  tn :  44128 - 0.000005 s
# education_Masters - capital-loss-binary_1  -  tnr :  0.9554203563773356 - 0.000006 s
# education_Masters - capital-loss-binary_1  -  tp :  225 - 0.000005 s
# education_Masters - capital-loss-binary_1  -  tpr :  0.08461827754795036 - 0.000005 s
# education_Masters - capital-loss-binary_1  -  ts :  0.08461827754795036 - 0.000005 s
# education_Preschool - capital-gain-binary_1  -  acc :  0.9158170576915203 - 0.000021 s
# education_Preschool - capital-gain-binary_1  -  ba :  0.4880672475712871 - 0.000012 s
# education_Preschool - capital-gain-binary_1  -  bm :  -0.02386550485742578 - 0.000005 s
# education_Preschool - capital-gain-binary_1  -  dor :  0.6933438740079365 - 0.000007 s
# education_Preschool - capital-gain-binary_1  -  f1 :  0.0024260067928190197 - 0.000022 s
# education_Preschool - capital-gain-binary_1  -  fdr :  0.9987614565271241 - 0.000011 s
# education_Preschool - capital-gain-binary_1  -  fn :  80 - 0.000005 s
# education_Preschool - capital-gain-binary_1  -  fnr :  0.9411764705882353 - 0.000006 s
# education_Preschool - capital-gain-binary_1  -  fomr :  0.001785355620522663 - 0.000006 s
# education_Preschool - capital-gain-binary_1  -  fp :  4032 - 0.000005 s
# education_Preschool - capital-gain-binary_1  -  fpr :  0.08268903426919054 - 0.000008 s
# education_Preschool - capital-gain-binary_1  -  mcc :  -0.010146473393576732 - 0.000018 s
# education_Preschool - capital-gain-binary_1  -  mk :  -0.0005468121476467358 - 0.000005 s
# education_Preschool - capital-gain-binary_1  -  n :  48846 - 0.000004 s
# education_Preschool - capital-gain-binary_1  -  nlr :  1.0260168097286535 - 0.000006 s
# education_Preschool - capital-gain-binary_1  -  npv :  0.9982146443794774 - 0.000014 s
# education_Preschool - capital-gain-binary_1  -  plr :  0.7113824696545284 - 0.000006 s
# education_Preschool - capital-gain-binary_1  -  ppv :  0.0012385434728758979 - 0.000005 s
# education_Preschool - capital-gain-binary_1  -  precision :  0.0012385434728758979 - 0.000012 s
# education_Preschool - capital-gain-binary_1  -  prevalence :  0.0017401629611431847 - 0.000006 s
# education_Preschool - capital-gain-binary_1  -  pt :  0.5424655828208857 - 0.000009 s
# education_Preschool - capital-gain-binary_1  -  recall :  0.058823529411764705 - 0.000028 s
# education_Preschool - capital-gain-binary_1  -  sensitivity :  0.058823529411764705 - 0.000004 s
# education_Preschool - capital-gain-binary_1  -  specificity :  0.9173109657308095 - 0.000015 s
# education_Preschool - capital-gain-binary_1  -  tn :  44729 - 0.000006 s
# education_Preschool - capital-gain-binary_1  -  tnr :  0.9173109657308095 - 0.000013 s
# education_Preschool - capital-gain-binary_1  -  tp :  5 - 0.000005 s
# education_Preschool - capital-gain-binary_1  -  tpr :  0.058823529411764705 - 0.000008 s
# education_Preschool - capital-gain-binary_1  -  ts :  0.058823529411764705 - 0.000005 s
# education_Preschool - capital-loss-binary_1  -  acc :  0.9516234696802195 - 0.000016 s
# education_Preschool - capital-loss-binary_1  -  ba :  0.49425746468066933 - 0.000014 s
# education_Preschool - capital-loss-binary_1  -  bm :  -0.011485070638661332 - 0.000009 s
# education_Preschool - capital-loss-binary_1  -  dor :  0.745501010468237 - 0.000010 s
# education_Preschool - capital-loss-binary_1  -  f1 :  0.0025327142254115663 - 0.000007 s
# education_Preschool - capital-loss-binary_1  -  fdr :  0.9986865148861647 - 0.000007 s
# education_Preschool - capital-loss-binary_1  -  fn :  82 - 0.000005 s
# education_Preschool - capital-loss-binary_1  -  fnr :  0.9647058823529412 - 0.000005 s
# education_Preschool - capital-loss-binary_1  -  fomr :  0.0017610927365662987 - 0.000004 s
# education_Preschool - capital-loss-binary_1  -  fp :  2281 - 0.000006 s
# education_Preschool - capital-loss-binary_1  -  fpr :  0.04677918828572015 - 0.000007 s
# education_Preschool - capital-loss-binary_1  -  mcc :  -0.006694976100487023 - 0.000009 s
# education_Preschool - capital-loss-binary_1  -  mk :  -0.0004476076227309944 - 0.000006 s
# education_Preschool - capital-loss-binary_1  -  n :  48846 - 0.000005 s
# education_Preschool - capital-loss-binary_1  -  nlr :  1.0120486989976714 - 0.000007 s
# education_Preschool - capital-loss-binary_1  -  npv :  0.9982389072634337 - 0.000004 s
# education_Preschool - capital-loss-binary_1  -  plr :  0.7544833277458286 - 0.000007 s
# education_Preschool - capital-loss-binary_1  -  ppv :  0.0013134851138353765 - 0.000005 s
# education_Preschool - capital-loss-binary_1  -  precision :  0.0013134851138353765 - 0.000006 s
# education_Preschool - capital-loss-binary_1  -  prevalence :  0.0017401629611431847 - 0.000005 s
# education_Preschool - capital-loss-binary_1  -  pt :  0.5351571496145868 - 0.000010 s
# education_Preschool - capital-loss-binary_1  -  recall :  0.03529411764705882 - 0.000026 s
# education_Preschool - capital-loss-binary_1  -  sensitivity :  0.03529411764705882 - 0.000008 s
# education_Preschool - capital-loss-binary_1  -  specificity :  0.9532208117142799 - 0.000005 s
# education_Preschool - capital-loss-binary_1  -  tn :  46480 - 0.000005 s
# education_Preschool - capital-loss-binary_1  -  tnr :  0.9532208117142799 - 0.000005 s
# education_Preschool - capital-loss-binary_1  -  tp :  3 - 0.000013 s
# education_Preschool - capital-loss-binary_1  -  tpr :  0.03529411764705882 - 0.000011 s
# education_Preschool - capital-loss-binary_1  -  ts :  0.03529411764705882 - 0.000005 s
# education_Prof-school - capital-gain-binary_1  -  acc :  0.9094501085042788 - 0.000013 s
# education_Prof-school - capital-gain-binary_1  -  ba :  0.5948693155034488 - 0.000007 s
# education_Prof-school - capital-gain-binary_1  -  bm :  0.18973863100689758 - 0.000008 s
# education_Prof-school - capital-gain-binary_1  -  dor :  4.269637787811081 - 0.000022 s
# education_Prof-school - capital-gain-binary_1  -  f1 :  0.09234557767289144 - 0.000007 s
# education_Prof-school - capital-gain-binary_1  -  fdr :  0.9442655437205846 - 0.000007 s
# education_Prof-school - capital-gain-binary_1  -  fn :  611 - 0.000010 s
# education_Prof-school - capital-gain-binary_1  -  fnr :  0.7308612440191388 - 0.000008 s
# education_Prof-school - capital-gain-binary_1  -  fomr :  0.013635653551741837 - 0.000004 s
# education_Prof-school - capital-gain-binary_1  -  fp :  3812 - 0.000005 s
# education_Prof-school - capital-gain-binary_1  -  fpr :  0.07940012497396376 - 0.000006 s
# education_Prof-school - capital-gain-binary_1  -  mcc :  -0.026813277330403198 - 0.000008 s
# education_Prof-school - capital-gain-binary_1  -  mk :  0.042098802727673634 - 0.000007 s
# education_Prof-school - capital-gain-binary_1  -  n :  48846 - 0.000004 s
# education_Prof-school - capital-gain-binary_1  -  nlr :  0.7938967447703257 - 0.000007 s
# education_Prof-school - capital-gain-binary_1  -  npv :  0.9863643464482582 - 0.000004 s
# education_Prof-school - capital-gain-binary_1  -  plr :  3.3896515410915917 - 0.000006 s
# education_Prof-school - capital-gain-binary_1  -  ppv :  0.05573445627941541 - 0.000004 s
# education_Prof-school - capital-gain-binary_1  -  precision :  0.05573445627941541 - 0.000005 s
# education_Prof-school - capital-gain-binary_1  -  prevalence :  0.017115014535478854 - 0.000005 s
# education_Prof-school - capital-gain-binary_1  -  pt :  0.35197626876009414 - 0.000010 s
# education_Prof-school - capital-gain-binary_1  -  recall :  0.26913875598086123 - 0.000027 s
# education_Prof-school - capital-gain-binary_1  -  sensitivity :  0.26913875598086123 - 0.000006 s
# education_Prof-school - capital-gain-binary_1  -  specificity :  0.9205998750260362 - 0.000005 s
# education_Prof-school - capital-gain-binary_1  -  tn :  44198 - 0.000012 s
# education_Prof-school - capital-gain-binary_1  -  tnr :  0.9205998750260362 - 0.000008 s
# education_Prof-school - capital-gain-binary_1  -  tp :  225 - 0.000005 s
# education_Prof-school - capital-gain-binary_1  -  tpr :  0.26913875598086123 - 0.000005 s
# education_Prof-school - capital-gain-binary_1  -  ts :  0.26913875598086123 - 0.000004 s
# education_Prof-school - capital-loss-binary_1  -  acc :  0.9400155591041232 - 0.000017 s
# education_Prof-school - capital-loss-binary_1  -  ba :  0.5340208479294086 - 0.000015 s
# education_Prof-school - capital-loss-binary_1  -  bm :  0.06804169585881725 - 0.000006 s
# education_Prof-school - capital-loss-binary_1  -  dor :  2.6836396434386383 - 0.000007 s
# education_Prof-school - capital-loss-binary_1  -  f1 :  0.060897435897435896 - 0.000006 s
# education_Prof-school - capital-loss-binary_1  -  fdr :  0.9584063047285464 - 0.000014 s
# education_Prof-school - capital-loss-binary_1  -  fn :  741 - 0.000004 s
# education_Prof-school - capital-loss-binary_1  -  fnr :  0.8863636363636364 - 0.000005 s
# education_Prof-school - capital-loss-binary_1  -  fomr :  0.015914264851166187 - 0.000004 s
# education_Prof-school - capital-loss-binary_1  -  fp :  2189 - 0.000005 s
# education_Prof-school - capital-loss-binary_1  -  fpr :  0.045594667777546345 - 0.000005 s
# education_Prof-school - capital-loss-binary_1  -  mcc :  -0.024124593674777088 - 0.000007 s
# education_Prof-school - capital-loss-binary_1  -  mk :  0.02567943042028742 - 0.000005 s
# education_Prof-school - capital-loss-binary_1  -  n :  48846 - 0.000004 s
# education_Prof-school - capital-loss-binary_1  -  nlr :  0.9287077580545642 - 0.000005 s
# education_Prof-school - capital-loss-binary_1  -  npv :  0.9840857351488338 - 0.000004 s
# education_Prof-school - capital-loss-binary_1  -  plr :  2.4923169566842476 - 0.000005 s
# education_Prof-school - capital-loss-binary_1  -  ppv :  0.04159369527145359 - 0.000004 s
# education_Prof-school - capital-loss-binary_1  -  precision :  0.04159369527145359 - 0.000015 s
# education_Prof-school - capital-loss-binary_1  -  prevalence :  0.017115014535478854 - 0.000010 s
# education_Prof-school - capital-loss-binary_1  -  pt :  0.38779119028871334 - 0.000009 s
# education_Prof-school - capital-loss-binary_1  -  recall :  0.11363636363636363 - 0.000026 s
# education_Prof-school - capital-loss-binary_1  -  sensitivity :  0.11363636363636363 - 0.000005 s
# education_Prof-school - capital-loss-binary_1  -  specificity :  0.9544053322224536 - 0.000010 s
# education_Prof-school - capital-loss-binary_1  -  tn :  45821 - 0.000004 s
# education_Prof-school - capital-loss-binary_1  -  tnr :  0.9544053322224536 - 0.000004 s
# education_Prof-school - capital-loss-binary_1  -  tp :  95 - 0.000006 s
# education_Prof-school - capital-loss-binary_1  -  tpr :  0.11363636363636363 - 0.000005 s
# education_Prof-school - capital-loss-binary_1  -  ts :  0.11363636363636363 - 0.000004 s
# education_Some-college - capital-gain-binary_1  -  acc :  0.7232731441673832 - 0.000017 s
# education_Some-college - capital-gain-binary_1  -  ba :  0.4882219017170161 - 0.000007 s
# education_Some-college - capital-gain-binary_1  -  bm :  -0.023556196565967746 - 0.000009 s
# education_Some-college - capital-gain-binary_1  -  dor :  0.7135657652809806 - 0.000007 s
# education_Some-college - capital-gain-binary_1  -  f1 :  0.09385265133740027 - 0.000005 s
# education_Some-college - capital-gain-binary_1  -  fdr :  0.8266039137973743 - 0.000006 s
# education_Some-college - capital-gain-binary_1  -  fn :  10180 - 0.000005 s
# education_Some-college - capital-gain-binary_1  -  fnr :  0.9356617647058824 - 0.000004 s
# education_Some-college - capital-gain-binary_1  -  fomr :  0.22718650271150884 - 0.000004 s
# education_Some-college - capital-gain-binary_1  -  fp :  3337 - 0.000005 s
# education_Some-college - capital-gain-binary_1  -  fpr :  0.08789443186008535 - 0.000005 s
# education_Some-college - capital-gain-binary_1  -  mcc :  -0.124144710353463 - 0.000007 s
# education_Some-college - capital-gain-binary_1  -  mk :  -0.053790416508883165 - 0.000006 s
# education_Some-college - capital-gain-binary_1  -  n :  48846 - 0.000004 s
# education_Some-college - capital-gain-binary_1  -  nlr :  1.025826173404474 - 0.000005 s
# education_Some-college - capital-gain-binary_1  -  npv :  0.7728134972884911 - 0.000004 s
# education_Some-college - capital-gain-binary_1  -  plr :  0.7319944384706234 - 0.000005 s
# education_Some-college - capital-gain-binary_1  -  ppv :  0.1733960862026257 - 0.000004 s
# education_Some-college - capital-gain-binary_1  -  precision :  0.1733960862026257 - 0.000005 s
# education_Some-college - capital-gain-binary_1  -  prevalence :  0.22274085902632765 - 0.000004 s
# education_Some-college - capital-gain-binary_1  -  pt :  0.5389189087095383 - 0.000007 s
# education_Some-college - capital-gain-binary_1  -  recall :  0.06433823529411764 - 0.000024 s
# education_Some-college - capital-gain-binary_1  -  sensitivity :  0.06433823529411764 - 0.000005 s
# education_Some-college - capital-gain-binary_1  -  specificity :  0.9121055681399146 - 0.000004 s
# education_Some-college - capital-gain-binary_1  -  tn :  34629 - 0.000010 s
# education_Some-college - capital-gain-binary_1  -  tnr :  0.9121055681399146 - 0.000007 s
# education_Some-college - capital-gain-binary_1  -  tp :  700 - 0.000005 s
# education_Some-college - capital-gain-binary_1  -  tpr :  0.06433823529411764 - 0.000004 s
# education_Some-college - capital-gain-binary_1  -  ts :  0.06433823529411764 - 0.000005 s
# education_Some-college - capital-loss-binary_1  -  acc :  0.7485566883675224 - 0.000019 s
# education_Some-college - capital-loss-binary_1  -  ba :  0.4959948273184056 - 0.000012 s
# education_Some-college - capital-loss-binary_1  -  bm :  -0.008010345363188787 - 0.000006 s
# education_Some-college - capital-loss-binary_1  -  dor :  0.8280149302380775 - 0.000008 s
# education_Some-college - capital-loss-binary_1  -  f1 :  0.06700091157702827 - 0.000010 s
# education_Some-college - capital-loss-binary_1  -  fdr :  0.8069176882661997 - 0.000005 s
# education_Some-college - capital-loss-binary_1  -  fn :  10439 - 0.000005 s
# education_Some-college - capital-loss-binary_1  -  fnr :  0.9594669117647059 - 0.000004 s
# education_Some-college - capital-loss-binary_1  -  fomr :  0.22419569606116577 - 0.000007 s
# education_Some-college - capital-loss-binary_1  -  fp :  1843 - 0.000005 s
# education_Some-college - capital-loss-binary_1  -  fpr :  0.04854343359848285 - 0.000005 s
# education_Some-college - capital-loss-binary_1  -  mcc :  -0.09161832242573616 - 0.000008 s
# education_Some-college - capital-loss-binary_1  -  mk :  -0.031113384327365434 - 0.000006 s
# education_Some-college - capital-loss-binary_1  -  n :  48846 - 0.000005 s
# education_Some-college - capital-loss-binary_1  -  nlr :  1.0084190341903725 - 0.000007 s
# education_Some-college - capital-loss-binary_1  -  npv :  0.7758043039388343 - 0.000004 s
# education_Some-college - capital-loss-binary_1  -  plr :  0.8349860162458907 - 0.000015 s
# education_Some-college - capital-loss-binary_1  -  ppv :  0.19308231173380036 - 0.000004 s
# education_Some-college - capital-loss-binary_1  -  precision :  0.19308231173380036 - 0.000006 s
# education_Some-college - capital-loss-binary_1  -  prevalence :  0.22274085902632765 - 0.000015 s
# education_Some-college - capital-loss-binary_1  -  pt :  0.5225272762669816 - 0.000016 s
# education_Some-college - capital-loss-binary_1  -  recall :  0.04053308823529412 - 0.000030 s
# education_Some-college - capital-loss-binary_1  -  sensitivity :  0.04053308823529412 - 0.000005 s
# education_Some-college - capital-loss-binary_1  -  specificity :  0.9514565664015171 - 0.000016 s
# education_Some-college - capital-loss-binary_1  -  tn :  36123 - 0.000008 s
# education_Some-college - capital-loss-binary_1  -  tnr :  0.9514565664015171 - 0.000009 s
# education_Some-college - capital-loss-binary_1  -  tp :  441 - 0.000009 s
# education_Some-college - capital-loss-binary_1  -  tpr :  0.04053308823529412 - 0.000010 s
# education_Some-college - capital-loss-binary_1  -  ts :  0.04053308823529412 - 0.000005 s
# marital-status_Divorced - capital-gain-binary_1  -  acc :  0.799328501822053 - 0.000027 s
# marital-status_Divorced - capital-gain-binary_1  -  ba :  0.4901141048727517 - 0.000012 s
# marital-status_Divorced - capital-gain-binary_1  -  bm :  -0.019771790254496602 - 0.000007 s
# marital-status_Divorced - capital-gain-binary_1  -  dor :  0.7520425480467839 - 0.000008 s
# marital-status_Divorced - capital-gain-binary_1  -  f1 :  0.08152173913043478 - 0.000007 s
# marital-status_Divorced - capital-gain-binary_1  -  fdr :  0.8922467178597969 - 0.000005 s
# marital-status_Divorced - capital-gain-binary_1  -  fn :  6200 - 0.000005 s
# marital-status_Divorced - capital-gain-binary_1  -  fnr :  0.9344385832705351 - 0.000015 s
# marital-status_Divorced - capital-gain-binary_1  -  fomr :  0.13836506059050638 - 0.000004 s
# marital-status_Divorced - capital-gain-binary_1  -  fp :  3602 - 0.000012 s
# marital-status_Divorced - capital-gain-binary_1  -  fpr :  0.08533320698396153 - 0.000008 s
# marital-status_Divorced - capital-gain-binary_1  -  mcc :  -0.09904445499174878 - 0.000013 s
# marital-status_Divorced - capital-gain-binary_1  -  mk :  -0.030611778450303273 - 0.000006 s
# marital-status_Divorced - capital-gain-binary_1  -  n :  48846 - 0.000004 s
# marital-status_Divorced - capital-gain-binary_1  -  nlr :  1.0216163857761806 - 0.000006 s
# marital-status_Divorced - capital-gain-binary_1  -  npv :  0.8616349394094936 - 0.000004 s
# marital-status_Divorced - capital-gain-binary_1  -  plr :  0.7682989898854651 - 0.000005 s
# marital-status_Divorced - capital-gain-binary_1  -  ppv :  0.10775328214020312 - 0.000004 s
# marital-status_Divorced - capital-gain-binary_1  -  precision :  0.10775328214020312 - 0.000005 s
# marital-status_Divorced - capital-gain-binary_1  -  prevalence :  0.13583507349629448 - 0.000008 s
# marital-status_Divorced - capital-gain-binary_1  -  pt :  0.5328994359850345 - 0.000015 s
# marital-status_Divorced - capital-gain-binary_1  -  recall :  0.06556141672946496 - 0.000028 s
# marital-status_Divorced - capital-gain-binary_1  -  sensitivity :  0.06556141672946496 - 0.000004 s
# marital-status_Divorced - capital-gain-binary_1  -  specificity :  0.9146667930160385 - 0.000013 s
# marital-status_Divorced - capital-gain-binary_1  -  tn :  38609 - 0.000008 s
# marital-status_Divorced - capital-gain-binary_1  -  tnr :  0.9146667930160385 - 0.000005 s
# marital-status_Divorced - capital-gain-binary_1  -  tp :  435 - 0.000008 s
# marital-status_Divorced - capital-gain-binary_1  -  tpr :  0.06556141672946496 - 0.000006 s
# marital-status_Divorced - capital-gain-binary_1  -  ts :  0.06556141672946496 - 0.000005 s
# marital-status_Divorced - capital-loss-binary_1  -  acc :  0.8279285919010768 - 0.000017 s
# marital-status_Divorced - capital-loss-binary_1  -  ba :  0.49535666415663926 - 0.000013 s
# marital-status_Divorced - capital-loss-binary_1  -  bm :  -0.009286671686721482 - 0.000009 s
# marital-status_Divorced - capital-loss-binary_1  -  dor :  0.7988183356608023 - 0.000008 s
# marital-status_Divorced - capital-loss-binary_1  -  f1 :  0.05762977912322009 - 0.000006 s
# marital-status_Divorced - capital-loss-binary_1  -  fdr :  0.887478108581436 - 0.000006 s
# marital-status_Divorced - capital-loss-binary_1  -  fn :  6378 - 0.000004 s
# marital-status_Divorced - capital-loss-binary_1  -  fnr :  0.9612660135644311 - 0.000006 s
# marital-status_Divorced - capital-loss-binary_1  -  fomr :  0.1369786521197543 - 0.000004 s
# marital-status_Divorced - capital-loss-binary_1  -  fp :  2027 - 0.000005 s
# marital-status_Divorced - capital-loss-binary_1  -  fpr :  0.0480206581222904 - 0.000006 s
# marital-status_Divorced - capital-loss-binary_1  -  mcc :  -0.0746758992849734 - 0.000008 s
# marital-status_Divorced - capital-loss-binary_1  -  mk :  -0.024456760701190405 - 0.000006 s
# marital-status_Divorced - capital-loss-binary_1  -  n :  48846 - 0.000004 s
# marital-status_Divorced - capital-loss-binary_1  -  nlr :  1.009755118917186 - 0.000005 s
# marital-status_Divorced - capital-loss-binary_1  -  npv :  0.8630213478802456 - 0.000004 s
# marital-status_Divorced - capital-loss-binary_1  -  plr :  0.806610903518402 - 0.000005 s
# marital-status_Divorced - capital-loss-binary_1  -  ppv :  0.11252189141856392 - 0.000004 s
# marital-status_Divorced - capital-loss-binary_1  -  precision :  0.11252189141856392 - 0.000006 s
# marital-status_Divorced - capital-loss-binary_1  -  prevalence :  0.13583507349629448 - 0.000005 s
# marital-status_Divorced - capital-loss-binary_1  -  pt :  0.5268384145629434 - 0.000007 s
# marital-status_Divorced - capital-loss-binary_1  -  recall :  0.038733986435568954 - 0.000023 s
# marital-status_Divorced - capital-loss-binary_1  -  sensitivity :  0.038733986435568954 - 0.000004 s
# marital-status_Divorced - capital-loss-binary_1  -  specificity :  0.9519793418777096 - 0.000004 s
# marital-status_Divorced - capital-loss-binary_1  -  tn :  40184 - 0.000004 s
# marital-status_Divorced - capital-loss-binary_1  -  tnr :  0.9519793418777096 - 0.000004 s
# marital-status_Divorced - capital-loss-binary_1  -  tp :  257 - 0.000005 s
# marital-status_Divorced - capital-loss-binary_1  -  tpr :  0.038733986435568954 - 0.000007 s
# marital-status_Divorced - capital-loss-binary_1  -  ts :  0.038733986435568954 - 0.000004 s
# marital-status_Married-AF-spouse - capital-gain-binary_1  -  acc :  0.9167178479302297 - 0.000018 s
# marital-status_Married-AF-spouse - capital-gain-binary_1  -  ba :  0.5099662564165607 - 0.000009 s
# marital-status_Married-AF-spouse - capital-gain-binary_1  -  bm :  0.019932512833121363 - 0.000005 s
# marital-status_Married-AF-spouse - capital-gain-binary_1  -  dor :  1.268789628422656 - 0.000007 s
# marital-status_Married-AF-spouse - capital-gain-binary_1  -  f1 :  0.001962708537782139 - 0.000017 s
# marital-status_Married-AF-spouse - capital-gain-binary_1  -  fdr :  0.9990091652216992 - 0.000005 s
# marital-status_Married-AF-spouse - capital-gain-binary_1  -  fn :  35 - 0.000004 s
# marital-status_Married-AF-spouse - capital-gain-binary_1  -  fnr :  0.8974358974358975 - 0.000004 s
# marital-status_Married-AF-spouse - capital-gain-binary_1  -  fomr :  0.000781093083978665 - 0.000016 s
# marital-status_Married-AF-spouse - capital-gain-binary_1  -  fp :  4033 - 0.000005 s
# marital-status_Married-AF-spouse - capital-gain-binary_1  -  fpr :  0.08263158973098121 - 0.000006 s
# marital-status_Married-AF-spouse - capital-gain-binary_1  -  mcc :  -0.005193833729942862 - 0.000008 s
# marital-status_Married-AF-spouse - capital-gain-binary_1  -  mk :  0.00020974169432208534 - 0.000006 s
# marital-status_Married-AF-spouse - capital-gain-binary_1  -  n :  48846 - 0.000010 s
# marital-status_Married-AF-spouse - capital-gain-binary_1  -  nlr :  0.9782720741089437 - 0.000014 s
# marital-status_Married-AF-spouse - capital-gain-binary_1  -  npv :  0.9992189069160213 - 0.000006 s
# marital-status_Married-AF-spouse - capital-gain-binary_1  -  plr :  1.2412214614049477 - 0.000007 s
# marital-status_Married-AF-spouse - capital-gain-binary_1  -  ppv :  0.0009908347783007183 - 0.000005 s
# marital-status_Married-AF-spouse - capital-gain-binary_1  -  precision :  0.0009908347783007183 - 0.000005 s
# marital-status_Married-AF-spouse - capital-gain-binary_1  -  prevalence :  0.0007984277115833436 - 0.000005 s
# marital-status_Married-AF-spouse - capital-gain-binary_1  -  pt :  0.4730142553076195 - 0.000009 s
# marital-status_Married-AF-spouse - capital-gain-binary_1  -  recall :  0.10256410256410256 - 0.000025 s
# marital-status_Married-AF-spouse - capital-gain-binary_1  -  sensitivity :  0.10256410256410256 - 0.000007 s
# marital-status_Married-AF-spouse - capital-gain-binary_1  -  specificity :  0.9173684102690188 - 0.000005 s
# marital-status_Married-AF-spouse - capital-gain-binary_1  -  tn :  44774 - 0.000004 s
# marital-status_Married-AF-spouse - capital-gain-binary_1  -  tnr :  0.9173684102690188 - 0.000007 s
# marital-status_Married-AF-spouse - capital-gain-binary_1  -  tp :  4 - 0.000005 s
# marital-status_Married-AF-spouse - capital-gain-binary_1  -  tpr :  0.10256410256410256 - 0.000005 s
# marital-status_Married-AF-spouse - capital-gain-binary_1  -  ts :  0.10256410256410256 - 0.000004 s
# marital-status_Married-AF-spouse - capital-loss-binary_1  -  acc :  0.9525652049297793 - 0.000017 s
# marital-status_Married-AF-spouse - capital-loss-binary_1  -  ba :  0.5150939887248204 - 0.000012 s
# marital-status_Married-AF-spouse - capital-loss-binary_1  -  bm :  0.030187977449640746 - 0.000010 s
# marital-status_Married-AF-spouse - capital-loss-binary_1  -  dor :  1.6997661844220369 - 0.000007 s
# marital-status_Married-AF-spouse - capital-loss-binary_1  -  f1 :  0.002582866982350409 - 0.000009 s
# marital-status_Married-AF-spouse - capital-loss-binary_1  -  fdr :  0.9986865148861647 - 0.000005 s
# marital-status_Married-AF-spouse - capital-loss-binary_1  -  fn :  36 - 0.000004 s
# marital-status_Married-AF-spouse - capital-loss-binary_1  -  fnr :  0.9230769230769231 - 0.000006 s
# marital-status_Married-AF-spouse - capital-loss-binary_1  -  fomr :  0.0007731626648339848 - 0.000004 s
# marital-status_Married-AF-spouse - capital-loss-binary_1  -  fp :  2281 - 0.000005 s
# marital-status_Married-AF-spouse - capital-loss-binary_1  -  fpr :  0.04673509947343619 - 0.000005 s
# marital-status_Married-AF-spouse - capital-loss-binary_1  -  mcc :  -0.002501233028403075 - 0.000009 s
# marital-status_Married-AF-spouse - capital-loss-binary_1  -  mk :  0.0005403224490014846 - 0.000009 s
# marital-status_Married-AF-spouse - capital-loss-binary_1  -  n :  48846 - 0.000004 s
# marital-status_Married-AF-spouse - capital-loss-binary_1  -  nlr :  0.9683320161762324 - 0.000005 s
# marital-status_Married-AF-spouse - capital-loss-binary_1  -  npv :  0.999226837335166 - 0.000005 s
# marital-status_Married-AF-spouse - capital-loss-binary_1  -  plr :  1.6459380163895727 - 0.000006 s
# marital-status_Married-AF-spouse - capital-loss-binary_1  -  ppv :  0.0013134851138353765 - 0.000005 s
# marital-status_Married-AF-spouse - capital-loss-binary_1  -  precision :  0.0013134851138353765 - 0.000005 s
# marital-status_Married-AF-spouse - capital-loss-binary_1  -  prevalence :  0.0007984277115833436 - 0.000004 s
# marital-status_Married-AF-spouse - capital-loss-binary_1  -  pt :  0.43803143862898575 - 0.000008 s
# marital-status_Married-AF-spouse - capital-loss-binary_1  -  recall :  0.07692307692307693 - 0.000024 s
# marital-status_Married-AF-spouse - capital-loss-binary_1  -  sensitivity :  0.07692307692307693 - 0.000005 s
# marital-status_Married-AF-spouse - capital-loss-binary_1  -  specificity :  0.9532649005265638 - 0.000005 s
# marital-status_Married-AF-spouse - capital-loss-binary_1  -  tn :  46526 - 0.000004 s
# marital-status_Married-AF-spouse - capital-loss-binary_1  -  tnr :  0.9532649005265638 - 0.000021 s
# marital-status_Married-AF-spouse - capital-loss-binary_1  -  tp :  3 - 0.000005 s
# marital-status_Married-AF-spouse - capital-loss-binary_1  -  tpr :  0.07692307692307693 - 0.000013 s
# marital-status_Married-AF-spouse - capital-loss-binary_1  -  ts :  0.07692307692307693 - 0.000005 s
# marital-status_Married-civ-spouse - capital-gain-binary_1  -  acc :  0.5690537607992466 - 0.000017 s
# marital-status_Married-civ-spouse - capital-gain-binary_1  -  ba :  0.5343995114476309 - 0.000014 s
# marital-status_Married-civ-spouse - capital-gain-binary_1  -  bm :  0.06879902289526174 - 0.000008 s
# marital-status_Married-civ-spouse - capital-gain-binary_1  -  dor :  2.529099598758591 - 0.000011 s
# marital-status_Married-civ-spouse - capital-gain-binary_1  -  f1 :  0.20319479143008554 - 0.000015 s
# marital-status_Married-civ-spouse - capital-gain-binary_1  -  fdr :  0.335149863760218 - 0.000007 s
# marital-status_Married-civ-spouse - capital-gain-binary_1  -  fn :  19697 - 0.000004 s
# marital-status_Married-civ-spouse - capital-gain-binary_1  -  fnr :  0.8800768509003173 - 0.000005 s
# marital-status_Married-civ-spouse - capital-gain-binary_1  -  fomr :  0.4395768707179361 - 0.000005 s
# marital-status_Married-civ-spouse - capital-gain-binary_1  -  fp :  1353 - 0.000005 s
# marital-status_Married-civ-spouse - capital-gain-binary_1  -  fpr :  0.05112412620442093 - 0.000007 s
# marital-status_Married-civ-spouse - capital-gain-binary_1  -  mcc :  -0.08133116297368063 - 0.000009 s
# marital-status_Married-civ-spouse - capital-gain-binary_1  -  mk :  0.2252732655218459 - 0.000006 s
# marital-status_Married-civ-spouse - capital-gain-binary_1  -  n :  48846 - 0.000004 s
# marital-status_Married-civ-spouse - capital-gain-binary_1  -  nlr :  0.9274941804347283 - 0.000005 s
# marital-status_Married-civ-spouse - capital-gain-binary_1  -  npv :  0.5604231292820638 - 0.000004 s
# marital-status_Married-civ-spouse - capital-gain-binary_1  -  plr :  2.3457251595883997 - 0.000005 s
# marital-status_Married-civ-spouse - capital-gain-binary_1  -  ppv :  0.6648501362397821 - 0.000004 s
# marital-status_Married-civ-spouse - capital-gain-binary_1  -  precision :  0.6648501362397821 - 0.000005 s
# marital-status_Married-civ-spouse - capital-gain-binary_1  -  prevalence :  0.4581951439217131 - 0.000004 s
# marital-status_Married-civ-spouse - capital-gain-binary_1  -  pt :  0.3950108489989365 - 0.000010 s
# marital-status_Married-civ-spouse - capital-gain-binary_1  -  recall :  0.11992314909968277 - 0.000031 s
# marital-status_Married-civ-spouse - capital-gain-binary_1  -  sensitivity :  0.11992314909968277 - 0.000008 s
# marital-status_Married-civ-spouse - capital-gain-binary_1  -  specificity :  0.948875873795579 - 0.000005 s
# marital-status_Married-civ-spouse - capital-gain-binary_1  -  tn :  25112 - 0.000005 s
# marital-status_Married-civ-spouse - capital-gain-binary_1  -  tnr :  0.948875873795579 - 0.000004 s
# marital-status_Married-civ-spouse - capital-gain-binary_1  -  tp :  2684 - 0.000004 s
# marital-status_Married-civ-spouse - capital-gain-binary_1  -  tpr :  0.11992314909968277 - 0.000004 s
# marital-status_Married-civ-spouse - capital-gain-binary_1  -  ts :  0.11992314909968277 - 0.000013 s
# marital-status_Married-civ-spouse - capital-loss-binary_1  -  acc :  0.5528600090079024 - 0.000017 s
# marital-status_Married-civ-spouse - capital-loss-binary_1  -  ba :  0.5150700246549476 - 0.000015 s
# marital-status_Married-civ-spouse - capital-loss-binary_1  -  bm :  0.03014004930989511 - 0.000005 s
# marital-status_Married-civ-spouse - capital-loss-binary_1  -  dor :  1.9763401281314787 - 0.000010 s
# marital-status_Married-civ-spouse - capital-loss-binary_1  -  f1 :  0.11449422258260691 - 0.000007 s
# marital-status_Married-civ-spouse - capital-loss-binary_1  -  fdr :  0.38178633975481613 - 0.000006 s
# ...
# native-country_Yugoslavia - capital-gain-binary_1  -  nlr :  0.8720176829132154 - 0.000005 s
# native-country_Yugoslavia - capital-gain-binary_1  -  npv :  0.9995536610948693 - 0.000004 s
# native-country_Yugoslavia - capital-gain-binary_1  -  plr :  2.421676587301587 - 0.000005 s
# native-country_Yugoslavia - capital-gain-binary_1  -  ppv :  0.0012385434728758979 - 0.000004 s
# native-country_Yugoslavia - capital-gain-binary_1  -  precision :  0.0012385434728758979 - 0.000005 s
# native-country_Yugoslavia - capital-gain-binary_1  -  prevalence :  0.0005118126356303484 - 0.000007 s
# native-country_Yugoslavia - capital-gain-binary_1  -  pt :  0.3912097208639869 - 0.000007 s
# native-country_Yugoslavia - capital-gain-binary_1  -  recall :  0.2 - 0.000040 s
# native-country_Yugoslavia - capital-gain-binary_1  -  sensitivity :  0.2 - 0.000008 s
# native-country_Yugoslavia - capital-gain-binary_1  -  specificity :  0.9174125888449642 - 0.000007 s
# native-country_Yugoslavia - capital-gain-binary_1  -  tn :  44789 - 0.000005 s
# native-country_Yugoslavia - capital-gain-binary_1  -  tnr :  0.9174125888449642 - 0.000004 s
# native-country_Yugoslavia - capital-gain-binary_1  -  tp :  5 - 0.000005 s
# native-country_Yugoslavia - capital-gain-binary_1  -  tpr :  0.2 - 0.000005 s
# native-country_Yugoslavia - capital-gain-binary_1  -  ts :  0.2 - 0.000005 s
# native-country_Yugoslavia - capital-loss-binary_1  -  acc :  0.9527699299840314 - 0.000029 s
# native-country_Yugoslavia - capital-loss-binary_1  -  ba :  0.4966186681960632 - 0.000008 s
# native-country_Yugoslavia - capital-loss-binary_1  -  bm :  -0.006762663607873587 - 0.000005 s
# native-country_Yugoslavia - capital-loss-binary_1  -  dor :  0.8493575704482406 - 0.000007 s
# native-country_Yugoslavia - capital-loss-binary_1  -  f1 :  0.0008661758336942398 - 0.000006 s
# native-country_Yugoslavia - capital-loss-binary_1  -  fdr :  0.9995621716287215 - 0.000005 s
# native-country_Yugoslavia - capital-loss-binary_1  -  fn :  24 - 0.000004 s
# native-country_Yugoslavia - capital-loss-binary_1  -  fnr :  0.96 - 0.000011 s
# native-country_Yugoslavia - capital-loss-binary_1  -  fomr :  0.0005154417765559898 - 0.000005 s
# native-country_Yugoslavia - capital-loss-binary_1  -  fp :  2283 - 0.000007 s
# native-country_Yugoslavia - capital-loss-binary_1  -  fpr :  0.046762663607873664 - 0.000005 s
# native-country_Yugoslavia - capital-loss-binary_1  -  mcc :  -0.0007243936627941391 - 0.000008 s
# native-country_Yugoslavia - capital-loss-binary_1  -  mk :  -7.761340527745464e-05 - 0.000015 s
# native-country_Yugoslavia - capital-loss-binary_1  -  n :  48846 - 0.000005 s
# native-country_Yugoslavia - capital-loss-binary_1  -  nlr :  1.0070944174652972 - 0.000006 s
# native-country_Yugoslavia - capital-loss-binary_1  -  npv :  0.9994845582234441 - 0.000004 s
# native-country_Yugoslavia - capital-loss-binary_1  -  plr :  0.8553832676303109 - 0.000005 s
# native-country_Yugoslavia - capital-loss-binary_1  -  ppv :  0.00043782837127845885 - 0.000004 s
# native-country_Yugoslavia - capital-loss-binary_1  -  precision :  0.00043782837127845885 - 0.000005 s
# native-country_Yugoslavia - capital-loss-binary_1  -  prevalence :  0.0005118126356303484 - 0.000005 s
# native-country_Yugoslavia - capital-loss-binary_1  -  pt :  0.5195157859328398 - 0.000008 s
# native-country_Yugoslavia - capital-loss-binary_1  -  recall :  0.04 - 0.000030 s
# native-country_Yugoslavia - capital-loss-binary_1  -  sensitivity :  0.04 - 0.000004 s
# native-country_Yugoslavia - capital-loss-binary_1  -  specificity :  0.9532373363921264 - 0.000005 s
# native-country_Yugoslavia - capital-loss-binary_1  -  tn :  46538 - 0.000004 s
# native-country_Yugoslavia - capital-loss-binary_1  -  tnr :  0.9532373363921264 - 0.000004 s
# native-country_Yugoslavia - capital-loss-binary_1  -  tp :  1 - 0.000004 s
# native-country_Yugoslavia - capital-loss-binary_1  -  tpr :  0.04 - 0.000004 s
# native-country_Yugoslavia - capital-loss-binary_1  -  ts :  0.04 - 0.000004 s
# native-country_nan - capital-gain-binary_1  -  acc :  0.9125619293289112 - 0.000016 s
# native-country_nan - capital-gain-binary_1  -  ba :  0.496701085837563 - 0.000012 s
# native-country_nan - capital-gain-binary_1  -  bm :  -0.006597828324873989 - 0.000007 s
# native-country_nan - capital-gain-binary_1  -  dor :  0.9136337004921491 - 0.000008 s
# native-country_nan - capital-gain-binary_1  -  f1 :  0.009738001391143055 - 0.000007 s
# native-country_nan - capital-gain-binary_1  -  fdr :  0.9947981174139212 - 0.000005 s
# native-country_nan - capital-gain-binary_1  -  fn :  255 - 0.000004 s
# native-country_nan - capital-gain-binary_1  -  fnr :  0.9239130434782609 - 0.000010 s
# native-country_nan - capital-gain-binary_1  -  fomr :  0.005690821040415988 - 0.000005 s
# native-country_nan - capital-gain-binary_1  -  fp :  4016 - 0.000004 s
# native-country_nan - capital-gain-binary_1  -  fpr :  0.08268478484661314 - 0.000006 s
# native-country_nan - capital-gain-binary_1  -  mcc :  -0.019890974646176344 - 0.000007 s
# native-country_nan - capital-gain-binary_1  -  mk :  -0.0004889384543371733 - 0.000007 s
# native-country_nan - capital-gain-binary_1  -  n :  48846 - 0.000005 s
# native-country_nan - capital-gain-binary_1  -  nlr :  1.0071925421227976 - 0.000006 s
# native-country_nan - capital-gain-binary_1  -  npv :  0.994309178959584 - 0.000015 s
# native-country_nan - capital-gain-binary_1  -  plr :  0.9202050493677464 - 0.000015 s
# native-country_nan - capital-gain-binary_1  -  ppv :  0.005201882586078771 - 0.000005 s
# native-country_nan - capital-gain-binary_1  -  precision :  0.005201882586078771 - 0.000005 s
# native-country_nan - capital-gain-binary_1  -  prevalence :  0.0056504114973590465 - 0.000006 s
# native-country_nan - capital-gain-binary_1  -  pt :  0.5103933469228646 - 0.000008 s
# native-country_nan - capital-gain-binary_1  -  recall :  0.07608695652173914 - 0.000027 s
# native-country_nan - capital-gain-binary_1  -  sensitivity :  0.07608695652173914 - 0.000004 s
# native-country_nan - capital-gain-binary_1  -  specificity :  0.9173152151533869 - 0.000005 s
# native-country_nan - capital-gain-binary_1  -  tn :  44554 - 0.000005 s
# native-country_nan - capital-gain-binary_1  -  tnr :  0.9173152151533869 - 0.000004 s
# native-country_nan - capital-gain-binary_1  -  tp :  21 - 0.000004 s
# native-country_nan - capital-gain-binary_1  -  tpr :  0.07608695652173914 - 0.000008 s
# native-country_nan - capital-gain-binary_1  -  ts :  0.07608695652173914 - 0.000005 s
# native-country_nan - capital-loss-binary_1  -  acc :  0.9479179461982558 - 0.000018 s
# native-country_nan - capital-loss-binary_1  -  ba :  0.49106265273786825 - 0.000016 s
# native-country_nan - capital-loss-binary_1  -  bm :  -0.01787469452426349 - 0.000005 s
# native-country_nan - capital-loss-binary_1  -  dor :  0.607166277575217 - 0.000007 s
# native-country_nan - capital-loss-binary_1  -  f1 :  0.0062499999999999995 - 0.000006 s
# native-country_nan - capital-loss-binary_1  -  fdr :  0.9964973730297724 - 0.000005 s
# native-country_nan - capital-loss-binary_1  -  fn :  268 - 0.000005 s
# native-country_nan - capital-loss-binary_1  -  fnr :  0.9710144927536232 - 0.000006 s
# native-country_nan - capital-loss-binary_1  -  fomr :  0.0057557665048752205 - 0.000005 s
# native-country_nan - capital-loss-binary_1  -  fp :  2276 - 0.000005 s
# native-country_nan - capital-loss-binary_1  -  fpr :  0.04686020177064031 - 0.000006 s
# native-country_nan - capital-loss-binary_1  -  mcc :  -0.01492861037415021 - 0.000008 s
# native-country_nan - capital-loss-binary_1  -  mk :  -0.0022531395346475636 - 0.000006 s
# native-country_nan - capital-loss-binary_1  -  n :  48846 - 0.000004 s
# native-country_nan - capital-loss-binary_1  -  nlr :  1.0187534866946792 - 0.000005 s
# native-country_nan - capital-loss-binary_1  -  npv :  0.9942442334951248 - 0.000008 s
# native-country_nan - capital-loss-binary_1  -  plr :  0.6185527622831818 - 0.000009 s
# native-country_nan - capital-loss-binary_1  -  ppv :  0.0035026269702276708 - 0.000004 s
# native-country_nan - capital-loss-binary_1  -  precision :  0.0035026269702276708 - 0.000006 s
# native-country_nan - capital-loss-binary_1  -  prevalence :  0.0056504114973590465 - 0.000005 s
# native-country_nan - capital-loss-binary_1  -  pt :  0.5597595821272273 - 0.000007 s
# native-country_nan - capital-loss-binary_1  -  recall :  0.028985507246376812 - 0.000030 s
# native-country_nan - capital-loss-binary_1  -  sensitivity :  0.028985507246376812 - 0.000005 s
# native-country_nan - capital-loss-binary_1  -  specificity :  0.9531397982293597 - 0.000005 s
# native-country_nan - capital-loss-binary_1  -  tn :  46294 - 0.000005 s
# native-country_nan - capital-loss-binary_1  -  tnr :  0.9531397982293597 - 0.000005 s
# native-country_nan - capital-loss-binary_1  -  tp :  8 - 0.000005 s
# native-country_nan - capital-loss-binary_1  -  tpr :  0.028985507246376812 - 0.000005 s
# native-country_nan - capital-loss-binary_1  -  ts :  0.028985507246376812 - 0.000005 s
# income_>50K - capital-gain-binary_1  -  acc :  0.7800843467223518 - 0.000018 s
# income_>50K - capital-gain-binary_1  -  ba :  0.5858057842358755 - 0.000013 s
# income_>50K - capital-gain-binary_1  -  bm :  0.17161156847175096 - 0.000007 s
# income_>50K - capital-gain-binary_1  -  dor :  6.245536236137224 - 0.000007 s
# income_>50K - capital-gain-binary_1  -  f1 :  0.31692738140658777 - 0.000007 s
# income_>50K - capital-gain-binary_1  -  fdr :  0.3827099331186525 - 0.000005 s
# income_>50K - capital-gain-binary_1  -  fn :  9197 - 0.000004 s
# income_>50K - capital-gain-binary_1  -  fnr :  0.7868081101890666 - 0.000006 s
# income_>50K - capital-gain-binary_1  -  fomr :  0.20524894552433662 - 0.000004 s
# income_>50K - capital-gain-binary_1  -  fp :  1545 - 0.000005 s
# income_>50K - capital-gain-binary_1  -  fpr :  0.04158032133918239 - 0.000006 s
# income_>50K - capital-gain-binary_1  -  mcc :  -0.05055772176994318 - 0.000008 s
# income_>50K - capital-gain-binary_1  -  mk :  0.412041121357011 - 0.000006 s
# income_>50K - capital-gain-binary_1  -  n :  48846 - 0.000004 s
# income_>50K - capital-gain-binary_1  -  nlr :  0.8209431919098941 - 0.000005 s
# income_>50K - capital-gain-binary_1  -  npv :  0.7947510544756634 - 0.000010 s
# income_>50K - capital-gain-binary_1  -  plr :  5.127230452883398 - 0.000006 s
# income_>50K - capital-gain-binary_1  -  ppv :  0.6172900668813476 - 0.000007 s
# income_>50K - capital-gain-binary_1  -  precision :  0.6172900668813476 - 0.000005 s
# income_>50K - capital-gain-binary_1  -  prevalence :  0.23930311591532571 - 0.000004 s
# income_>50K - capital-gain-binary_1  -  pt :  0.3063407459342096 - 0.000009 s
# income_>50K - capital-gain-binary_1  -  recall :  0.21319188981093334 - 0.000031 s
# income_>50K - capital-gain-binary_1  -  sensitivity :  0.21319188981093334 - 0.000010 s
# income_>50K - capital-gain-binary_1  -  specificity :  0.9584196786608176 - 0.000005 s
# income_>50K - capital-gain-binary_1  -  tn :  35612 - 0.000005 s
# income_>50K - capital-gain-binary_1  -  tnr :  0.9584196786608176 - 0.000004 s
# income_>50K - capital-gain-binary_1  -  tp :  2492 - 0.000006 s
# income_>50K - capital-gain-binary_1  -  tpr :  0.21319188981093334 - 0.000005 s
# income_>50K - capital-gain-binary_1  -  ts :  0.21319188981093334 - 0.000004 s
# income_>50K - capital-loss-binary_1  -  acc :  0.7608197191172256 - 0.000018 s
# income_>50K - capital-loss-binary_1  -  ba :  0.5336508150025073 - 0.000010 s
# income_>50K - capital-loss-binary_1  -  bm :  0.06730163000501466 - 0.000005 s
# income_>50K - capital-loss-binary_1  -  dor :  3.4339657487799777 - 0.000012 s
# income_>50K - capital-loss-binary_1  -  f1 :  0.1638874973162528 - 0.000007 s
# income_>50K - capital-loss-binary_1  -  fdr :  0.4986865148861646 - 0.000006 s
# income_>50K - capital-loss-binary_1  -  fn :  10544 - 0.000005 s
# income_>50K - capital-loss-binary_1  -  fnr :  0.9020446573701771 - 0.000004 s
# income_>50K - capital-loss-binary_1  -  fomr :  0.22645075383359822 - 0.000004 s
# income_>50K - capital-loss-binary_1  -  fp :  1139 - 0.000005 s
# income_>50K - capital-loss-binary_1  -  fpr :  0.030653712624808246 - 0.000006 s
# income_>50K - capital-loss-binary_1  -  mcc :  -0.0557070649420263 - 0.000007 s
# income_>50K - capital-loss-binary_1  -  mk :  0.27486273128023697 - 0.000005 s
# income_>50K - capital-loss-binary_1  -  n :  48846 - 0.000004 s
# income_>50K - capital-loss-binary_1  -  nlr :  0.9305700853435414 - 0.000006 s
# income_>50K - capital-loss-binary_1  -  npv :  0.7735492461664017 - 0.000005 s
# income_>50K - capital-loss-binary_1  -  plr :  3.195545799908982 - 0.000005 s
# income_>50K - capital-loss-binary_1  -  ppv :  0.5013134851138353 - 0.000005 s
# income_>50K - capital-loss-binary_1  -  precision :  0.5013134851138353 - 0.000005 s
# income_>50K - capital-loss-binary_1  -  prevalence :  0.23930311591532571 - 0.000005 s
# income_>50K - capital-loss-binary_1  -  pt :  0.35873037206563074 - 0.000008 s
# income_>50K - capital-loss-binary_1  -  recall :  0.09795534262982292 - 0.000028 s
# income_>50K - capital-loss-binary_1  -  sensitivity :  0.09795534262982292 - 0.000010 s
# income_>50K - capital-loss-binary_1  -  specificity :  0.9693462873751918 - 0.000008 s
# income_>50K - capital-loss-binary_1  -  tn :  36018 - 0.000005 s
# income_>50K - capital-loss-binary_1  -  tnr :  0.9693462873751918 - 0.000005 s
# income_>50K - capital-loss-binary_1  -  tp :  1145 - 0.000005 s
# income_>50K - capital-loss-binary_1  -  tpr :  0.09795534262982292 - 0.000005 s
# income_>50K - capital-loss-binary_1  -  ts :  0.09795534262982292 - 0.000004 s
# capital-gain-binary_1 - capital-loss-binary_1  -  acc :  0.8706342382180732 - 0.000019 s
# capital-gain-binary_1 - capital-loss-binary_1  -  ba :  0.47464906133695484 - 0.000011 s
# capital-gain-binary_1 - capital-loss-binary_1  -  bm :  -0.05070187732609033 - 0.000005 s
# capital-gain-binary_1 - capital-loss-binary_1  -  dor :  0.004615273749569685 - 0.000007 s
# capital-gain-binary_1 - capital-loss-binary_1  -  f1 :  0.0003164056320202499 - 0.000007 s
# capital-gain-binary_1 - capital-loss-binary_1  -  fdr :  0.9995621716287215 - 0.000005 s
# capital-gain-binary_1 - capital-loss-binary_1  -  fn :  4036 - 0.000004 s
# capital-gain-binary_1 - capital-loss-binary_1  -  fnr :  0.9997522913054249 - 0.000004 s
# capital-gain-binary_1 - capital-loss-binary_1  -  fomr :  0.08668012542416563 - 0.000015 s
# capital-gain-binary_1 - capital-loss-binary_1  -  fp :  2283 - 0.000006 s
# capital-gain-binary_1 - capital-loss-binary_1  -  fpr :  0.05094958602066549 - 0.000006 s
# capital-gain-binary_1 - capital-loss-binary_1  -  mcc :  -0.06612598136877407 - 0.000011 s
# capital-gain-binary_1 - capital-loss-binary_1  -  mk :  -0.0862422970528871 - 0.000013 s
# capital-gain-binary_1 - capital-loss-binary_1  -  n :  48846 - 0.000005 s
# capital-gain-binary_1 - capital-loss-binary_1  -  nlr :  1.0534237977026943 - 0.000006 s
# capital-gain-binary_1 - capital-loss-binary_1  -  npv :  0.9133198745758344 - 0.000011 s
# capital-gain-binary_1 - capital-loss-binary_1  -  plr :  0.004861839200709252 - 0.000007 s
# capital-gain-binary_1 - capital-loss-binary_1  -  ppv :  0.00043782837127845885 - 0.000007 s
# capital-gain-binary_1 - capital-loss-binary_1  -  precision :  0.00043782837127845885 - 0.000005 s
# capital-gain-binary_1 - capital-loss-binary_1  -  prevalence :  0.08264750440158866 - 0.000005 s
# capital-gain-binary_1 - capital-loss-binary_1  -  pt :  0.9348180449329371 - 0.000008 s
# capital-gain-binary_1 - capital-loss-binary_1  -  recall :  0.00024770869457517957 - 0.000029 s
# capital-gain-binary_1 - capital-loss-binary_1  -  sensitivity :  0.00024770869457517957 - 0.000005 s
# capital-gain-binary_1 - capital-loss-binary_1  -  specificity :  0.9490504139793345 - 0.000004 s
# capital-gain-binary_1 - capital-loss-binary_1  -  tn :  42526 - 0.000006 s
# capital-gain-binary_1 - capital-loss-binary_1  -  tnr :  0.9490504139793345 - 0.000005 s
# capital-gain-binary_1 - capital-loss-binary_1  -  tp :  1 - 0.000006 s
# capital-gain-binary_1 - capital-loss-binary_1  -  tpr :  0.00024770869457517957 - 0.000005 s
# capital-gain-binary_1 - capital-loss-binary_1  -  ts :  0.00024770869457517957 - 0.000006 s

# %%
import torch
import numpy as np
import pickle
rbf_hsic_matrix = torch.load('rbf_hsic_matrix_fullv3.pt')
linear_hsic_matrix = torch.load('linear_hsic_matrix_fullv3.pt')
mutual_information_matrix = torch.load('mutual_information_matrix_fullv3.pt')
distance_correlation_matrix = torch.load('distance_correlation_matrix_fullv3.pt')
chi2_matrix = torch.load('chi2_matrix_fullv3.pt')
theils_u_matrix = torch.load('theils_u_matrix_fullv3.pt')
cramers_v_matrix = torch.load('cramers_v_matrix_fullv3.pt')

maximal_coefficient_matrix = torch.load('maximal_coefficient_matrix_fullv3.pt')
spearsmans_matrix = torch.load('spearmans_rank_matrix_fullv3.pt')
pearsons_matrix = torch.load('pearsons_correlation_coefficient_matrix_fullv3.pt')

def load_measure_matrix(filename):
    with open(filename, 'rb') as f:
        data = pickle.load(f)
    return data['matrix'], data['feature_names']

agreement_matrix, agreement_feature_names = load_measure_matrix('agreement_matrixv3.pkl')
binary_matrix, binary_feature_names = load_measure_matrix('binary_matrixv3.pkl')
categorical_matrix, categorical_feature_names = load_measure_matrix('categorical_matrixv3.pkl')
confusion_matrix, confusion_feature_names = load_measure_matrix('confusion_matrixv3.pkl')

num_features = rbf_hsic_matrix.shape[0]
from sklearn.preprocessing import OneHotEncoder

print(X_encoded.shape)

index = []
attr = []

for a in range(num_features):
    for b in range(a + 1, num_features):
        index.append([i,j])

        list1 = [linear_hsic_matrix[i, j],
            rbf_hsic_matrix[i, j],
            mutual_information_matrix[i, j],
            distance_correlation_matrix[i, j],
            maximal_coefficient_matrix[i,j],
            spearsmans_matrix[i,j],
            pearsons_matrix[i,j],
            chi2_matrix[i, j],
            theils_u_matrix[i, j],
            cramers_v_matrix[i, j],
                 ]
        if i<107 and j<107:
          for measure in agreement_matrix[i][j].keys():
            list1.append(agreement_matrix[i][j][measure])
          for measure in binary_matrix[i][j].keys():
            if measure == 'mcnemar_test':
              list1.append(binary_matrix[i][j][measure][0])
            else:
              list1.append(binary_matrix[i][j][measure])
          for measure in categorical_matrix[i][j].keys():
            list1.append(categorical_matrix[i][j][measure])
          for measure in confusion_matrix[i][j].keys():
            list1.append(confusion_matrix[i][j][measure])
          list1.extend([1,0,0])
        elif i>=107 and j>=107:
          list1.extend([0]*115)
          list1.extend([0,0,1])
        else:
          list1.extend([0]*115)
          list1.extend([0,1,0])
        attr.append(list1)


attr = torch.tensor(attr, dtype=torch.float)
index = torch.tensor(index, dtype=torch.int)
print(attr.shape)
print(index.shape)

torch.save(attr, 'census_attr_finalv2.pt')
# !cp 'census_attr_finalv2.pt' /content/drive/MyDrive

torch.save(index, 'census_index_finalv2.pt')
# !cp 'census_attr_finalv2.pt' /content/drive/MyDrive
# Out:
# torch.Size([48842, 112])
# torch.Size([6441, 128])
# torch.Size([6441, 2])
